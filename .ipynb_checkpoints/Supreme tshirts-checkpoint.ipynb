# %%
import requests
import json
import threading
import csv
from datetime import datetime
import time
import re

from pyquery import PyQuery as pq

from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

def log(t):
    ts = datetime.now().strftime('%H:%M:%S')
    print('{} :: {}'.format(ts, t))

# %%
SPRING_SUMMER = 'spring-summer'
FALL_WINTER = 'fall-winter'
SEASON_TEMPLATE = 'https://www.supremecommunity.com/season/{}{}/droplists/'

USER_AGENT_1 = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
USER_AGENT_2 = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
USER_AGENT_3 = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/605.1.15 (KHTML, like Gecko)'
USER_AGENT_4 = 'Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Mobile/13G36'
USER_AGENT_5 = 'Mozilla/5.0 (iPhone; CPU iPhone OS 13_4_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1 Mobile/15E148 Safari/604.1'

def cut_last_six(s):
    return s[:-6]

def sc_to_stockx_name(sc):
    sc = sc.replace(' ', '-')
    sc = sc.replace('L/S', 'ls')
    sc = sc.replace('/', '-')
    sc = sc.replace('™', '-')
    sc = sc.replace('®', '-')
    sc = sc.replace('&', '-')
    sc = sc.replace('+', '-')
    sc = sc.replace('"', '')
    sc = sc.replace('--', '-')
    sc = sc.replace('.','')
    sc = sc.replace('Supreme', '')
    sc = 'supreme-' + sc + '-black'
    sc = sc.replace('--', '-')
    return sc

# %%
class Downloader(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.S = requests.Session()
        self.S.headers = {
            'user-agent': USER_AGENT_2,
            'content-type': 'application/json'
        }
        self.rawdetails = {}
        
    def get_search_results(self, query):
        log('Retrieving search results for {}'.format(query))
        
        r = self.S.request(
            method='get',
            url='https://stockx.com/api/browse?&_search={}'.format(query),
        )
        try:
            j = r.json()
        except json.decoder.JSONDecodeError:
            log('Product detail retrieval failed [{}]'.format(r.status_code))
            return 'Failed'
        try:
            r.raise_for_status()
        except requests.exceptions.HTTPError:
            log('Product detail retrieval failed [{}] : {}'.format(r.status_code, j['error']))
            return 'Failed'
        return j
    
    def get_raw_details(self, product):
        log('Retrieving raw details for {}'.format(product))
        
        r = self.S.request(
            method='get',
            url='https://stockx.com/api/products/{}?includes=market'.format(product),
            params = {
            }
        )
        try: 
            j = r.json()
        except json.decoder.JSONDecodeError:
            log('Product detail retrieval failed [{}]'.format(r.status_code))
            return 'Failed'
        except requests.exceptions.HTTPError as e:
            log("Error: " + str(e))
            return "Failed"
        try:
            r.raise_for_status()
        except requests.exceptions.HTTPError as e:
#             log('Product detail retrieval failed [{}] : {}'.format(r.status_code, j['error']))
            log("Error: " + str(e))
            return "Failed"
        self.rawdetails = j
        return j

# %%
def get_season_links(season, year):
    response = requests.get(SEASON_TEMPLATE.format(season, year))
    doc = pq(response.content)
    links = [('https://www.supremecommunity.com' + pq(block).attr('href'), pq(block).attr('href')[-11:-1])
            for block in doc('a.block')]
    links.reverse()
    return links

def get_week_tees_from_url(url):
    response = requests.get(url)
    doc = pq(response.content)
    return [{'name': pq(card).find('h2').text(), 'retail': re.search('\$(.*)/', pq(card).find('.label-price').text()).group(1)} 
            for card in doc('.card.card-2') 
            if pq(card).find('.category').text() == 't-shirts']

def get_season_tees(season, year):
    return [{"week": link[1],"tees": get_week_tees_from_url(link[0])}
            for link in get_season_links(season,year)]

def get_all_tees():
    all_tees = []
    for y in [2017, 2018, 2019]:
        for s in [SPRING_SUMMER, FALL_WINTER]:
            all_tees.append(get_season_tees(s,y))
    all_tees.append(get_season_tees(SPRING_SUMMER, 2020))
    return all_tees

def add_stockx_names(lst):
    for season in lst:
        for week in season:
            for t in week['tees']:
                t['search'] = sc_to_stockx_name(t['name'])
    return lst

# TODO: verify urls, then a getter for colors

def ss18(lst):
    for season in lst:
        for week in season:
            for t in week['tees']:
                if week['week'] == '2018-06-28':
                    t['search'] += '-ss18' 
        
def add_stockx_prices(lst):
    d = Downloader()
    for season in lst:
        for week in season:
            for t in week['tees']:
                # 3 seconds is enough to avoid bans
                time.sleep(3)
                search_result = d.get_raw_details(t['search'])
                try:
                    t['price'] = search_result['Product']['market']['averageDeadstockPrice']
                    if t['price'] == 0:
                        t['price'] = "Bad search: zero average"
                    print('Good search. '+ str(t['price']))
                except (AttributeError, IndexError, TypeError, KeyError):
                    print("{} was a bad search".format(t['search']))
                    t['price'] = "Bad search"
    return lst

# %%
def csv_to_object(c):
    ob = []
    with open(c, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            ob.append({'name': row['ï»¿name'], 'search': row['stockx search'], 'week': row['release date']})
    return ob

# %%
def get_all_search_results(tees):
    d = Downloader()
    for t in tees:
        search = cut_last_six(t['search'])
        j = d.get_search_results(search)['Products']
        all_results.append(j)
        time.sleep(4)
    return all_results

def get_all_info(tees, start, end):
    d = Downloader()
    for t in tees[start:end]:
        search = cut_last_six(t['search']).lower()
        j = d.get_search_results(search)['Products']
        colors = []
        total = 0
        num = 0
        for p in j:
            if search in str(p['urlKey']) and p['childId'] is None:
                colors.append({'color': p['urlKey'].replace(search,'')[1:], 'price': p['market']['averageDeadstockPrice']})
                if p['market']['averageDeadstockPrice']:
                    num += 1
                    total += p['market']['averageDeadstockPrice']
        print('Got {} colors'.format(len(colors)))
        t['colors'] = colors
        if num > 0:
            t['average'] = total/num
        
    with open('data{}-{}.json'.format(start,end), 'w') as outfile:
        json.dump(tees[start:end], outfile)
    return tees[start:end]

# %%
tees = csv_to_object('supreme black tees.csv')

# %%
all_results = []

# %%
get_all_info(tees, 186, 190)
# Out:
# []

# %%
d.get_search_results('supreme-the-north-face-photo-tee')
# Out:
# 23:30:46 :: Retrieving search results for supreme-the-north-face-photo-tee
# {'Pagination': {'limit': 40,
#   'page': 1,
#   'total': 0,
#   'lastPage': '/api/v3/browse?_search=supreme-the-north-face-photo-tee&page=0',
#   'sort': ['featured'],
#   'order': ['DESC'],
#   'currentPage': '/api/v3/browse?_search=supreme-the-north-face-photo-tee',
#   'nextPage': '/api/v3/browse?_search=supreme-the-north-face-photo-tee&page=2',
#   'previousPage': None},
#  'Facets': {},
#  'Products': []}

# %%
d = Downloader()
cloud = d.get_search_results('supreme-cloud-tee')
# Out:
# 22:59:36 :: Retrieving search results for supreme-cloud-tee
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-d662601f3754> in get_search_results(self, query)
#      23         try:
# ---> 24             r.raise_for_status()
#      25         except requests.exceptions.HTTPError:
#
# ~\AppData\Roaming\Python\Python37\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 403 Client Error: Forbidden for url: https://stockx.com/api/browse?&_search=supreme-cloud-tee
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-9f3fd7af790d> in <module>()
#       1 d = Downloader()
# ----> 2 cloud = d.get_search_results('supreme-cloud-tee')
#
# <ipython-input-3-d662601f3754> in get_search_results(self, query)
#      24             r.raise_for_status()
#      25         except requests.exceptions.HTTPError:
# ---> 26             log('Product detail retrieval failed [{}] : {}'.format(r.status_code, j['error']))
#      27             return 'Failed'
#      28         return j
#
# KeyError: 'error'

# %%
cloud['Products'][0]['urlKey']
# Out:
# 'supreme-cloud-tee-black'

# %%
'ss18' in 'supreme-ss18'[-5:]
# Out:
# True

# %%
def read_json(lst, file):
    with open(file) as json_file:
        data = json.load(json_file)
        lst += data
        return lst

# %%
full = []

# %%
read_json(full, 'data0-184.json')
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208},
#    {'color': 'black', 'price': 246},
#    {'color': 'white', 'price': 212},
#    {'color': 'heather-grey', 'price': 172},
#    {'color': 'navy', 'price': 191},
#    {'color': 'lime-green', 'price': 218},
#    {'color': 'lt-pink', 'price': 196},
#    {'color': 'aqua', 'price': 189},
#    {'color': 'red', 'price': None}],
#   'average': 204.0},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318},
#    {'color': 'grey', 'price': 121},
#    {'color': 'white', 'price': 233},
#    {'color': 'black', 'price': 315},
#    {'color': 'lt-green', 'price': 165},
#    {'color': 'mocha', 'price': 150},
#    {'color': 'aqua', 'price': 180},
#    {'color': 'red', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 211.71428571428572},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107},
#    {'color': 'navy', 'price': 110},
#    {'color': 'black', 'price': 138},
#    {'color': 'red', 'price': 95},
#    {'color': 'bright-coral', 'price': 80},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'mocha', 'price': None}],
#   'average': 106.0},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61},
#    {'color': 'black', 'price': 127},
#    {'color': 'white', 'price': 146},
#    {'color': 'lt-teal', 'price': 90},
#    {'color': 'mocha', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'red', 'price': 115},
#    {'color': 'lt-pink', 'price': None}],
#   'average': 107.8},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'bright-coral', 'price': 44},
#    {'color': 'navy', 'price': 70},
#    {'color': 'mocha', 'price': 46},
#    {'color': 'white', 'price': 66},
#    {'color': 'aqua', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 60.8},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120},
#    {'color': 'red', 'price': 90},
#    {'color': 'white', 'price': 145},
#    {'color': 'navy', 'price': 83},
#    {'color': 'grey', 'price': 65},
#    {'color': 'mocha', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'aqua', 'price': 133}],
#   'average': 106.0},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137},
#    {'color': 'white', 'price': 137},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 137.0},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 90},
#    {'color': 'heather-grey', 'price': 71},
#    {'color': 'pale-pink', 'price': 72},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 79.0},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95},
#    {'color': 'white', 'price': 73},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'black', 'price': 60},
#    {'color': 'light-blue', 'price': 91},
#    {'color': 'navy', 'price': 50},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 76.5},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84},
#    {'color': 'black', 'price': 76},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 66},
#    {'color': 'hot-pink', 'price': 50},
#    {'color': 'orange', 'price': 64},
#    {'color': 'light-blue', 'price': None},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'navy', 'price': 64}],
#   'average': 65.85714285714286},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 55},
#    {'color': 'navy', 'price': 57},
#    {'color': 'red', 'price': 40},
#    {'color': 'teal', 'price': 55},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 57.0},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'navy', 'price': 95},
#    {'color': 'white', 'price': 99},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'orange', 'price': None}],
#   'average': 98.33333333333333},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 56},
#    {'color': 'teal', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 77.5},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88},
#    {'color': 'heather-grey', 'price': 64},
#    {'color': 'white', 'price': 75},
#    {'color': 'navy', 'price': 66},
#    {'color': 'red', 'price': 53},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'dusty-pink', 'price': 60}],
#   'average': 67.66666666666667},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'black', 'price': 75},
#    {'color': 'lime', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'light-brown', 'price': None}],
#   'average': 64.75},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76},
#    {'color': 'orange', 'price': 60},
#    {'color': 'black', 'price': 87},
#    {'color': 'red', 'price': 72},
#    {'color': 'dark-pink', 'price': 48},
#    {'color': 'teal', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'pale-yellow', 'price': 48}],
#   'average': 65.16666666666667},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238},
#    {'color': 'black', 'price': 297},
#    {'color': 'heather-grey', 'price': 224},
#    {'color': 'pale-blue', 'price': 224},
#    {'color': 'red', 'price': 226},
#    {'color': 'brown', 'price': 266},
#    {'color': 'lime', 'price': 201}],
#   'average': 239.42857142857142},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175},
#    {'color': 'white', 'price': 162},
#    {'color': 'heather-grey', 'price': 110},
#    {'color': 'red', 'price': 123},
#    {'color': 'bright-orange', 'price': 93},
#    {'color': 'navy', 'price': 108},
#    {'color': 'royal', 'price': 208},
#    {'color': 'lime', 'price': 70},
#    {'color': 'brown', 'price': None}],
#   'average': 131.125},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'red', 'price': 100},
#    {'color': 'white', 'price': 116},
#    {'color': 'heather-grey', 'price': 95},
#    {'color': 'navy', 'price': 89},
#    {'color': 'lime', 'price': 61},
#    {'color': 'bright-orange', 'price': 121},
#    {'color': 'brown', 'price': 80}],
#   'average': 101.875},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'white', 'price': 82},
#    {'color': 'navy', 'price': 72},
#    {'color': 'light-pink', 'price': 63},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 75.5},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 50},
#    {'color': 'brown', 'price': 100},
#    {'color': 'lime', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 83.0},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58},
#    {'color': 'black', 'price': 113},
#    {'color': 'white', 'price': 122},
#    {'color': 'navy', 'price': 59},
#    {'color': 'lime', 'price': 60},
#    {'color': 'red', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 82.4},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73},
#    {'color': 'black', 'price': 71},
#    {'color': 'white', 'price': 71},
#    {'color': 'red', 'price': 63},
#    {'color': 'brown', 'price': 60},
#    {'color': 'navy', 'price': 55},
#    {'color': 'light-pink', 'price': 55},
#    {'color': 'lime', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 64.0},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 85.33333333333333},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 92},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'navy', 'price': 60},
#    {'color': 'royal', 'price': 75},
#    {'color': 'heather-grey', 'price': 75},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 73.0},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'heather-grey', 'price': 79},
#    {'color': 'white', 'price': 95},
#    {'color': 'red', 'price': 79},
#    {'color': 'navy', 'price': 71},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'pale-blue', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 80.66666666666667},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71},
#    {'color': 'black', 'price': 95},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 59},
#    {'color': 'brick', 'price': 70},
#    {'color': 'lime', 'price': 50},
#    {'color': 'pale-blue', 'price': 108},
#    {'color': 'navy', 'price': None}],
#   'average': 71.71428571428571},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57},
#    {'color': 'black', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'pale-blue', 'price': 90},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'red', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 59.2},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88}, {'color': 'black', 'price': 98}],
#   'average': 93.0},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65}, {'color': 'white', 'price': 64}],
#   'average': 64.5},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'heather-grey', 'price': 48},
#    {'color': 'lime', 'price': 50},
#    {'color': 'white', 'price': 50},
#    {'color': 'royal', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 48.75},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266},
#    {'color': 'red', 'price': 221},
#    {'color': 'white', 'price': 233},
#    {'color': 'heather-grey', 'price': 200}],
#   'average': 230.0},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134},
#    {'color': 'black', 'price': 208},
#    {'color': 'white', 'price': 180},
#    {'color': 'red', 'price': 148}],
#   'average': 167.5},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 140},
#    {'color': 'red', 'price': 119}],
#   'average': 143.25},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144},
#    {'color': 'white', 'price': 120},
#    {'color': 'heather-grey', 'price': 108},
#    {'color': 'red', 'price': 125}],
#   'average': 124.25},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253},
#    {'color': 'white', 'price': 273},
#    {'color': 'lime', 'price': 105},
#    {'color': 'cardinal', 'price': 132},
#    {'color': 'slate', 'price': 128}],
#   'average': 178.2},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230},
#    {'color': 'white', 'price': 190},
#    {'color': 'cardinal', 'price': 157},
#    {'color': 'slate', 'price': 153},
#    {'color': 'lime', 'price': 173}],
#   'average': 180.6},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 141},
#    {'color': 'slate', 'price': 120},
#    {'color': 'lime', 'price': 109}],
#   'average': 129.8},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150},
#    {'color': 'white', 'price': 116},
#    {'color': 'lime', 'price': 97},
#    {'color': 'slate', 'price': 127},
#    {'color': 'cardinal', 'price': 150}],
#   'average': 128.0},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104},
#    {'color': 'black', 'price': 80},
#    {'color': 'dark-slate', 'price': 59},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': None},
#    {'color': 'olive-green', 'price': None}],
#   'average': 76.0},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': []},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201},
#    {'color': 'white', 'price': 140},
#    {'color': 'heather-grey', 'price': 120},
#    {'color': 'lime', 'price': 110},
#    {'color': 'red', 'price': 150},
#    {'color': 'brown', 'price': 153},
#    {'color': 'dark-slate', 'price': 130},
#    {'color': 'bright-orange', 'price': 131}],
#   'average': 141.875},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127},
#    {'color': 'navy', 'price': 121},
#    {'color': 'white', 'price': 104},
#    {'color': 'heather-grey', 'price': 105},
#    {'color': 'light-pink', 'price': 176},
#    {'color': 'mustard', 'price': 125},
#    {'color': 'red', 'price': 100},
#    {'color': 'brown', 'price': 70},
#    {'color': 'lime', 'price': 65}],
#   'average': 110.33333333333333},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133},
#    {'color': 'white', 'price': 127},
#    {'color': 'brick', 'price': 101},
#    {'color': 'green', 'price': 71},
#    {'color': 'light-purple', 'price': 105},
#    {'color': 'dark-slate', 'price': 85},
#    {'color': 'heather-grey', 'price': 50}],
#   'average': 96.0},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93},
#    {'color': 'red', 'price': 69},
#    {'color': 'white', 'price': 89}],
#   'average': 83.66666666666667},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'green', 'price': 63},
#    {'color': 'light-purple', 'price': 55},
#    {'color': 'navy', 'price': 50},
#    {'color': 'brick', 'price': None}],
#   'average': 78.33333333333333},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 39},
#    {'color': 'white', 'price': 51},
#    {'color': 'mustard', 'price': 44},
#    {'color': 'grey', 'price': 41},
#    {'color': 'light-purple', 'price': 65},
#    {'color': 'dark-slate', 'price': 54},
#    {'color': 'green', 'price': 54}],
#   'average': 52.625},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89},
#    {'color': 'white', 'price': 86},
#    {'color': 'red', 'price': 69},
#    {'color': 'royal', 'price': 79}],
#   'average': 80.75},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 66}],
#   'average': 64.33333333333333},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 73},
#    {'color': 'royal', 'price': 81},
#    {'color': 'red', 'price': 66}],
#   'average': 76.75},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 74},
#    {'color': 'royal', 'price': 58}],
#   'average': 72.25},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172},
#    {'color': 'white', 'price': 148},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'navy', 'price': 122},
#    {'color': 'red', 'price': 100},
#    {'color': 'light-purple', 'price': 143},
#    {'color': 'light-pink', 'price': 193},
#    {'color': 'pale-blue', 'price': 140},
#    {'color': 'bright-yellow', 'price': 130}],
#   'average': 138.66666666666666},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129},
#    {'color': 'black', 'price': 125},
#    {'color': 'heather-grey', 'price': 78},
#    {'color': 'navy', 'price': 98},
#    {'color': 'pale-blue', 'price': 82},
#    {'color': 'green', 'price': 87},
#    {'color': 'red', 'price': 106},
#    {'color': 'bright-yellow', 'price': 61},
#    {'color': 'light-purple', 'price': 117}],
#   'average': 98.11111111111111},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55},
#    {'color': 'black', 'price': 68},
#    {'color': 'white', 'price': 65},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 52},
#    {'color': 'bright-yellow', 'price': 58},
#    {'color': 'pale-blue', 'price': 73}],
#   'average': 60.5},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'light-purple', 'price': 47},
#    {'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 53},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 66},
#    {'color': 'pale-blue', 'price': 54},
#    {'color': 'bright-yellow', 'price': 45},
#    {'color': 'green', 'price': 44}],
#   'average': 52.77777777777778},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 53},
#    {'color': 'pale-blue', 'price': 65},
#    {'color': 'light-purple', 'price': 53},
#    {'color': 'bright-yellow', 'price': 43},
#    {'color': 'green', 'price': 45},
#    {'color': 'navy', 'price': 65}],
#   'average': 58.0},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'heather-grey', 'price': 70},
#    {'color': 'white', 'price': 79},
#    {'color': 'royal', 'price': 53},
#    {'color': 'red', 'price': 58},
#    {'color': 'pale-yellow', 'price': 20}],
#   'average': 59.666666666666664},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65},
#    {'color': 'red', 'price': 43},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 62.0},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62},
#    {'color': 'hot-pink', 'price': 35},
#    {'color': 'white', 'price': 52},
#    {'color': 'royal', 'price': 50},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 48.8},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': []},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98}, {'color': 'white', 'price': 90}],
#   'average': 94.0},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'white', 'price': 81}],
#   'average': 91.0},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 81},
#    {'color': 'red', 'price': 71},
#    {'color': 'dark-green', 'price': 73},
#    {'color': 'light-purple', 'price': 84},
#    {'color': 'bright-orange', 'price': 68}],
#   'average': 74.0},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'red', 'price': 58},
#    {'color': 'white', 'price': 84},
#    {'color': 'dark-green', 'price': 79},
#    {'color': 'bright-orange', 'price': 43},
#    {'color': 'light-purple', 'price': 75}],
#   'average': 67.14285714285714},
#  {'name': 'Madonna Tee',
#   'search': 'supreme-Madonna-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 100},
#    {'color': 'black', 'price': 178},
#    {'color': 'dark-green', 'price': 102},
#    {'color': 'heather-grey', 'price': 109},
#    {'color': 'white', 'price': 167},
#    {'color': 'navy', 'price': 114},
#    {'color': 'red', 'price': 95},
#    {'color': 'pink', 'price': 97},
#    {'color': 'pale-yellow', 'price': 102}],
#   'average': 118.22222222222223},
#  {'name': 'Liquid Tee',
#   'search': 'supreme-Liquid-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 84},
#    {'color': 'navy', 'price': 76},
#    {'color': 'black', 'price': 94},
#    {'color': 'white', 'price': 88},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'burgundy', 'price': 71},
#    {'color': 'pink', 'price': 80},
#    {'color': 'natural', 'price': 76}],
#   'average': 79.5},
#  {'name': 'Still Life Tee',
#   'search': 'supreme-Still-Life-Tee-black',
#   'colors': [{'color': 'red', 'price': 49},
#    {'color': 'bright-blue', 'price': 55},
#    {'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 62},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'pink', 'price': 87},
#    {'color': 'dark-green', 'price': 62}],
#   'average': 64.625},
#  {'name': '1994 L/S Tee',
#   'search': 'supreme-1994-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'heather-grey', 'price': 88},
#    {'color': 'white', 'price': 102},
#    {'color': 'navy', 'price': 98},
#    {'color': 'natural', 'price': 101},
#    {'color': 'dark-green', 'price': 94},
#    {'color': 'burgundy', 'price': 83},
#    {'color': 'pink', 'price': 93},
#    {'color': 'red', 'price': 82}],
#   'average': 93.22222222222223},
#  {'name': 'Bottle Cap Tee',
#   'search': 'supreme-Bottle-Cap-Tee-black',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'white', 'price': 64},
#    {'color': 'red', 'price': 52},
#    {'color': 'bright-blue', 'price': 58},
#    {'color': 'navy', 'price': 63},
#    {'color': 'pale-yellow', 'price': 51},
#    {'color': 'pink', 'price': 62},
#    {'color': 'dark-green', 'price': 60}],
#   'average': 59.333333333333336},
#  {'name': 'Cutouts Tee',
#   'search': 'supreme-Cutouts-Tee-black',
#   'colors': [{'color': 'black', 'price': 75},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'bright-blue', 'price': 73},
#    {'color': 'pink', 'price': 56}],
#   'average': 60.75},
#  {'name': 'Life Sucks Die Tee',
#   'search': 'supreme-Life-Sucks-Die-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 54},
#    {'color': 'black', 'price': 64},
#    {'color': 'red', 'price': 55},
#    {'color': 'natural', 'price': 66},
#    {'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 52},
#    {'color': 'dark-green', 'price': 77},
#    {'color': 'bright-blue', 'price': 48},
#    {'color': 'pink', 'price': 53}],
#   'average': 58.888888888888886},
#  {'name': 'Bedroom Tee',
#   'search': 'supreme-Bedroom-Tee-black',
#   'colors': [{'color': 'navy', 'price': 59},
#    {'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 64},
#    {'color': 'light-pink', 'price': 80},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-green', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'natural', 'price': 70},
#    {'color': 'bright-blue', 'price': 51},
#    {'color': 'pink', 'price': 77}],
#   'average': 62.3},
#  {'name': 'Fuck You Tee',
#   'search': 'supreme-Fuck-You-Tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'bright-blue', 'price': 53},
#    {'color': 'dark-green', 'price': 56},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 57},
#    {'color': 'orange', 'price': 62},
#    {'color': 'red', 'price': 58}],
#   'average': 59.5},
#  {'name': 'Guts Tee',
#   'search': 'supreme-Guts-Tee-black',
#   'colors': [{'color': 'white', 'price': 57},
#    {'color': 'red', 'price': 47},
#    {'color': 'natural', 'price': 51},
#    {'color': 'black', 'price': 56},
#    {'color': 'navy', 'price': 51},
#    {'color': 'ash-grey', 'price': 50},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'bright-blue', 'price': 63},
#    {'color': 'pink', 'price': 56}],
#   'average': 54.333333333333336},
#  {'name': 'Mike Kelley/Supreme The Empire State Building Tee',
#   'search': 'supreme-mike-kelley-supreme-the-empire-state-building-tee-black',
#   'colors': [{'color': 'white', 'price': 66},
#    {'color': 'burgundy', 'price': 47},
#    {'color': 'ash-grey', 'price': 49},
#    {'color': 'black', 'price': 70},
#    {'color': 'dark-green', 'price': 49},
#    {'color': 'slate', 'price': 49},
#    {'color': 'clay', 'price': 51},
#    {'color': 'bright-orange', 'price': 51}],
#   'average': 54.0},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 77},
#    {'color': 'slate', 'price': 73},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'clay', 'price': 77},
#    {'color': 'black', 'price': 126},
#    {'color': 'white', 'price': 108},
#    {'color': 'dark-green', 'price': 84},
#    {'color': 'bright-orange', 'price': 94}],
#   'average': 89.875},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! L/S Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 166},
#    {'color': 'white', 'price': 134},
#    {'color': 'clay', 'price': 95},
#    {'color': 'ash-grey', 'price': 103},
#    {'color': 'slate', 'price': 93},
#    {'color': 'dark-green', 'price': 103},
#    {'color': 'burgundy', 'price': 104},
#    {'color': 'bright-orange', 'price': 105}],
#   'average': 112.875},
#  {'name': 'Mike Kelley/Supreme Hiding From Indians Tee',
#   'search': 'supreme-mike-kelley-supreme-hiding-from-indians-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 46},
#    {'color': 'black', 'price': 59},
#    {'color': 'clay', 'price': 55},
#    {'color': 'white', 'price': 58},
#    {'color': 'burgundy', 'price': 48},
#    {'color': 'bright-orange', 'price': 59},
#    {'color': 'dark-green', 'price': 61},
#    {'color': 'slate', 'price': 57}],
#   'average': 55.375},
#  {'name': 'SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee',
#   'search': 'supreme-comme-des-garcons-shirt-split-box-logo-tee-black',
#   'colors': []},
#  {'name': 'Group Tee',
#   'search': 'supreme-Group-Tee-black',
#   'colors': [{'color': 'slate', 'price': 65},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 82},
#    {'color': 'red', 'price': 76},
#    {'color': 'dark-pink', 'price': 76},
#    {'color': 'bright-orange', 'price': 68},
#    {'color': 'navy', 'price': 75},
#    {'color': 'dark-green', 'price': 72}],
#   'average': 74.0},
#  {'name': 'Remember Tee',
#   'search': 'supreme-Remember-Tee-black',
#   'colors': [{'color': 'black', 'price': 81},
#    {'color': 'dark-pink', 'price': 63},
#    {'color': 'white', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'heather-grey', 'price': 74},
#    {'color': 'red', 'price': 68},
#    {'color': 'slate', 'price': 74},
#    {'color': 'bright-orange', 'price': 66}],
#   'average': 72.5},
#  {'name': 'Liquid Swords Tee',
#   'search': 'supreme-Liquid-Swords-Tee-black',
#   'colors': [{'color': 'dark-green', 'price': 89},
#    {'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 81},
#    {'color': 'heather-grey', 'price': 81},
#    {'color': 'navy', 'price': 94},
#    {'color': 'slate', 'price': 96},
#    {'color': 'red', 'price': 80},
#    {'color': 'bright-orange', 'price': 85}],
#   'average': 88.125},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889},
#  {'name': 'Payphone Tee',
#   'search': 'supreme-Payphone-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 52},
#    {'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 57},
#    {'color': 'natural', 'price': 53},
#    {'color': 'red', 'price': 48},
#    {'color': 'bright-orange', 'price': 48},
#    {'color': 'dark-pink', 'price': 47},
#    {'color': 'navy', 'price': 56},
#    {'color': 'slate', 'price': 61}],
#   'average': 53.0},
#  {'name': 'Faces Tee',
#   'search': 'supreme-Faces-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'slate', 'price': 55},
#    {'color': 'dark-pink', 'price': 49},
#    {'color': 'bright-orange', 'price': 39},
#    {'color': 'navy', 'price': 59},
#    {'color': 'red', 'price': 51}],
#   'average': 51.625},
#  {'name': 'System Tee',
#   'search': 'supreme-System-Tee-black',
#   'colors': [{'color': 'black', 'price': 45},
#    {'color': 'ash-grey', 'price': 40},
#    {'color': 'white', 'price': 49},
#    {'color': 'navy', 'price': 45},
#    {'color': 'dark-pink', 'price': 40},
#    {'color': 'slate', 'price': 44},
#    {'color': 'bright-orange', 'price': 42},
#    {'color': 'burgundy', 'price': 41}],
#   'average': 43.25},
#  {'name': 'The Killer Trust Tee',
#   'search': 'supreme-The-Killer-Trust-Tee-black',
#   'colors': [{'color': 'black', 'price': 238},
#    {'color': 'olive', 'price': 147},
#    {'color': 'white', 'price': 183},
#    {'color': 'heather-grey', 'price': 142},
#    {'color': 'red', 'price': 123},
#    {'color': 'navy', 'price': 191},
#    {'color': 'pale-yellow', 'price': 131}],
#   'average': 165.0},
#  {'name': 'Chris Cunningham Chihuahua Tee',
#   'search': 'supreme-Chris-Cunningham-Chihuahua-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'white', 'price': 58},
#    {'color': 'pale-mint', 'price': 57},
#    {'color': 'taupe', 'price': 55},
#    {'color': 'red', 'price': 55}],
#   'average': 59.6},
#  {'name': 'Chris Cunningham Rubber Johnny Tee',
#   'search': 'supreme-Chris-Cunningham-Rubber-Johnny-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'pale-mint', 'price': 53},
#    {'color': 'taupe', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'red', 'price': 43}],
#   'average': 50.2},
#  {'name': 'SupremeÂ®/The North FaceÂ® Photo Tee',
#   'search': 'supreme-the-north-face-photo-tee-black',
#   'colors': []},
#  {'name': 'Cat in the Hat Tee',
#   'search': 'supreme-Cat-in-the-Hat-Tee-black',
#   'colors': [{'color': 'black', 'price': 107},
#    {'color': 'white', 'price': 97},
#    {'color': 'purple', 'price': 95},
#    {'color': 'red', 'price': 85},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 88},
#    {'color': 'yellow', 'price': 69},
#    {'color': 'olive', 'price': 76}],
#   'average': 88.25},
#  {'name': 'Marvin Gaye Tee',
#   'search': 'supreme-Marvin-Gaye-Tee-black',
#   'colors': [{'color': 'white', 'price': 60},
#    {'color': 'black', 'price': 64},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'clay', 'price': 61},
#    {'color': 'navy', 'price': 55},
#    {'color': 'red', 'price': 61},
#    {'color': 'purple', 'price': 66},
#    {'color': 'yellow', 'price': 54}],
#   'average': 59.125},
#  {'name': 'Smile Tee',
#   'search': 'supreme-Smile-Tee-black',
#   'colors': [{'color': 'black', 'price': 104},
#    {'color': 'white', 'price': 90},
#    {'color': 'red', 'price': 88},
#    {'color': 'clay', 'price': 80},
#    {'color': 'heather-grey', 'price': 73},
#    {'color': 'purple', 'price': 91},
#    {'color': 'yellow', 'price': 90},
#    {'color': 'slate', 'price': 71}],
#   'average': 85.875},
#  {'name': "Luden'sÂ® Tee",
#   'search': 'supreme-ludens-tee-black',
#   'colors': [{'color': 'purple', 'price': 66},
#    {'color': 'black', 'price': 64},
#    {'color': 'white', 'price': 58},
#    {'color': 'royal', 'price': 50},
#    {'color': 'clay', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'burgundy', 'price': 61},
#    {'color': 'yellow', 'price': 62}],
#   'average': 58.25},
#  {'name': 'Bombay Tee',
#   'search': 'supreme-Bombay-Tee-black',
#   'colors': [{'color': 'pale-blue', 'price': 55},
#    {'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 47},
#    {'color': 'light-purple', 'price': 50},
#    {'color': 'bright-yellow', 'price': 56}],
#   'average': 50.5},
#  {'name': 'Creeper Tee',
#   'search': 'supreme-Creeper-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 63},
#    {'color': 'red', 'price': 75},
#    {'color': 'white', 'price': 83},
#    {'color': 'black', 'price': 96},
#    {'color': 'woodland-camo', 'price': 63},
#    {'color': 'navy', 'price': 65},
#    {'color': 'light-blue', 'price': 81},
#    {'color': 'pale-yellow', 'price': 68}],
#   'average': 74.25},
#  {'name': 'Christopher Walken King Of New York Tee',
#   'search': 'supreme-king-of-new-york-tee-black',
#   'colors': [{'color': 'black', 'price': 92},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 61},
#    {'color': 'navy', 'price': 67},
#    {'color': 'light-blue', 'price': 67},
#    {'color': 'green', 'price': 51},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'pale-yellow', 'price': 61}],
#   'average': 63.77777777777778},
#  {'name': 'The Real Shit L/S Tee',
#   'search': 'supreme-the-real-shit-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 86},
#    {'color': 'navy', 'price': 84},
#    {'color': 'white', 'price': 88},
#    {'color': 'light-blue', 'price': 87},
#    {'color': 'heather-grey', 'price': 72},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'orange', 'price': 83},
#    {'color': 'green', 'price': 76}],
#   'average': 82.0},
#  {'name': 'Knot Tee',
#   'search': 'supreme-Knot-Tee-black',
#   'colors': [{'color': 'black', 'price': 54},
#    {'color': 'white', 'price': 54},
#    {'color': 'natural', 'price': 60},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'navy', 'price': 52},
#    {'color': 'neon-orange', 'price': 58},
#    {'color': 'green', 'price': 44}],
#   'average': 52.625},
#  {'name': 'Fruit Tee',
#   'search': 'supreme-Fruit-Tee-black',
#   'colors': [{'color': 'black', 'price': 66},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'navy', 'price': 54},
#    {'color': 'pale-yellow', 'price': 74},
#    {'color': 'light-blue', 'price': 61},
#    {'color': 'green', 'price': 61},
#    {'color': 'red', 'price': 66}],
#   'average': 62.375},
#  {'name': 'Kids Tee',
#   'search': 'supreme-Kids-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 74},
#    {'color': 'heather-grey', 'price': 58},
# ...
#   'average': 143.0},
#  {'name': 'SupremeÂ®/SwarovskiÂ® Box Logo Tee',
#   'search': 'supreme-swarovski-box-logo-tee-black',
#   'colors': [{'color': 'white', 'price': 753},
#    {'color': 'black', 'price': 719},
#    {'color': 'red', 'price': 560}],
#   'average': 677.3333333333334},
#  {'name': 'Buju Banton Tee',
#   'search': 'supreme-Buju-Banton-Tee-black',
#   'colors': [{'color': 'black', 'price': 134},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'red', 'price': 92},
#    {'color': 'clay', 'price': 98},
#    {'color': 'white', 'price': 110},
#    {'color': 'navy', 'price': 98},
#    {'color': 'light-blue', 'price': 97},
#    {'color': 'neon-orange', 'price': 95},
#    {'color': 'green', 'price': 94}],
#   'average': 100.88888888888889},
#  {'name': 'Dynamite Tee',
#   'search': 'supreme-Dynamite-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 65},
#    {'color': 'heather-grey', 'price': 62},
#    {'color': 'light-pink', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'light-blue', 'price': 82},
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664}]

# %%
len(full)
# Out:
# 184

# %%
    with open('data0-184.json', 'w') as outfile:
        json.dump(full, outfile)

# %%
all_averages = []
black = []
white = []

# %%
for p in full:
    try:
        all_averages.append(p['average'])
        for c in p['colors']:
            if c['color'] == 'black':
                black.append(c['price'])
            if c['color'] == 'white':
                white.append(c['price'])
    except (KeyError):
        print(p['name'])
# Out:
# SupremeÂ®/The North FaceÂ® Mountain Tee
# SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt
# SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee
# SupremeÂ®/The North FaceÂ® Photo Tee

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(all_averages)

# %%
len(all_averages)
# Out:
# 306

# %%
plt.plot(black, 'bo')
plt.plot(white, 'ro')
plt.plot(all_averages)
plt.figure(figsize=(50,20))

# %%
len(tees)
# Out:
# 184

# %%
for i in range(0,184):
    full[i]['date'] = tees[i]['week']

# %%
full
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208},
#    {'color': 'black', 'price': 246},
#    {'color': 'white', 'price': 212},
#    {'color': 'heather-grey', 'price': 172},
#    {'color': 'navy', 'price': 191},
#    {'color': 'lime-green', 'price': 218},
#    {'color': 'lt-pink', 'price': 196},
#    {'color': 'aqua', 'price': 189},
#    {'color': 'red', 'price': None}],
#   'average': 204.0,
#   'date': '2/16/2017'},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318},
#    {'color': 'grey', 'price': 121},
#    {'color': 'white', 'price': 233},
#    {'color': 'black', 'price': 315},
#    {'color': 'lt-green', 'price': 165},
#    {'color': 'mocha', 'price': 150},
#    {'color': 'aqua', 'price': 180},
#    {'color': 'red', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 211.71428571428572,
#   'date': '2/16/2017'},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107},
#    {'color': 'navy', 'price': 110},
#    {'color': 'black', 'price': 138},
#    {'color': 'red', 'price': 95},
#    {'color': 'bright-coral', 'price': 80},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'mocha', 'price': None}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '2/16/2017'},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61},
#    {'color': 'black', 'price': 127},
#    {'color': 'white', 'price': 146},
#    {'color': 'lt-teal', 'price': 90},
#    {'color': 'mocha', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'red', 'price': 115},
#    {'color': 'lt-pink', 'price': None}],
#   'average': 107.8,
#   'date': '2/16/2017'},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'bright-coral', 'price': 44},
#    {'color': 'navy', 'price': 70},
#    {'color': 'mocha', 'price': 46},
#    {'color': 'white', 'price': 66},
#    {'color': 'aqua', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 60.8,
#   'date': '2/16/2017'},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120},
#    {'color': 'red', 'price': 90},
#    {'color': 'white', 'price': 145},
#    {'color': 'navy', 'price': 83},
#    {'color': 'grey', 'price': 65},
#    {'color': 'mocha', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'aqua', 'price': 133}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '2/16/2017'},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137},
#    {'color': 'white', 'price': 137},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 137.0,
#   'date': '2/16/2017'},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 90},
#    {'color': 'heather-grey', 'price': 71},
#    {'color': 'pale-pink', 'price': 72},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 79.0,
#   'date': '2/16/2017'},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95},
#    {'color': 'white', 'price': 73},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'black', 'price': 60},
#    {'color': 'light-blue', 'price': 91},
#    {'color': 'navy', 'price': 50},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 76.5,
#   'date': '6/29/2017'},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84},
#    {'color': 'black', 'price': 76},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 66},
#    {'color': 'hot-pink', 'price': 50},
#    {'color': 'orange', 'price': 64},
#    {'color': 'light-blue', 'price': None},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'navy', 'price': 64}],
#   'average': 65.85714285714286,
#   'date': '6/29/2017'},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 55},
#    {'color': 'navy', 'price': 57},
#    {'color': 'red', 'price': 40},
#    {'color': 'teal', 'price': 55},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 57.0,
#   'date': '6/29/2017'},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'navy', 'price': 95},
#    {'color': 'white', 'price': 99},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'orange', 'price': None}],
#   'average': 98.33333333333333,
#   'date': '6/29/2017'},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 56},
#    {'color': 'teal', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 77.5,
#   'date': '6/29/2017'},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88},
#    {'color': 'heather-grey', 'price': 64},
#    {'color': 'white', 'price': 75},
#    {'color': 'navy', 'price': 66},
#    {'color': 'red', 'price': 53},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'dusty-pink', 'price': 60}],
#   'average': 67.66666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'black', 'price': 75},
#    {'color': 'lime', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'light-brown', 'price': None}],
#   'average': 64.75,
#   'date': '6/29/2017'},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76},
#    {'color': 'orange', 'price': 60},
#    {'color': 'black', 'price': 87},
#    {'color': 'red', 'price': 72},
#    {'color': 'dark-pink', 'price': 48},
#    {'color': 'teal', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'pale-yellow', 'price': 48}],
#   'average': 65.16666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238},
#    {'color': 'black', 'price': 297},
#    {'color': 'heather-grey', 'price': 224},
#    {'color': 'pale-blue', 'price': 224},
#    {'color': 'red', 'price': 226},
#    {'color': 'brown', 'price': 266},
#    {'color': 'lime', 'price': 201}],
#   'average': 239.42857142857142,
#   'date': '8/24/2017'},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175},
#    {'color': 'white', 'price': 162},
#    {'color': 'heather-grey', 'price': 110},
#    {'color': 'red', 'price': 123},
#    {'color': 'bright-orange', 'price': 93},
#    {'color': 'navy', 'price': 108},
#    {'color': 'royal', 'price': 208},
#    {'color': 'lime', 'price': 70},
#    {'color': 'brown', 'price': None}],
#   'average': 131.125,
#   'date': '8/24/2017'},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'red', 'price': 100},
#    {'color': 'white', 'price': 116},
#    {'color': 'heather-grey', 'price': 95},
#    {'color': 'navy', 'price': 89},
#    {'color': 'lime', 'price': 61},
#    {'color': 'bright-orange', 'price': 121},
#    {'color': 'brown', 'price': 80}],
#   'average': 101.875,
#   'date': '8/24/2017'},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'white', 'price': 82},
#    {'color': 'navy', 'price': 72},
#    {'color': 'light-pink', 'price': 63},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 75.5,
#   'date': '8/24/2017'},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 50},
#    {'color': 'brown', 'price': 100},
#    {'color': 'lime', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 83.0,
#   'date': '8/24/2017'},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58},
#    {'color': 'black', 'price': 113},
#    {'color': 'white', 'price': 122},
#    {'color': 'navy', 'price': 59},
#    {'color': 'lime', 'price': 60},
#    {'color': 'red', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 82.4,
#   'date': '8/24/2017'},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73},
#    {'color': 'black', 'price': 71},
#    {'color': 'white', 'price': 71},
#    {'color': 'red', 'price': 63},
#    {'color': 'brown', 'price': 60},
#    {'color': 'navy', 'price': 55},
#    {'color': 'light-pink', 'price': 55},
#    {'color': 'lime', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 64.0,
#   'date': '8/24/2017'},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '8/24/2017'},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 92},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'navy', 'price': 60},
#    {'color': 'royal', 'price': 75},
#    {'color': 'heather-grey', 'price': 75},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 73.0,
#   'date': '8/24/2017'},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'heather-grey', 'price': 79},
#    {'color': 'white', 'price': 95},
#    {'color': 'red', 'price': 79},
#    {'color': 'navy', 'price': 71},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'pale-blue', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 80.66666666666667,
#   'date': '9/21/2017'},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71},
#    {'color': 'black', 'price': 95},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 59},
#    {'color': 'brick', 'price': 70},
#    {'color': 'lime', 'price': 50},
#    {'color': 'pale-blue', 'price': 108},
#    {'color': 'navy', 'price': None}],
#   'average': 71.71428571428571,
#   'date': '9/21/2017'},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57},
#    {'color': 'black', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'pale-blue', 'price': 90},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'red', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 59.2,
#   'date': '9/21/2017'},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88}, {'color': 'black', 'price': 98}],
#   'average': 93.0,
#   'date': '9/21/2017'},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65}, {'color': 'white', 'price': 64}],
#   'average': 64.5,
#   'date': '9/21/2017'},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'heather-grey', 'price': 48},
#    {'color': 'lime', 'price': 50},
#    {'color': 'white', 'price': 50},
#    {'color': 'royal', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 48.75,
#   'date': '9/21/2017'},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266},
#    {'color': 'red', 'price': 221},
#    {'color': 'white', 'price': 233},
#    {'color': 'heather-grey', 'price': 200}],
#   'average': 230.0,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134},
#    {'color': 'black', 'price': 208},
#    {'color': 'white', 'price': 180},
#    {'color': 'red', 'price': 148}],
#   'average': 167.5,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 140},
#    {'color': 'red', 'price': 119}],
#   'average': 143.25,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144},
#    {'color': 'white', 'price': 120},
#    {'color': 'heather-grey', 'price': 108},
#    {'color': 'red', 'price': 125}],
#   'average': 124.25,
#   'date': '10/12/2017'},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253},
#    {'color': 'white', 'price': 273},
#    {'color': 'lime', 'price': 105},
#    {'color': 'cardinal', 'price': 132},
#    {'color': 'slate', 'price': 128}],
#   'average': 178.2,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230},
#    {'color': 'white', 'price': 190},
#    {'color': 'cardinal', 'price': 157},
#    {'color': 'slate', 'price': 153},
#    {'color': 'lime', 'price': 173}],
#   'average': 180.6,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 141},
#    {'color': 'slate', 'price': 120},
#    {'color': 'lime', 'price': 109}],
#   'average': 129.8,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150},
#    {'color': 'white', 'price': 116},
#    {'color': 'lime', 'price': 97},
#    {'color': 'slate', 'price': 127},
#    {'color': 'cardinal', 'price': 150}],
#   'average': 128.0,
#   'date': '11/2/2017'},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104},
#    {'color': 'black', 'price': 80},
#    {'color': 'dark-slate', 'price': 59},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': None},
#    {'color': 'olive-green', 'price': None}],
#   'average': 76.0,
#   'date': '11/16/2017'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': [],
#   'date': '11/30/2017'},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201},
#    {'color': 'white', 'price': 140},
#    {'color': 'heather-grey', 'price': 120},
#    {'color': 'lime', 'price': 110},
#    {'color': 'red', 'price': 150},
#    {'color': 'brown', 'price': 153},
#    {'color': 'dark-slate', 'price': 130},
#    {'color': 'bright-orange', 'price': 131}],
#   'average': 141.875,
#   'date': '12/14/2017'},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127},
#    {'color': 'navy', 'price': 121},
#    {'color': 'white', 'price': 104},
#    {'color': 'heather-grey', 'price': 105},
#    {'color': 'light-pink', 'price': 176},
#    {'color': 'mustard', 'price': 125},
#    {'color': 'red', 'price': 100},
#    {'color': 'brown', 'price': 70},
#    {'color': 'lime', 'price': 65}],
#   'average': 110.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133},
#    {'color': 'white', 'price': 127},
#    {'color': 'brick', 'price': 101},
#    {'color': 'green', 'price': 71},
#    {'color': 'light-purple', 'price': 105},
#    {'color': 'dark-slate', 'price': 85},
#    {'color': 'heather-grey', 'price': 50}],
#   'average': 96.0,
#   'date': '12/14/2017'},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93},
#    {'color': 'red', 'price': 69},
#    {'color': 'white', 'price': 89}],
#   'average': 83.66666666666667,
#   'date': '12/14/2017'},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'green', 'price': 63},
#    {'color': 'light-purple', 'price': 55},
#    {'color': 'navy', 'price': 50},
#    {'color': 'brick', 'price': None}],
#   'average': 78.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 39},
#    {'color': 'white', 'price': 51},
#    {'color': 'mustard', 'price': 44},
#    {'color': 'grey', 'price': 41},
#    {'color': 'light-purple', 'price': 65},
#    {'color': 'dark-slate', 'price': 54},
#    {'color': 'green', 'price': 54}],
#   'average': 52.625,
#   'date': '12/14/2017'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/15/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/15/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/15/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/15/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/15/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/15/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/15/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/15/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/15/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/15/2018'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/22/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/22/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/22/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/22/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/22/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/22/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/22/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/22/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/22/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/22/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89},
#    {'color': 'white', 'price': 86},
#    {'color': 'red', 'price': 69},
#    {'color': 'royal', 'price': 79}],
#   'average': 80.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 66}],
#   'average': 64.33333333333333,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 73},
#    {'color': 'royal', 'price': 81},
#    {'color': 'red', 'price': 66}],
#   'average': 76.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 74},
#    {'color': 'royal', 'price': 58}],
#   'average': 72.25,
#   'date': '3/15/2018'},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172},
#    {'color': 'white', 'price': 148},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'navy', 'price': 122},
#    {'color': 'red', 'price': 100},
#    {'color': 'light-purple', 'price': 143},
#    {'color': 'light-pink', 'price': 193},
#    {'color': 'pale-blue', 'price': 140},
#    {'color': 'bright-yellow', 'price': 130}],
#   'average': 138.66666666666666,
#   'date': '3/29/2018'},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129},
#    {'color': 'black', 'price': 125},
#    {'color': 'heather-grey', 'price': 78},
#    {'color': 'navy', 'price': 98},
#    {'color': 'pale-blue', 'price': 82},
#    {'color': 'green', 'price': 87},
#    {'color': 'red', 'price': 106},
#    {'color': 'bright-yellow', 'price': 61},
#    {'color': 'light-purple', 'price': 117}],
#   'average': 98.11111111111111,
#   'date': '3/29/2018'},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55},
#    {'color': 'black', 'price': 68},
#    {'color': 'white', 'price': 65},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 52},
#    {'color': 'bright-yellow', 'price': 58},
#    {'color': 'pale-blue', 'price': 73}],
#   'average': 60.5,
#   'date': '3/29/2018'},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'light-purple', 'price': 47},
#    {'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 53},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 66},
#    {'color': 'pale-blue', 'price': 54},
#    {'color': 'bright-yellow', 'price': 45},
#    {'color': 'green', 'price': 44}],
#   'average': 52.77777777777778,
#   'date': '3/29/2018'},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 53},
#    {'color': 'pale-blue', 'price': 65},
#    {'color': 'light-purple', 'price': 53},
#    {'color': 'bright-yellow', 'price': 43},
#    {'color': 'green', 'price': 45},
#    {'color': 'navy', 'price': 65}],
#   'average': 58.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'heather-grey', 'price': 70},
#    {'color': 'white', 'price': 79},
#    {'color': 'royal', 'price': 53},
#    {'color': 'red', 'price': 58},
#    {'color': 'pale-yellow', 'price': 20}],
#   'average': 59.666666666666664,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65},
#    {'color': 'red', 'price': 43},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 62.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62},
#    {'color': 'hot-pink', 'price': 35},
#    {'color': 'white', 'price': 52},
#    {'color': 'royal', 'price': 50},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 48.8,
#   'date': '3/29/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': [],
#   'date': '4/5/2018'},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98}, {'color': 'white', 'price': 90}],
#   'average': 94.0,
#   'date': '4/26/2018'},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'white', 'price': 81}],
#   'average': 91.0,
#   'date': '4/26/2018'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '5/31/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 81},
#    {'color': 'red', 'price': 71},
#    {'color': 'dark-green', 'price': 73},
#    {'color': 'light-purple', 'price': 84},
#    {'color': 'bright-orange', 'price': 68}],
#   'average': 74.0,
#   'date': '6/21/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'red', 'price': 58},
#    {'color': 'white', 'price': 84},
#    {'color': 'dark-green', 'price': 79},
#    {'color': 'bright-orange', 'price': 43},
#    {'color': 'light-purple', 'price': 75}],
#   'average': 67.14285714285714,
#   'date': '6/21/2018'},
#  {'name': 'Madonna Tee',
#   'search': 'supreme-Madonna-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 100},
#    {'color': 'black', 'price': 178},
#    {'color': 'dark-green', 'price': 102},
#    {'color': 'heather-grey', 'price': 109},
#    {'color': 'white', 'price': 167},
#    {'color': 'navy', 'price': 114},
#    {'color': 'red', 'price': 95},
#    {'color': 'pink', 'price': 97},
#    {'color': 'pale-yellow', 'price': 102}],
#   'average': 118.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Liquid Tee',
#   'search': 'supreme-Liquid-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 84},
#    {'color': 'navy', 'price': 76},
#    {'color': 'black', 'price': 94},
#    {'color': 'white', 'price': 88},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'burgundy', 'price': 71},
#    {'color': 'pink', 'price': 80},
#    {'color': 'natural', 'price': 76}],
#   'average': 79.5,
#   'date': '8/16/2018'},
#  {'name': 'Still Life Tee',
#   'search': 'supreme-Still-Life-Tee-black',
#   'colors': [{'color': 'red', 'price': 49},
#    {'color': 'bright-blue', 'price': 55},
#    {'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 62},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'pink', 'price': 87},
#    {'color': 'dark-green', 'price': 62}],
#   'average': 64.625,
#   'date': '8/16/2018'},
#  {'name': '1994 L/S Tee',
#   'search': 'supreme-1994-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'heather-grey', 'price': 88},
#    {'color': 'white', 'price': 102},
#    {'color': 'navy', 'price': 98},
#    {'color': 'natural', 'price': 101},
#    {'color': 'dark-green', 'price': 94},
#    {'color': 'burgundy', 'price': 83},
#    {'color': 'pink', 'price': 93},
#    {'color': 'red', 'price': 82}],
#   'average': 93.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Bottle Cap Tee',
#   'search': 'supreme-Bottle-Cap-Tee-black',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'white', 'price': 64},
#    {'color': 'red', 'price': 52},
#    {'color': 'bright-blue', 'price': 58},
#    {'color': 'navy', 'price': 63},
#    {'color': 'pale-yellow', 'price': 51},
#    {'color': 'pink', 'price': 62},
#    {'color': 'dark-green', 'price': 60}],
#   'average': 59.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Cutouts Tee',
#   'search': 'supreme-Cutouts-Tee-black',
#   'colors': [{'color': 'black', 'price': 75},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'bright-blue', 'price': 73},
#    {'color': 'pink', 'price': 56}],
#   'average': 60.75,
#   'date': '8/16/2018'},
#  {'name': 'Life Sucks Die Tee',
#   'search': 'supreme-Life-Sucks-Die-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 54},
#    {'color': 'black', 'price': 64},
#    {'color': 'red', 'price': 55},
#    {'color': 'natural', 'price': 66},
#    {'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 52},
#    {'color': 'dark-green', 'price': 77},
#    {'color': 'bright-blue', 'price': 48},
#    {'color': 'pink', 'price': 53}],
#   'average': 58.888888888888886,
#   'date': '8/16/2018'},
#  {'name': 'Bedroom Tee',
#   'search': 'supreme-Bedroom-Tee-black',
#   'colors': [{'color': 'navy', 'price': 59},
#    {'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 64},
#    {'color': 'light-pink', 'price': 80},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-green', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'natural', 'price': 70},
#    {'color': 'bright-blue', 'price': 51},
#    {'color': 'pink', 'price': 77}],
#   'average': 62.3,
#   'date': '8/16/2018'},
#  {'name': 'Fuck You Tee',
#   'search': 'supreme-Fuck-You-Tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'bright-blue', 'price': 53},
#    {'color': 'dark-green', 'price': 56},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 57},
#    {'color': 'orange', 'price': 62},
#    {'color': 'red', 'price': 58}],
#   'average': 59.5,
#   'date': '8/16/2018'},
#  {'name': 'Guts Tee',
#   'search': 'supreme-Guts-Tee-black',
#   'colors': [{'color': 'white', 'price': 57},
#    {'color': 'red', 'price': 47},
#    {'color': 'natural', 'price': 51},
#    {'color': 'black', 'price': 56},
#    {'color': 'navy', 'price': 51},
#    {'color': 'ash-grey', 'price': 50},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'bright-blue', 'price': 63},
#    {'color': 'pink', 'price': 56}],
#   'average': 54.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Mike Kelley/Supreme The Empire State Building Tee',
#   'search': 'supreme-mike-kelley-supreme-the-empire-state-building-tee-black',
#   'colors': [{'color': 'white', 'price': 66},
#    {'color': 'burgundy', 'price': 47},
#    {'color': 'ash-grey', 'price': 49},
#    {'color': 'black', 'price': 70},
#    {'color': 'dark-green', 'price': 49},
#    {'color': 'slate', 'price': 49},
#    {'color': 'clay', 'price': 51},
#    {'color': 'bright-orange', 'price': 51}],
#   'average': 54.0,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 77},
#    {'color': 'slate', 'price': 73},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'clay', 'price': 77},
#    {'color': 'black', 'price': 126},
#    {'color': 'white', 'price': 108},
#    {'color': 'dark-green', 'price': 84},
#    {'color': 'bright-orange', 'price': 94}],
#   'average': 89.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! L/S Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 166},
#    {'color': 'white', 'price': 134},
#    {'color': 'clay', 'price': 95},
#    {'color': 'ash-grey', 'price': 103},
#    {'color': 'slate', 'price': 93},
#    {'color': 'dark-green', 'price': 103},
#    {'color': 'burgundy', 'price': 104},
#    {'color': 'bright-orange', 'price': 105}],
#   'average': 112.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Hiding From Indians Tee',
#   'search': 'supreme-mike-kelley-supreme-hiding-from-indians-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 46},
#    {'color': 'black', 'price': 59},
#    {'color': 'clay', 'price': 55},
#    {'color': 'white', 'price': 58},
#    {'color': 'burgundy', 'price': 48},
#    {'color': 'bright-orange', 'price': 59},
#    {'color': 'dark-green', 'price': 61},
#    {'color': 'slate', 'price': 57}],
#   'average': 55.375,
#   'date': '9/6/2018'},
#  {'name': 'SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee',
#   'search': 'supreme-comme-des-garcons-shirt-split-box-logo-tee-black',
#   'colors': [],
#   'date': '9/13/2018'},
#  {'name': 'Group Tee',
#   'search': 'supreme-Group-Tee-black',
#   'colors': [{'color': 'slate', 'price': 65},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 82},
#    {'color': 'red', 'price': 76},
#    {'color': 'dark-pink', 'price': 76},
#    {'color': 'bright-orange', 'price': 68},
#    {'color': 'navy', 'price': 75},
#    {'color': 'dark-green', 'price': 72}],
#   'average': 74.0,
#   'date': '9/20/2018'},
#  {'name': 'Remember Tee',
#   'search': 'supreme-Remember-Tee-black',
#   'colors': [{'color': 'black', 'price': 81},
#    {'color': 'dark-pink', 'price': 63},
#    {'color': 'white', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'heather-grey', 'price': 74},
#    {'color': 'red', 'price': 68},
#    {'color': 'slate', 'price': 74},
#    {'color': 'bright-orange', 'price': 66}],
#   'average': 72.5,
#   'date': '9/20/2018'},
#  {'name': 'Liquid Swords Tee',
#   'search': 'supreme-Liquid-Swords-Tee-black',
#   'colors': [{'color': 'dark-green', 'price': 89},
#    {'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 81},
#    {'color': 'heather-grey', 'price': 81},
#    {'color': 'navy', 'price': 94},
#    {'color': 'slate', 'price': 96},
#    {'color': 'red', 'price': 80},
#    {'color': 'bright-orange', 'price': 85}],
#   'average': 88.125,
#   'date': '9/20/2018'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '9/20/2018'},
#  {'name': 'Payphone Tee',
#   'search': 'supreme-Payphone-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 52},
#    {'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 57},
#    {'color': 'natural', 'price': 53},
#    {'color': 'red', 'price': 48},
#    {'color': 'bright-orange', 'price': 48},
#    {'color': 'dark-pink', 'price': 47},
#    {'color': 'navy', 'price': 56},
#    {'color': 'slate', 'price': 61}],
#   'average': 53.0,
#   'date': '9/20/2018'},
#  {'name': 'Faces Tee',
#   'search': 'supreme-Faces-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'slate', 'price': 55},
#    {'color': 'dark-pink', 'price': 49},
#    {'color': 'bright-orange', 'price': 39},
#    {'color': 'navy', 'price': 59},
#    {'color': 'red', 'price': 51}],
#   'average': 51.625,
#   'date': '9/20/2018'},
#  {'name': 'System Tee',
#   'search': 'supreme-System-Tee-black',
#   'colors': [{'color': 'black', 'price': 45},
#    {'color': 'ash-grey', 'price': 40},
#    {'color': 'white', 'price': 49},
#    {'color': 'navy', 'price': 45},
#    {'color': 'dark-pink', 'price': 40},
#    {'color': 'slate', 'price': 44},
#    {'color': 'bright-orange', 'price': 42},
#    {'color': 'burgundy', 'price': 41}],
#   'average': 43.25,
#   'date': '9/20/2018'},
#  {'name': 'The Killer Trust Tee',
#   'search': 'supreme-The-Killer-Trust-Tee-black',
#   'colors': [{'color': 'black', 'price': 238},
#    {'color': 'olive', 'price': 147},
#    {'color': 'white', 'price': 183},
#    {'color': 'heather-grey', 'price': 142},
#    {'color': 'red', 'price': 123},
#    {'color': 'navy', 'price': 191},
#    {'color': 'pale-yellow', 'price': 131}],
#   'average': 165.0,
#   'date': '10/25/2018'},
#  {'name': 'Chris Cunningham Chihuahua Tee',
#   'search': 'supreme-Chris-Cunningham-Chihuahua-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'white', 'price': 58},
#    {'color': 'pale-mint', 'price': 57},
#    {'color': 'taupe', 'price': 55},
#    {'color': 'red', 'price': 55}],
#   'average': 59.6,
#   'date': '11/8/2018'},
#  {'name': 'Chris Cunningham Rubber Johnny Tee',
#   'search': 'supreme-Chris-Cunningham-Rubber-Johnny-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'pale-mint', 'price': 53},
#    {'color': 'taupe', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'red', 'price': 43}],
#   'average': 50.2,
#   'date': '11/8/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Photo Tee',
#   'search': 'supreme-the-north-face-photo-tee-black',
#   'colors': [],
#   'date': '11/29/2018'},
#  {'name': 'Cat in the Hat Tee',
#   'search': 'supreme-Cat-in-the-Hat-Tee-black',
#   'colors': [{'color': 'black', 'price': 107},
#    {'color': 'white', 'price': 97},
#    {'color': 'purple', 'price': 95},
#    {'color': 'red', 'price': 85},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 88},
#    {'color': 'yellow', 'price': 69},
#    {'color': 'olive', 'price': 76}],
#   'average': 88.25,
#   'date': '12/13/2018'},
#  {'name': 'Marvin Gaye Tee',
#   'search': 'supreme-Marvin-Gaye-Tee-black',
#   'colors': [{'color': 'white', 'price': 60},
#    {'color': 'black', 'price': 64},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'clay', 'price': 61},
#    {'color': 'navy', 'price': 55},
#    {'color': 'red', 'price': 61},
#    {'color': 'purple', 'price': 66},
#    {'color': 'yellow', 'price': 54}],
#   'average': 59.125,
#   'date': '12/13/2018'},
#  {'name': 'Smile Tee',
#   'search': 'supreme-Smile-Tee-black',
#   'colors': [{'color': 'black', 'price': 104},
#    {'color': 'white', 'price': 90},
#    {'color': 'red', 'price': 88},
#    {'color': 'clay', 'price': 80},
#    {'color': 'heather-grey', 'price': 73},
#    {'color': 'purple', 'price': 91},
#    {'color': 'yellow', 'price': 90},
#    {'color': 'slate', 'price': 71}],
#   'average': 85.875,
#   'date': '12/13/2018'},
#  {'name': "Luden'sÂ® Tee",
#   'search': 'supreme-ludens-tee-black',
#   'colors': [{'color': 'purple', 'price': 66},
#    {'color': 'black', 'price': 64},
#    {'color': 'white', 'price': 58},
#    {'color': 'royal', 'price': 50},
#    {'color': 'clay', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'burgundy', 'price': 61},
#    {'color': 'yellow', 'price': 62}],
#   'average': 58.25,
#   'date': '12/13/2018'},
#  {'name': 'Bombay Tee',
# ...
#    {'color': 'light-pink', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'light-blue', 'price': 82},
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5,
#   'date': '6/27/2019'},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444,
#   'date': '6/27/2019'},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75,
#   'date': '6/27/2019'},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75,
#   'date': '6/27/2019'},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375,
#   'date': '6/27/2019'},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25,
#   'date': '6/27/2019'},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75,
#   'date': '6/27/2019'},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375,
#   'date': '6/27/2019'},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875,
#   'date': '8/22/2019'},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857,
#   'date': '8/22/2019'},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5,
#   'date': '8/22/2019'},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285,
#   'date': '8/22/2019'},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0,
#   'date': '8/22/2019'},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0,
#   'date': '8/22/2019'},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125,
#   'date': '8/22/2019'},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854,
#   'date': '8/22/2019'},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5,
#   'date': '8/22/2019'},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143,
#   'date': '8/22/2019'},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2,
#   'date': '9/19/2019'},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429,
#   'date': '10/10/2019'},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375,
#   'date': '10/10/2019'},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25,
#   'date': '10/10/2019'},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285,
#   'date': '10/10/2019'},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125,
#   'date': '10/10/2019'},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146,
#   'date': '10/10/2019'},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5,
#   'date': '10/10/2019'},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875,
#   'date': '10/10/2019'},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336,
#   'date': '10/10/2019'},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0,
#   'date': '10/24/2019'},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6,
#   'date': '12/5/2019'},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4,
#   'date': '12/5/2019'},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25,
#   'date': '12/19/2019'},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854,
#   'date': '12/19/2019'},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285,
#   'date': '12/19/2019'},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0,
#   'date': '12/19/2019'},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875,
#   'date': '12/19/2019'},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0,
#   'date': '12/19/2019'},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5,
#   'date': '12/19/2019'},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664,
#   'date': '12/19/2019'}]

# %%
import datetime
d = ['09/01/2012', '04/05/2007', '11/18/2012']
sorted(d, key=lambda x: datetime.datetime.strptime(x, '%m/%d/%Y'))
# Out:
# ['04/05/2007', '09/01/2012', '11/18/2012']

# %%
# Sort data
sorted(full, key=lambda x: datetime.datetime.strptime(x['date'], '%m/%d/%Y'))
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208},
#    {'color': 'black', 'price': 246},
#    {'color': 'white', 'price': 212},
#    {'color': 'heather-grey', 'price': 172},
#    {'color': 'navy', 'price': 191},
#    {'color': 'lime-green', 'price': 218},
#    {'color': 'lt-pink', 'price': 196},
#    {'color': 'aqua', 'price': 189},
#    {'color': 'red', 'price': None}],
#   'average': 204.0,
#   'date': '2/16/2017'},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318},
#    {'color': 'grey', 'price': 121},
#    {'color': 'white', 'price': 233},
#    {'color': 'black', 'price': 315},
#    {'color': 'lt-green', 'price': 165},
#    {'color': 'mocha', 'price': 150},
#    {'color': 'aqua', 'price': 180},
#    {'color': 'red', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 211.71428571428572,
#   'date': '2/16/2017'},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107},
#    {'color': 'navy', 'price': 110},
#    {'color': 'black', 'price': 138},
#    {'color': 'red', 'price': 95},
#    {'color': 'bright-coral', 'price': 80},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'mocha', 'price': None}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '2/16/2017'},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61},
#    {'color': 'black', 'price': 127},
#    {'color': 'white', 'price': 146},
#    {'color': 'lt-teal', 'price': 90},
#    {'color': 'mocha', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'red', 'price': 115},
#    {'color': 'lt-pink', 'price': None}],
#   'average': 107.8,
#   'date': '2/16/2017'},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'bright-coral', 'price': 44},
#    {'color': 'navy', 'price': 70},
#    {'color': 'mocha', 'price': 46},
#    {'color': 'white', 'price': 66},
#    {'color': 'aqua', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 60.8,
#   'date': '2/16/2017'},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120},
#    {'color': 'red', 'price': 90},
#    {'color': 'white', 'price': 145},
#    {'color': 'navy', 'price': 83},
#    {'color': 'grey', 'price': 65},
#    {'color': 'mocha', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'aqua', 'price': 133}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '2/16/2017'},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137},
#    {'color': 'white', 'price': 137},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 137.0,
#   'date': '2/16/2017'},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 90},
#    {'color': 'heather-grey', 'price': 71},
#    {'color': 'pale-pink', 'price': 72},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 79.0,
#   'date': '2/16/2017'},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95},
#    {'color': 'white', 'price': 73},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'black', 'price': 60},
#    {'color': 'light-blue', 'price': 91},
#    {'color': 'navy', 'price': 50},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 76.5,
#   'date': '6/29/2017'},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84},
#    {'color': 'black', 'price': 76},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 66},
#    {'color': 'hot-pink', 'price': 50},
#    {'color': 'orange', 'price': 64},
#    {'color': 'light-blue', 'price': None},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'navy', 'price': 64}],
#   'average': 65.85714285714286,
#   'date': '6/29/2017'},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 55},
#    {'color': 'navy', 'price': 57},
#    {'color': 'red', 'price': 40},
#    {'color': 'teal', 'price': 55},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 57.0,
#   'date': '6/29/2017'},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'navy', 'price': 95},
#    {'color': 'white', 'price': 99},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'orange', 'price': None}],
#   'average': 98.33333333333333,
#   'date': '6/29/2017'},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 56},
#    {'color': 'teal', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 77.5,
#   'date': '6/29/2017'},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88},
#    {'color': 'heather-grey', 'price': 64},
#    {'color': 'white', 'price': 75},
#    {'color': 'navy', 'price': 66},
#    {'color': 'red', 'price': 53},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'dusty-pink', 'price': 60}],
#   'average': 67.66666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'black', 'price': 75},
#    {'color': 'lime', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'light-brown', 'price': None}],
#   'average': 64.75,
#   'date': '6/29/2017'},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76},
#    {'color': 'orange', 'price': 60},
#    {'color': 'black', 'price': 87},
#    {'color': 'red', 'price': 72},
#    {'color': 'dark-pink', 'price': 48},
#    {'color': 'teal', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'pale-yellow', 'price': 48}],
#   'average': 65.16666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238},
#    {'color': 'black', 'price': 297},
#    {'color': 'heather-grey', 'price': 224},
#    {'color': 'pale-blue', 'price': 224},
#    {'color': 'red', 'price': 226},
#    {'color': 'brown', 'price': 266},
#    {'color': 'lime', 'price': 201}],
#   'average': 239.42857142857142,
#   'date': '8/24/2017'},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175},
#    {'color': 'white', 'price': 162},
#    {'color': 'heather-grey', 'price': 110},
#    {'color': 'red', 'price': 123},
#    {'color': 'bright-orange', 'price': 93},
#    {'color': 'navy', 'price': 108},
#    {'color': 'royal', 'price': 208},
#    {'color': 'lime', 'price': 70},
#    {'color': 'brown', 'price': None}],
#   'average': 131.125,
#   'date': '8/24/2017'},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'red', 'price': 100},
#    {'color': 'white', 'price': 116},
#    {'color': 'heather-grey', 'price': 95},
#    {'color': 'navy', 'price': 89},
#    {'color': 'lime', 'price': 61},
#    {'color': 'bright-orange', 'price': 121},
#    {'color': 'brown', 'price': 80}],
#   'average': 101.875,
#   'date': '8/24/2017'},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'white', 'price': 82},
#    {'color': 'navy', 'price': 72},
#    {'color': 'light-pink', 'price': 63},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 75.5,
#   'date': '8/24/2017'},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 50},
#    {'color': 'brown', 'price': 100},
#    {'color': 'lime', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 83.0,
#   'date': '8/24/2017'},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58},
#    {'color': 'black', 'price': 113},
#    {'color': 'white', 'price': 122},
#    {'color': 'navy', 'price': 59},
#    {'color': 'lime', 'price': 60},
#    {'color': 'red', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 82.4,
#   'date': '8/24/2017'},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73},
#    {'color': 'black', 'price': 71},
#    {'color': 'white', 'price': 71},
#    {'color': 'red', 'price': 63},
#    {'color': 'brown', 'price': 60},
#    {'color': 'navy', 'price': 55},
#    {'color': 'light-pink', 'price': 55},
#    {'color': 'lime', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 64.0,
#   'date': '8/24/2017'},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '8/24/2017'},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 92},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'navy', 'price': 60},
#    {'color': 'royal', 'price': 75},
#    {'color': 'heather-grey', 'price': 75},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 73.0,
#   'date': '8/24/2017'},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'heather-grey', 'price': 79},
#    {'color': 'white', 'price': 95},
#    {'color': 'red', 'price': 79},
#    {'color': 'navy', 'price': 71},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'pale-blue', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 80.66666666666667,
#   'date': '9/21/2017'},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71},
#    {'color': 'black', 'price': 95},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 59},
#    {'color': 'brick', 'price': 70},
#    {'color': 'lime', 'price': 50},
#    {'color': 'pale-blue', 'price': 108},
#    {'color': 'navy', 'price': None}],
#   'average': 71.71428571428571,
#   'date': '9/21/2017'},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57},
#    {'color': 'black', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'pale-blue', 'price': 90},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'red', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 59.2,
#   'date': '9/21/2017'},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88}, {'color': 'black', 'price': 98}],
#   'average': 93.0,
#   'date': '9/21/2017'},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65}, {'color': 'white', 'price': 64}],
#   'average': 64.5,
#   'date': '9/21/2017'},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'heather-grey', 'price': 48},
#    {'color': 'lime', 'price': 50},
#    {'color': 'white', 'price': 50},
#    {'color': 'royal', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 48.75,
#   'date': '9/21/2017'},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266},
#    {'color': 'red', 'price': 221},
#    {'color': 'white', 'price': 233},
#    {'color': 'heather-grey', 'price': 200}],
#   'average': 230.0,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134},
#    {'color': 'black', 'price': 208},
#    {'color': 'white', 'price': 180},
#    {'color': 'red', 'price': 148}],
#   'average': 167.5,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 140},
#    {'color': 'red', 'price': 119}],
#   'average': 143.25,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144},
#    {'color': 'white', 'price': 120},
#    {'color': 'heather-grey', 'price': 108},
#    {'color': 'red', 'price': 125}],
#   'average': 124.25,
#   'date': '10/12/2017'},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253},
#    {'color': 'white', 'price': 273},
#    {'color': 'lime', 'price': 105},
#    {'color': 'cardinal', 'price': 132},
#    {'color': 'slate', 'price': 128}],
#   'average': 178.2,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230},
#    {'color': 'white', 'price': 190},
#    {'color': 'cardinal', 'price': 157},
#    {'color': 'slate', 'price': 153},
#    {'color': 'lime', 'price': 173}],
#   'average': 180.6,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 141},
#    {'color': 'slate', 'price': 120},
#    {'color': 'lime', 'price': 109}],
#   'average': 129.8,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150},
#    {'color': 'white', 'price': 116},
#    {'color': 'lime', 'price': 97},
#    {'color': 'slate', 'price': 127},
#    {'color': 'cardinal', 'price': 150}],
#   'average': 128.0,
#   'date': '11/2/2017'},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104},
#    {'color': 'black', 'price': 80},
#    {'color': 'dark-slate', 'price': 59},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': None},
#    {'color': 'olive-green', 'price': None}],
#   'average': 76.0,
#   'date': '11/16/2017'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': [],
#   'date': '11/30/2017'},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201},
#    {'color': 'white', 'price': 140},
#    {'color': 'heather-grey', 'price': 120},
#    {'color': 'lime', 'price': 110},
#    {'color': 'red', 'price': 150},
#    {'color': 'brown', 'price': 153},
#    {'color': 'dark-slate', 'price': 130},
#    {'color': 'bright-orange', 'price': 131}],
#   'average': 141.875,
#   'date': '12/14/2017'},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127},
#    {'color': 'navy', 'price': 121},
#    {'color': 'white', 'price': 104},
#    {'color': 'heather-grey', 'price': 105},
#    {'color': 'light-pink', 'price': 176},
#    {'color': 'mustard', 'price': 125},
#    {'color': 'red', 'price': 100},
#    {'color': 'brown', 'price': 70},
#    {'color': 'lime', 'price': 65}],
#   'average': 110.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133},
#    {'color': 'white', 'price': 127},
#    {'color': 'brick', 'price': 101},
#    {'color': 'green', 'price': 71},
#    {'color': 'light-purple', 'price': 105},
#    {'color': 'dark-slate', 'price': 85},
#    {'color': 'heather-grey', 'price': 50}],
#   'average': 96.0,
#   'date': '12/14/2017'},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93},
#    {'color': 'red', 'price': 69},
#    {'color': 'white', 'price': 89}],
#   'average': 83.66666666666667,
#   'date': '12/14/2017'},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'green', 'price': 63},
#    {'color': 'light-purple', 'price': 55},
#    {'color': 'navy', 'price': 50},
#    {'color': 'brick', 'price': None}],
#   'average': 78.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 39},
#    {'color': 'white', 'price': 51},
#    {'color': 'mustard', 'price': 44},
#    {'color': 'grey', 'price': 41},
#    {'color': 'light-purple', 'price': 65},
#    {'color': 'dark-slate', 'price': 54},
#    {'color': 'green', 'price': 54}],
#   'average': 52.625,
#   'date': '12/14/2017'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/15/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/15/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/15/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/15/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/15/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/15/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/15/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/15/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/15/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/15/2018'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/22/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/22/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/22/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/22/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/22/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/22/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/22/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/22/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/22/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/22/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89},
#    {'color': 'white', 'price': 86},
#    {'color': 'red', 'price': 69},
#    {'color': 'royal', 'price': 79}],
#   'average': 80.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 66}],
#   'average': 64.33333333333333,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 73},
#    {'color': 'royal', 'price': 81},
#    {'color': 'red', 'price': 66}],
#   'average': 76.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 74},
#    {'color': 'royal', 'price': 58}],
#   'average': 72.25,
#   'date': '3/15/2018'},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172},
#    {'color': 'white', 'price': 148},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'navy', 'price': 122},
#    {'color': 'red', 'price': 100},
#    {'color': 'light-purple', 'price': 143},
#    {'color': 'light-pink', 'price': 193},
#    {'color': 'pale-blue', 'price': 140},
#    {'color': 'bright-yellow', 'price': 130}],
#   'average': 138.66666666666666,
#   'date': '3/29/2018'},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129},
#    {'color': 'black', 'price': 125},
#    {'color': 'heather-grey', 'price': 78},
#    {'color': 'navy', 'price': 98},
#    {'color': 'pale-blue', 'price': 82},
#    {'color': 'green', 'price': 87},
#    {'color': 'red', 'price': 106},
#    {'color': 'bright-yellow', 'price': 61},
#    {'color': 'light-purple', 'price': 117}],
#   'average': 98.11111111111111,
#   'date': '3/29/2018'},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55},
#    {'color': 'black', 'price': 68},
#    {'color': 'white', 'price': 65},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 52},
#    {'color': 'bright-yellow', 'price': 58},
#    {'color': 'pale-blue', 'price': 73}],
#   'average': 60.5,
#   'date': '3/29/2018'},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'light-purple', 'price': 47},
#    {'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 53},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 66},
#    {'color': 'pale-blue', 'price': 54},
#    {'color': 'bright-yellow', 'price': 45},
#    {'color': 'green', 'price': 44}],
#   'average': 52.77777777777778,
#   'date': '3/29/2018'},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 53},
#    {'color': 'pale-blue', 'price': 65},
#    {'color': 'light-purple', 'price': 53},
#    {'color': 'bright-yellow', 'price': 43},
#    {'color': 'green', 'price': 45},
#    {'color': 'navy', 'price': 65}],
#   'average': 58.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'heather-grey', 'price': 70},
#    {'color': 'white', 'price': 79},
#    {'color': 'royal', 'price': 53},
#    {'color': 'red', 'price': 58},
#    {'color': 'pale-yellow', 'price': 20}],
#   'average': 59.666666666666664,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65},
#    {'color': 'red', 'price': 43},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 62.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62},
#    {'color': 'hot-pink', 'price': 35},
#    {'color': 'white', 'price': 52},
#    {'color': 'royal', 'price': 50},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 48.8,
#   'date': '3/29/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': [],
#   'date': '4/5/2018'},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98}, {'color': 'white', 'price': 90}],
#   'average': 94.0,
#   'date': '4/26/2018'},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'white', 'price': 81}],
#   'average': 91.0,
#   'date': '4/26/2018'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '5/31/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 81},
#    {'color': 'red', 'price': 71},
#    {'color': 'dark-green', 'price': 73},
#    {'color': 'light-purple', 'price': 84},
#    {'color': 'bright-orange', 'price': 68}],
#   'average': 74.0,
#   'date': '6/21/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'red', 'price': 58},
#    {'color': 'white', 'price': 84},
#    {'color': 'dark-green', 'price': 79},
#    {'color': 'bright-orange', 'price': 43},
#    {'color': 'light-purple', 'price': 75}],
#   'average': 67.14285714285714,
#   'date': '6/21/2018'},
#  {'name': 'Madonna Tee',
#   'search': 'supreme-Madonna-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 100},
#    {'color': 'black', 'price': 178},
#    {'color': 'dark-green', 'price': 102},
#    {'color': 'heather-grey', 'price': 109},
#    {'color': 'white', 'price': 167},
#    {'color': 'navy', 'price': 114},
#    {'color': 'red', 'price': 95},
#    {'color': 'pink', 'price': 97},
#    {'color': 'pale-yellow', 'price': 102}],
#   'average': 118.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Liquid Tee',
#   'search': 'supreme-Liquid-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 84},
#    {'color': 'navy', 'price': 76},
#    {'color': 'black', 'price': 94},
#    {'color': 'white', 'price': 88},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'burgundy', 'price': 71},
#    {'color': 'pink', 'price': 80},
#    {'color': 'natural', 'price': 76}],
#   'average': 79.5,
#   'date': '8/16/2018'},
#  {'name': 'Still Life Tee',
#   'search': 'supreme-Still-Life-Tee-black',
#   'colors': [{'color': 'red', 'price': 49},
#    {'color': 'bright-blue', 'price': 55},
#    {'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 62},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'pink', 'price': 87},
#    {'color': 'dark-green', 'price': 62}],
#   'average': 64.625,
#   'date': '8/16/2018'},
#  {'name': '1994 L/S Tee',
#   'search': 'supreme-1994-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'heather-grey', 'price': 88},
#    {'color': 'white', 'price': 102},
#    {'color': 'navy', 'price': 98},
#    {'color': 'natural', 'price': 101},
#    {'color': 'dark-green', 'price': 94},
#    {'color': 'burgundy', 'price': 83},
#    {'color': 'pink', 'price': 93},
#    {'color': 'red', 'price': 82}],
#   'average': 93.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Bottle Cap Tee',
#   'search': 'supreme-Bottle-Cap-Tee-black',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'white', 'price': 64},
#    {'color': 'red', 'price': 52},
#    {'color': 'bright-blue', 'price': 58},
#    {'color': 'navy', 'price': 63},
#    {'color': 'pale-yellow', 'price': 51},
#    {'color': 'pink', 'price': 62},
#    {'color': 'dark-green', 'price': 60}],
#   'average': 59.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Cutouts Tee',
#   'search': 'supreme-Cutouts-Tee-black',
#   'colors': [{'color': 'black', 'price': 75},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'bright-blue', 'price': 73},
#    {'color': 'pink', 'price': 56}],
#   'average': 60.75,
#   'date': '8/16/2018'},
#  {'name': 'Life Sucks Die Tee',
#   'search': 'supreme-Life-Sucks-Die-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 54},
#    {'color': 'black', 'price': 64},
#    {'color': 'red', 'price': 55},
#    {'color': 'natural', 'price': 66},
#    {'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 52},
#    {'color': 'dark-green', 'price': 77},
#    {'color': 'bright-blue', 'price': 48},
#    {'color': 'pink', 'price': 53}],
#   'average': 58.888888888888886,
#   'date': '8/16/2018'},
#  {'name': 'Bedroom Tee',
#   'search': 'supreme-Bedroom-Tee-black',
#   'colors': [{'color': 'navy', 'price': 59},
#    {'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 64},
#    {'color': 'light-pink', 'price': 80},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-green', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'natural', 'price': 70},
#    {'color': 'bright-blue', 'price': 51},
#    {'color': 'pink', 'price': 77}],
#   'average': 62.3,
#   'date': '8/16/2018'},
#  {'name': 'Fuck You Tee',
#   'search': 'supreme-Fuck-You-Tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'bright-blue', 'price': 53},
#    {'color': 'dark-green', 'price': 56},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 57},
#    {'color': 'orange', 'price': 62},
#    {'color': 'red', 'price': 58}],
#   'average': 59.5,
#   'date': '8/16/2018'},
#  {'name': 'Guts Tee',
#   'search': 'supreme-Guts-Tee-black',
#   'colors': [{'color': 'white', 'price': 57},
#    {'color': 'red', 'price': 47},
#    {'color': 'natural', 'price': 51},
#    {'color': 'black', 'price': 56},
#    {'color': 'navy', 'price': 51},
#    {'color': 'ash-grey', 'price': 50},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'bright-blue', 'price': 63},
#    {'color': 'pink', 'price': 56}],
#   'average': 54.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Mike Kelley/Supreme The Empire State Building Tee',
#   'search': 'supreme-mike-kelley-supreme-the-empire-state-building-tee-black',
#   'colors': [{'color': 'white', 'price': 66},
#    {'color': 'burgundy', 'price': 47},
#    {'color': 'ash-grey', 'price': 49},
#    {'color': 'black', 'price': 70},
#    {'color': 'dark-green', 'price': 49},
#    {'color': 'slate', 'price': 49},
#    {'color': 'clay', 'price': 51},
#    {'color': 'bright-orange', 'price': 51}],
#   'average': 54.0,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 77},
#    {'color': 'slate', 'price': 73},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'clay', 'price': 77},
#    {'color': 'black', 'price': 126},
#    {'color': 'white', 'price': 108},
#    {'color': 'dark-green', 'price': 84},
#    {'color': 'bright-orange', 'price': 94}],
#   'average': 89.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! L/S Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 166},
#    {'color': 'white', 'price': 134},
#    {'color': 'clay', 'price': 95},
#    {'color': 'ash-grey', 'price': 103},
#    {'color': 'slate', 'price': 93},
#    {'color': 'dark-green', 'price': 103},
#    {'color': 'burgundy', 'price': 104},
#    {'color': 'bright-orange', 'price': 105}],
#   'average': 112.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Hiding From Indians Tee',
#   'search': 'supreme-mike-kelley-supreme-hiding-from-indians-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 46},
#    {'color': 'black', 'price': 59},
#    {'color': 'clay', 'price': 55},
#    {'color': 'white', 'price': 58},
#    {'color': 'burgundy', 'price': 48},
#    {'color': 'bright-orange', 'price': 59},
#    {'color': 'dark-green', 'price': 61},
#    {'color': 'slate', 'price': 57}],
#   'average': 55.375,
#   'date': '9/6/2018'},
#  {'name': 'SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee',
#   'search': 'supreme-comme-des-garcons-shirt-split-box-logo-tee-black',
#   'colors': [],
#   'date': '9/13/2018'},
#  {'name': 'Group Tee',
#   'search': 'supreme-Group-Tee-black',
#   'colors': [{'color': 'slate', 'price': 65},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 82},
#    {'color': 'red', 'price': 76},
#    {'color': 'dark-pink', 'price': 76},
#    {'color': 'bright-orange', 'price': 68},
#    {'color': 'navy', 'price': 75},
#    {'color': 'dark-green', 'price': 72}],
#   'average': 74.0,
#   'date': '9/20/2018'},
#  {'name': 'Remember Tee',
#   'search': 'supreme-Remember-Tee-black',
#   'colors': [{'color': 'black', 'price': 81},
#    {'color': 'dark-pink', 'price': 63},
#    {'color': 'white', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'heather-grey', 'price': 74},
#    {'color': 'red', 'price': 68},
#    {'color': 'slate', 'price': 74},
#    {'color': 'bright-orange', 'price': 66}],
#   'average': 72.5,
#   'date': '9/20/2018'},
#  {'name': 'Liquid Swords Tee',
#   'search': 'supreme-Liquid-Swords-Tee-black',
#   'colors': [{'color': 'dark-green', 'price': 89},
#    {'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 81},
#    {'color': 'heather-grey', 'price': 81},
#    {'color': 'navy', 'price': 94},
#    {'color': 'slate', 'price': 96},
#    {'color': 'red', 'price': 80},
#    {'color': 'bright-orange', 'price': 85}],
#   'average': 88.125,
#   'date': '9/20/2018'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '9/20/2018'},
#  {'name': 'Payphone Tee',
#   'search': 'supreme-Payphone-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 52},
#    {'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 57},
#    {'color': 'natural', 'price': 53},
#    {'color': 'red', 'price': 48},
#    {'color': 'bright-orange', 'price': 48},
#    {'color': 'dark-pink', 'price': 47},
#    {'color': 'navy', 'price': 56},
#    {'color': 'slate', 'price': 61}],
#   'average': 53.0,
#   'date': '9/20/2018'},
#  {'name': 'Faces Tee',
#   'search': 'supreme-Faces-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'slate', 'price': 55},
#    {'color': 'dark-pink', 'price': 49},
#    {'color': 'bright-orange', 'price': 39},
#    {'color': 'navy', 'price': 59},
#    {'color': 'red', 'price': 51}],
#   'average': 51.625,
#   'date': '9/20/2018'},
#  {'name': 'System Tee',
#   'search': 'supreme-System-Tee-black',
#   'colors': [{'color': 'black', 'price': 45},
#    {'color': 'ash-grey', 'price': 40},
#    {'color': 'white', 'price': 49},
#    {'color': 'navy', 'price': 45},
#    {'color': 'dark-pink', 'price': 40},
#    {'color': 'slate', 'price': 44},
#    {'color': 'bright-orange', 'price': 42},
#    {'color': 'burgundy', 'price': 41}],
#   'average': 43.25,
#   'date': '9/20/2018'},
#  {'name': 'The Killer Trust Tee',
#   'search': 'supreme-The-Killer-Trust-Tee-black',
#   'colors': [{'color': 'black', 'price': 238},
#    {'color': 'olive', 'price': 147},
#    {'color': 'white', 'price': 183},
#    {'color': 'heather-grey', 'price': 142},
#    {'color': 'red', 'price': 123},
#    {'color': 'navy', 'price': 191},
#    {'color': 'pale-yellow', 'price': 131}],
#   'average': 165.0,
#   'date': '10/25/2018'},
#  {'name': 'Chris Cunningham Chihuahua Tee',
#   'search': 'supreme-Chris-Cunningham-Chihuahua-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'white', 'price': 58},
#    {'color': 'pale-mint', 'price': 57},
#    {'color': 'taupe', 'price': 55},
#    {'color': 'red', 'price': 55}],
#   'average': 59.6,
#   'date': '11/8/2018'},
#  {'name': 'Chris Cunningham Rubber Johnny Tee',
#   'search': 'supreme-Chris-Cunningham-Rubber-Johnny-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'pale-mint', 'price': 53},
#    {'color': 'taupe', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'red', 'price': 43}],
#   'average': 50.2,
#   'date': '11/8/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Photo Tee',
#   'search': 'supreme-the-north-face-photo-tee-black',
#   'colors': [],
#   'date': '11/29/2018'},
#  {'name': 'Cat in the Hat Tee',
#   'search': 'supreme-Cat-in-the-Hat-Tee-black',
#   'colors': [{'color': 'black', 'price': 107},
#    {'color': 'white', 'price': 97},
#    {'color': 'purple', 'price': 95},
#    {'color': 'red', 'price': 85},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 88},
#    {'color': 'yellow', 'price': 69},
#    {'color': 'olive', 'price': 76}],
#   'average': 88.25,
#   'date': '12/13/2018'},
#  {'name': 'Marvin Gaye Tee',
#   'search': 'supreme-Marvin-Gaye-Tee-black',
#   'colors': [{'color': 'white', 'price': 60},
#    {'color': 'black', 'price': 64},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'clay', 'price': 61},
#    {'color': 'navy', 'price': 55},
#    {'color': 'red', 'price': 61},
#    {'color': 'purple', 'price': 66},
#    {'color': 'yellow', 'price': 54}],
#   'average': 59.125,
#   'date': '12/13/2018'},
#  {'name': 'Smile Tee',
#   'search': 'supreme-Smile-Tee-black',
#   'colors': [{'color': 'black', 'price': 104},
#    {'color': 'white', 'price': 90},
#    {'color': 'red', 'price': 88},
#    {'color': 'clay', 'price': 80},
#    {'color': 'heather-grey', 'price': 73},
#    {'color': 'purple', 'price': 91},
#    {'color': 'yellow', 'price': 90},
#    {'color': 'slate', 'price': 71}],
#   'average': 85.875,
#   'date': '12/13/2018'},
#  {'name': "Luden'sÂ® Tee",
#   'search': 'supreme-ludens-tee-black',
#   'colors': [{'color': 'purple', 'price': 66},
#    {'color': 'black', 'price': 64},
#    {'color': 'white', 'price': 58},
#    {'color': 'royal', 'price': 50},
#    {'color': 'clay', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'burgundy', 'price': 61},
#    {'color': 'yellow', 'price': 62}],
#   'average': 58.25,
#   'date': '12/13/2018'},
#  {'name': 'Bombay Tee',
# ...
#    {'color': 'light-pink', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'light-blue', 'price': 82},
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5,
#   'date': '6/27/2019'},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444,
#   'date': '6/27/2019'},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75,
#   'date': '6/27/2019'},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75,
#   'date': '6/27/2019'},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375,
#   'date': '6/27/2019'},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25,
#   'date': '6/27/2019'},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75,
#   'date': '6/27/2019'},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375,
#   'date': '6/27/2019'},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875,
#   'date': '8/22/2019'},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857,
#   'date': '8/22/2019'},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5,
#   'date': '8/22/2019'},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285,
#   'date': '8/22/2019'},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0,
#   'date': '8/22/2019'},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0,
#   'date': '8/22/2019'},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125,
#   'date': '8/22/2019'},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854,
#   'date': '8/22/2019'},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5,
#   'date': '8/22/2019'},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143,
#   'date': '8/22/2019'},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2,
#   'date': '9/19/2019'},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429,
#   'date': '10/10/2019'},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375,
#   'date': '10/10/2019'},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25,
#   'date': '10/10/2019'},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285,
#   'date': '10/10/2019'},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125,
#   'date': '10/10/2019'},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146,
#   'date': '10/10/2019'},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5,
#   'date': '10/10/2019'},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875,
#   'date': '10/10/2019'},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336,
#   'date': '10/10/2019'},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0,
#   'date': '10/24/2019'},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6,
#   'date': '12/5/2019'},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4,
#   'date': '12/5/2019'},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25,
#   'date': '12/19/2019'},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854,
#   'date': '12/19/2019'},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285,
#   'date': '12/19/2019'},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0,
#   'date': '12/19/2019'},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875,
#   'date': '12/19/2019'},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0,
#   'date': '12/19/2019'},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5,
#   'date': '12/19/2019'},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664,
#   'date': '12/19/2019'}]

# %%
# Write
with open('data0-184sorted.json', 'w') as outfile:
    json.dump(full, outfile)

# %%
full2 = []

# %%
read_json(full2, "data0-184sorted.json")
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208},
#    {'color': 'black', 'price': 246},
#    {'color': 'white', 'price': 212},
#    {'color': 'heather-grey', 'price': 172},
#    {'color': 'navy', 'price': 191},
#    {'color': 'lime-green', 'price': 218},
#    {'color': 'lt-pink', 'price': 196},
#    {'color': 'aqua', 'price': 189},
#    {'color': 'red', 'price': None}],
#   'average': 204.0,
#   'date': '2/16/2017'},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318},
#    {'color': 'grey', 'price': 121},
#    {'color': 'white', 'price': 233},
#    {'color': 'black', 'price': 315},
#    {'color': 'lt-green', 'price': 165},
#    {'color': 'mocha', 'price': 150},
#    {'color': 'aqua', 'price': 180},
#    {'color': 'red', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 211.71428571428572,
#   'date': '2/16/2017'},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107},
#    {'color': 'navy', 'price': 110},
#    {'color': 'black', 'price': 138},
#    {'color': 'red', 'price': 95},
#    {'color': 'bright-coral', 'price': 80},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'mocha', 'price': None}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '2/16/2017'},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61},
#    {'color': 'black', 'price': 127},
#    {'color': 'white', 'price': 146},
#    {'color': 'lt-teal', 'price': 90},
#    {'color': 'mocha', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'red', 'price': 115},
#    {'color': 'lt-pink', 'price': None}],
#   'average': 107.8,
#   'date': '2/16/2017'},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'bright-coral', 'price': 44},
#    {'color': 'navy', 'price': 70},
#    {'color': 'mocha', 'price': 46},
#    {'color': 'white', 'price': 66},
#    {'color': 'aqua', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 60.8,
#   'date': '2/16/2017'},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120},
#    {'color': 'red', 'price': 90},
#    {'color': 'white', 'price': 145},
#    {'color': 'navy', 'price': 83},
#    {'color': 'grey', 'price': 65},
#    {'color': 'mocha', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'aqua', 'price': 133}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '2/16/2017'},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137},
#    {'color': 'white', 'price': 137},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 137.0,
#   'date': '2/16/2017'},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 90},
#    {'color': 'heather-grey', 'price': 71},
#    {'color': 'pale-pink', 'price': 72},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 79.0,
#   'date': '2/16/2017'},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95},
#    {'color': 'white', 'price': 73},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'black', 'price': 60},
#    {'color': 'light-blue', 'price': 91},
#    {'color': 'navy', 'price': 50},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 76.5,
#   'date': '6/29/2017'},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84},
#    {'color': 'black', 'price': 76},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 66},
#    {'color': 'hot-pink', 'price': 50},
#    {'color': 'orange', 'price': 64},
#    {'color': 'light-blue', 'price': None},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'navy', 'price': 64}],
#   'average': 65.85714285714286,
#   'date': '6/29/2017'},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 55},
#    {'color': 'navy', 'price': 57},
#    {'color': 'red', 'price': 40},
#    {'color': 'teal', 'price': 55},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 57.0,
#   'date': '6/29/2017'},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'navy', 'price': 95},
#    {'color': 'white', 'price': 99},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'orange', 'price': None}],
#   'average': 98.33333333333333,
#   'date': '6/29/2017'},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 56},
#    {'color': 'teal', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 77.5,
#   'date': '6/29/2017'},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88},
#    {'color': 'heather-grey', 'price': 64},
#    {'color': 'white', 'price': 75},
#    {'color': 'navy', 'price': 66},
#    {'color': 'red', 'price': 53},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'dusty-pink', 'price': 60}],
#   'average': 67.66666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'black', 'price': 75},
#    {'color': 'lime', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'light-brown', 'price': None}],
#   'average': 64.75,
#   'date': '6/29/2017'},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76},
#    {'color': 'orange', 'price': 60},
#    {'color': 'black', 'price': 87},
#    {'color': 'red', 'price': 72},
#    {'color': 'dark-pink', 'price': 48},
#    {'color': 'teal', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'pale-yellow', 'price': 48}],
#   'average': 65.16666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238},
#    {'color': 'black', 'price': 297},
#    {'color': 'heather-grey', 'price': 224},
#    {'color': 'pale-blue', 'price': 224},
#    {'color': 'red', 'price': 226},
#    {'color': 'brown', 'price': 266},
#    {'color': 'lime', 'price': 201}],
#   'average': 239.42857142857142,
#   'date': '8/24/2017'},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175},
#    {'color': 'white', 'price': 162},
#    {'color': 'heather-grey', 'price': 110},
#    {'color': 'red', 'price': 123},
#    {'color': 'bright-orange', 'price': 93},
#    {'color': 'navy', 'price': 108},
#    {'color': 'royal', 'price': 208},
#    {'color': 'lime', 'price': 70},
#    {'color': 'brown', 'price': None}],
#   'average': 131.125,
#   'date': '8/24/2017'},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'red', 'price': 100},
#    {'color': 'white', 'price': 116},
#    {'color': 'heather-grey', 'price': 95},
#    {'color': 'navy', 'price': 89},
#    {'color': 'lime', 'price': 61},
#    {'color': 'bright-orange', 'price': 121},
#    {'color': 'brown', 'price': 80}],
#   'average': 101.875,
#   'date': '8/24/2017'},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'white', 'price': 82},
#    {'color': 'navy', 'price': 72},
#    {'color': 'light-pink', 'price': 63},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 75.5,
#   'date': '8/24/2017'},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 50},
#    {'color': 'brown', 'price': 100},
#    {'color': 'lime', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 83.0,
#   'date': '8/24/2017'},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58},
#    {'color': 'black', 'price': 113},
#    {'color': 'white', 'price': 122},
#    {'color': 'navy', 'price': 59},
#    {'color': 'lime', 'price': 60},
#    {'color': 'red', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 82.4,
#   'date': '8/24/2017'},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73},
#    {'color': 'black', 'price': 71},
#    {'color': 'white', 'price': 71},
#    {'color': 'red', 'price': 63},
#    {'color': 'brown', 'price': 60},
#    {'color': 'navy', 'price': 55},
#    {'color': 'light-pink', 'price': 55},
#    {'color': 'lime', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 64.0,
#   'date': '8/24/2017'},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '8/24/2017'},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 92},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'navy', 'price': 60},
#    {'color': 'royal', 'price': 75},
#    {'color': 'heather-grey', 'price': 75},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 73.0,
#   'date': '8/24/2017'},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'heather-grey', 'price': 79},
#    {'color': 'white', 'price': 95},
#    {'color': 'red', 'price': 79},
#    {'color': 'navy', 'price': 71},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'pale-blue', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 80.66666666666667,
#   'date': '9/21/2017'},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71},
#    {'color': 'black', 'price': 95},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 59},
#    {'color': 'brick', 'price': 70},
#    {'color': 'lime', 'price': 50},
#    {'color': 'pale-blue', 'price': 108},
#    {'color': 'navy', 'price': None}],
#   'average': 71.71428571428571,
#   'date': '9/21/2017'},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57},
#    {'color': 'black', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'pale-blue', 'price': 90},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'red', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 59.2,
#   'date': '9/21/2017'},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88}, {'color': 'black', 'price': 98}],
#   'average': 93.0,
#   'date': '9/21/2017'},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65}, {'color': 'white', 'price': 64}],
#   'average': 64.5,
#   'date': '9/21/2017'},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'heather-grey', 'price': 48},
#    {'color': 'lime', 'price': 50},
#    {'color': 'white', 'price': 50},
#    {'color': 'royal', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 48.75,
#   'date': '9/21/2017'},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266},
#    {'color': 'red', 'price': 221},
#    {'color': 'white', 'price': 233},
#    {'color': 'heather-grey', 'price': 200}],
#   'average': 230.0,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134},
#    {'color': 'black', 'price': 208},
#    {'color': 'white', 'price': 180},
#    {'color': 'red', 'price': 148}],
#   'average': 167.5,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 140},
#    {'color': 'red', 'price': 119}],
#   'average': 143.25,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144},
#    {'color': 'white', 'price': 120},
#    {'color': 'heather-grey', 'price': 108},
#    {'color': 'red', 'price': 125}],
#   'average': 124.25,
#   'date': '10/12/2017'},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253},
#    {'color': 'white', 'price': 273},
#    {'color': 'lime', 'price': 105},
#    {'color': 'cardinal', 'price': 132},
#    {'color': 'slate', 'price': 128}],
#   'average': 178.2,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230},
#    {'color': 'white', 'price': 190},
#    {'color': 'cardinal', 'price': 157},
#    {'color': 'slate', 'price': 153},
#    {'color': 'lime', 'price': 173}],
#   'average': 180.6,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 141},
#    {'color': 'slate', 'price': 120},
#    {'color': 'lime', 'price': 109}],
#   'average': 129.8,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150},
#    {'color': 'white', 'price': 116},
#    {'color': 'lime', 'price': 97},
#    {'color': 'slate', 'price': 127},
#    {'color': 'cardinal', 'price': 150}],
#   'average': 128.0,
#   'date': '11/2/2017'},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104},
#    {'color': 'black', 'price': 80},
#    {'color': 'dark-slate', 'price': 59},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': None},
#    {'color': 'olive-green', 'price': None}],
#   'average': 76.0,
#   'date': '11/16/2017'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': [],
#   'date': '11/30/2017'},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201},
#    {'color': 'white', 'price': 140},
#    {'color': 'heather-grey', 'price': 120},
#    {'color': 'lime', 'price': 110},
#    {'color': 'red', 'price': 150},
#    {'color': 'brown', 'price': 153},
#    {'color': 'dark-slate', 'price': 130},
#    {'color': 'bright-orange', 'price': 131}],
#   'average': 141.875,
#   'date': '12/14/2017'},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127},
#    {'color': 'navy', 'price': 121},
#    {'color': 'white', 'price': 104},
#    {'color': 'heather-grey', 'price': 105},
#    {'color': 'light-pink', 'price': 176},
#    {'color': 'mustard', 'price': 125},
#    {'color': 'red', 'price': 100},
#    {'color': 'brown', 'price': 70},
#    {'color': 'lime', 'price': 65}],
#   'average': 110.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133},
#    {'color': 'white', 'price': 127},
#    {'color': 'brick', 'price': 101},
#    {'color': 'green', 'price': 71},
#    {'color': 'light-purple', 'price': 105},
#    {'color': 'dark-slate', 'price': 85},
#    {'color': 'heather-grey', 'price': 50}],
#   'average': 96.0,
#   'date': '12/14/2017'},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93},
#    {'color': 'red', 'price': 69},
#    {'color': 'white', 'price': 89}],
#   'average': 83.66666666666667,
#   'date': '12/14/2017'},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'green', 'price': 63},
#    {'color': 'light-purple', 'price': 55},
#    {'color': 'navy', 'price': 50},
#    {'color': 'brick', 'price': None}],
#   'average': 78.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 39},
#    {'color': 'white', 'price': 51},
#    {'color': 'mustard', 'price': 44},
#    {'color': 'grey', 'price': 41},
#    {'color': 'light-purple', 'price': 65},
#    {'color': 'dark-slate', 'price': 54},
#    {'color': 'green', 'price': 54}],
#   'average': 52.625,
#   'date': '12/14/2017'},
#  {'name': 'Christmas Tee',
#   'search': 'supreme-christmas-tee-white',
#   'colors': [{'color': 'white', 'price': 72}],
#   'average': 72,
#   'date': '12/14/2017'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/15/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/15/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/15/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/15/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/15/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/15/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/15/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/15/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/15/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/15/2018'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/22/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/22/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/22/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/22/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/22/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/22/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/22/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/22/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/22/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/22/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89},
#    {'color': 'white', 'price': 86},
#    {'color': 'red', 'price': 69},
#    {'color': 'royal', 'price': 79}],
#   'average': 80.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 66}],
#   'average': 64.33333333333333,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 73},
#    {'color': 'royal', 'price': 81},
#    {'color': 'red', 'price': 66}],
#   'average': 76.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 74},
#    {'color': 'royal', 'price': 58}],
#   'average': 72.25,
#   'date': '3/15/2018'},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172},
#    {'color': 'white', 'price': 148},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'navy', 'price': 122},
#    {'color': 'red', 'price': 100},
#    {'color': 'light-purple', 'price': 143},
#    {'color': 'light-pink', 'price': 193},
#    {'color': 'pale-blue', 'price': 140},
#    {'color': 'bright-yellow', 'price': 130}],
#   'average': 138.66666666666666,
#   'date': '3/29/2018'},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129},
#    {'color': 'black', 'price': 125},
#    {'color': 'heather-grey', 'price': 78},
#    {'color': 'navy', 'price': 98},
#    {'color': 'pale-blue', 'price': 82},
#    {'color': 'green', 'price': 87},
#    {'color': 'red', 'price': 106},
#    {'color': 'bright-yellow', 'price': 61},
#    {'color': 'light-purple', 'price': 117}],
#   'average': 98.11111111111111,
#   'date': '3/29/2018'},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55},
#    {'color': 'black', 'price': 68},
#    {'color': 'white', 'price': 65},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 52},
#    {'color': 'bright-yellow', 'price': 58},
#    {'color': 'pale-blue', 'price': 73}],
#   'average': 60.5,
#   'date': '3/29/2018'},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'light-purple', 'price': 47},
#    {'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 53},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 66},
#    {'color': 'pale-blue', 'price': 54},
#    {'color': 'bright-yellow', 'price': 45},
#    {'color': 'green', 'price': 44}],
#   'average': 52.77777777777778,
#   'date': '3/29/2018'},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 53},
#    {'color': 'pale-blue', 'price': 65},
#    {'color': 'light-purple', 'price': 53},
#    {'color': 'bright-yellow', 'price': 43},
#    {'color': 'green', 'price': 45},
#    {'color': 'navy', 'price': 65}],
#   'average': 58.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'heather-grey', 'price': 70},
#    {'color': 'white', 'price': 79},
#    {'color': 'royal', 'price': 53},
#    {'color': 'red', 'price': 58},
#    {'color': 'pale-yellow', 'price': 20}],
#   'average': 59.666666666666664,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65},
#    {'color': 'red', 'price': 43},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 62.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62},
#    {'color': 'hot-pink', 'price': 35},
#    {'color': 'white', 'price': 52},
#    {'color': 'royal', 'price': 50},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 48.8,
#   'date': '3/29/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': [],
#   'date': '4/5/2018'},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98}, {'color': 'white', 'price': 90}],
#   'average': 94.0,
#   'date': '4/26/2018'},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'white', 'price': 81}],
#   'average': 91.0,
#   'date': '4/26/2018'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '5/31/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 81},
#    {'color': 'red', 'price': 71},
#    {'color': 'dark-green', 'price': 73},
#    {'color': 'light-purple', 'price': 84},
#    {'color': 'bright-orange', 'price': 68}],
#   'average': 74.0,
#   'date': '6/21/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'red', 'price': 58},
#    {'color': 'white', 'price': 84},
#    {'color': 'dark-green', 'price': 79},
#    {'color': 'bright-orange', 'price': 43},
#    {'color': 'light-purple', 'price': 75}],
#   'average': 67.14285714285714,
#   'date': '6/21/2018'},
#  {'name': 'Madonna Tee',
#   'search': 'supreme-Madonna-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 100},
#    {'color': 'black', 'price': 178},
#    {'color': 'dark-green', 'price': 102},
#    {'color': 'heather-grey', 'price': 109},
#    {'color': 'white', 'price': 167},
#    {'color': 'navy', 'price': 114},
#    {'color': 'red', 'price': 95},
#    {'color': 'pink', 'price': 97},
#    {'color': 'pale-yellow', 'price': 102}],
#   'average': 118.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Liquid Tee',
#   'search': 'supreme-Liquid-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 84},
#    {'color': 'navy', 'price': 76},
#    {'color': 'black', 'price': 94},
#    {'color': 'white', 'price': 88},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'burgundy', 'price': 71},
#    {'color': 'pink', 'price': 80},
#    {'color': 'natural', 'price': 76}],
#   'average': 79.5,
#   'date': '8/16/2018'},
#  {'name': 'Still Life Tee',
#   'search': 'supreme-Still-Life-Tee-black',
#   'colors': [{'color': 'red', 'price': 49},
#    {'color': 'bright-blue', 'price': 55},
#    {'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 62},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'pink', 'price': 87},
#    {'color': 'dark-green', 'price': 62}],
#   'average': 64.625,
#   'date': '8/16/2018'},
#  {'name': '1994 L/S Tee',
#   'search': 'supreme-1994-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'heather-grey', 'price': 88},
#    {'color': 'white', 'price': 102},
#    {'color': 'navy', 'price': 98},
#    {'color': 'natural', 'price': 101},
#    {'color': 'dark-green', 'price': 94},
#    {'color': 'burgundy', 'price': 83},
#    {'color': 'pink', 'price': 93},
#    {'color': 'red', 'price': 82}],
#   'average': 93.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Bottle Cap Tee',
#   'search': 'supreme-Bottle-Cap-Tee-black',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'white', 'price': 64},
#    {'color': 'red', 'price': 52},
#    {'color': 'bright-blue', 'price': 58},
#    {'color': 'navy', 'price': 63},
#    {'color': 'pale-yellow', 'price': 51},
#    {'color': 'pink', 'price': 62},
#    {'color': 'dark-green', 'price': 60}],
#   'average': 59.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Cutouts Tee',
#   'search': 'supreme-Cutouts-Tee-black',
#   'colors': [{'color': 'black', 'price': 75},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'bright-blue', 'price': 73},
#    {'color': 'pink', 'price': 56}],
#   'average': 60.75,
#   'date': '8/16/2018'},
#  {'name': 'Life Sucks Die Tee',
#   'search': 'supreme-Life-Sucks-Die-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 54},
#    {'color': 'black', 'price': 64},
#    {'color': 'red', 'price': 55},
#    {'color': 'natural', 'price': 66},
#    {'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 52},
#    {'color': 'dark-green', 'price': 77},
#    {'color': 'bright-blue', 'price': 48},
#    {'color': 'pink', 'price': 53}],
#   'average': 58.888888888888886,
#   'date': '8/16/2018'},
#  {'name': 'Bedroom Tee',
#   'search': 'supreme-Bedroom-Tee-black',
#   'colors': [{'color': 'navy', 'price': 59},
#    {'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 64},
#    {'color': 'light-pink', 'price': 80},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-green', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'natural', 'price': 70},
#    {'color': 'bright-blue', 'price': 51},
#    {'color': 'pink', 'price': 77}],
#   'average': 62.3,
#   'date': '8/16/2018'},
#  {'name': 'Fuck You Tee',
#   'search': 'supreme-Fuck-You-Tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'bright-blue', 'price': 53},
#    {'color': 'dark-green', 'price': 56},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 57},
#    {'color': 'orange', 'price': 62},
#    {'color': 'red', 'price': 58}],
#   'average': 59.5,
#   'date': '8/16/2018'},
#  {'name': 'Guts Tee',
#   'search': 'supreme-Guts-Tee-black',
#   'colors': [{'color': 'white', 'price': 57},
#    {'color': 'red', 'price': 47},
#    {'color': 'natural', 'price': 51},
#    {'color': 'black', 'price': 56},
#    {'color': 'navy', 'price': 51},
#    {'color': 'ash-grey', 'price': 50},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'bright-blue', 'price': 63},
#    {'color': 'pink', 'price': 56}],
#   'average': 54.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Mike Kelley/Supreme The Empire State Building Tee',
#   'search': 'supreme-mike-kelley-supreme-the-empire-state-building-tee-black',
#   'colors': [{'color': 'white', 'price': 66},
#    {'color': 'burgundy', 'price': 47},
#    {'color': 'ash-grey', 'price': 49},
#    {'color': 'black', 'price': 70},
#    {'color': 'dark-green', 'price': 49},
#    {'color': 'slate', 'price': 49},
#    {'color': 'clay', 'price': 51},
#    {'color': 'bright-orange', 'price': 51}],
#   'average': 54.0,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 77},
#    {'color': 'slate', 'price': 73},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'clay', 'price': 77},
#    {'color': 'black', 'price': 126},
#    {'color': 'white', 'price': 108},
#    {'color': 'dark-green', 'price': 84},
#    {'color': 'bright-orange', 'price': 94}],
#   'average': 89.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! L/S Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 166},
#    {'color': 'white', 'price': 134},
#    {'color': 'clay', 'price': 95},
#    {'color': 'ash-grey', 'price': 103},
#    {'color': 'slate', 'price': 93},
#    {'color': 'dark-green', 'price': 103},
#    {'color': 'burgundy', 'price': 104},
#    {'color': 'bright-orange', 'price': 105}],
#   'average': 112.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Hiding From Indians Tee',
#   'search': 'supreme-mike-kelley-supreme-hiding-from-indians-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 46},
#    {'color': 'black', 'price': 59},
#    {'color': 'clay', 'price': 55},
#    {'color': 'white', 'price': 58},
#    {'color': 'burgundy', 'price': 48},
#    {'color': 'bright-orange', 'price': 59},
#    {'color': 'dark-green', 'price': 61},
#    {'color': 'slate', 'price': 57}],
#   'average': 55.375,
#   'date': '9/6/2018'},
#  {'name': 'SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee',
#   'search': 'supreme-comme-des-garcons-shirt-split-box-logo-tee-black',
#   'colors': [],
#   'date': '9/13/2018'},
#  {'name': 'Group Tee',
#   'search': 'supreme-Group-Tee-black',
#   'colors': [{'color': 'slate', 'price': 65},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 82},
#    {'color': 'red', 'price': 76},
#    {'color': 'dark-pink', 'price': 76},
#    {'color': 'bright-orange', 'price': 68},
#    {'color': 'navy', 'price': 75},
#    {'color': 'dark-green', 'price': 72}],
#   'average': 74.0,
#   'date': '9/20/2018'},
#  {'name': 'Remember Tee',
#   'search': 'supreme-Remember-Tee-black',
#   'colors': [{'color': 'black', 'price': 81},
#    {'color': 'dark-pink', 'price': 63},
#    {'color': 'white', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'heather-grey', 'price': 74},
#    {'color': 'red', 'price': 68},
#    {'color': 'slate', 'price': 74},
#    {'color': 'bright-orange', 'price': 66}],
#   'average': 72.5,
#   'date': '9/20/2018'},
#  {'name': 'Liquid Swords Tee',
#   'search': 'supreme-Liquid-Swords-Tee-black',
#   'colors': [{'color': 'dark-green', 'price': 89},
#    {'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 81},
#    {'color': 'heather-grey', 'price': 81},
#    {'color': 'navy', 'price': 94},
#    {'color': 'slate', 'price': 96},
#    {'color': 'red', 'price': 80},
#    {'color': 'bright-orange', 'price': 85}],
#   'average': 88.125,
#   'date': '9/20/2018'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'fw18-black', 'price': 72},
#    {'color': 'fw18-slate', 'price': 65},
#    {'color': 'fw18-white', 'price': 63},
#    {'color': 'fw18-navy', 'price': 65},
#    {'color': 'fw18-dark-green', 'price': 67},
#    {'color': 'fw18-pale-yellow', 'price': 69},
#    {'color': 'fw18-red', 'price': 59},
#    {'color': 'fw18-dark-pink', 'price': 62},
#    {'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '9/20/2018'},
#  {'name': 'Payphone Tee',
#   'search': 'supreme-Payphone-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 52},
#    {'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 57},
#    {'color': 'natural', 'price': 53},
#    {'color': 'red', 'price': 48},
#    {'color': 'bright-orange', 'price': 48},
#    {'color': 'dark-pink', 'price': 47},
#    {'color': 'navy', 'price': 56},
#    {'color': 'slate', 'price': 61}],
#   'average': 53.0,
#   'date': '9/20/2018'},
#  {'name': 'Faces Tee',
#   'search': 'supreme-Faces-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'slate', 'price': 55},
#    {'color': 'dark-pink', 'price': 49},
#    {'color': 'bright-orange', 'price': 39},
#    {'color': 'navy', 'price': 59},
#    {'color': 'red', 'price': 51}],
#   'average': 51.625,
#   'date': '9/20/2018'},
#  {'name': 'System Tee',
#   'search': 'supreme-System-Tee-black',
#   'colors': [{'color': 'black', 'price': 45},
#    {'color': 'ash-grey', 'price': 40},
#    {'color': 'white', 'price': 49},
#    {'color': 'navy', 'price': 45},
#    {'color': 'dark-pink', 'price': 40},
#    {'color': 'slate', 'price': 44},
#    {'color': 'bright-orange', 'price': 42},
#    {'color': 'burgundy', 'price': 41}],
#   'average': 43.25,
#   'date': '9/20/2018'},
#  {'name': 'The Killer Trust Tee',
#   'search': 'supreme-The-Killer-Trust-Tee-black',
#   'colors': [{'color': 'black', 'price': 238},
#    {'color': 'olive', 'price': 147},
#    {'color': 'white', 'price': 183},
#    {'color': 'heather-grey', 'price': 142},
#    {'color': 'red', 'price': 123},
#    {'color': 'navy', 'price': 191},
#    {'color': 'pale-yellow', 'price': 131}],
#   'average': 165.0,
#   'date': '10/25/2018'},
#  {'name': '18 & Stormy Tee',
#   'search': 'supreme-18-stormy-tee-white',
#   'colors': [{'color': 'white', 'price': 60}],
#   'average': 60,
#   'date': '11/1/2018'},
#  {'name': 'Chris Cunningham Chihuahua Tee',
#   'search': 'supreme-Chris-Cunningham-Chihuahua-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'white', 'price': 58},
#    {'color': 'pale-mint', 'price': 57},
#    {'color': 'taupe', 'price': 55},
#    {'color': 'red', 'price': 55}],
#   'average': 59.6,
#   'date': '11/8/2018'},
#  {'name': 'Chris Cunningham Rubber Johnny Tee',
#   'search': 'supreme-Chris-Cunningham-Rubber-Johnny-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'pale-mint', 'price': 53},
#    {'color': 'taupe', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'red', 'price': 43}],
#   'average': 50.2,
#   'date': '11/8/2018'},
#  {'name': 'BLESSED DVD + Tee',
#   'search': 'supreme-blessed-tee-white',
#   'colors': [{'color': 'white', 'price': 86}],
#   'average': 86,
#   'date': '11/23/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Photo Tee',
#   'search': 'supreme-the-north-face-photo-tee-black',
#   'colors': [],
#   'date': '11/29/2018'},
#  {'name': 'Cat in the Hat Tee',
#   'search': 'supreme-Cat-in-the-Hat-Tee-black',
#   'colors': [{'color': 'black', 'price': 107},
#    {'color': 'white', 'price': 97},
#    {'color': 'purple', 'price': 95},
#    {'color': 'red', 'price': 85},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 88},
#    {'color': 'yellow', 'price': 69},
#    {'color': 'olive', 'price': 76}],
#   'average': 88.25,
#   'date': '12/13/2018'},
#  {'name': 'Marvin Gaye Tee',
#   'search': 'supreme-Marvin-Gaye-Tee-black',
#   'colors': [{'color': 'white', 'price': 60},
#    {'color': 'black', 'price': 64},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'clay', 'price': 61},
#    {'color': 'navy', 'price': 55},
#    {'color': 'red', 'price': 61},
#    {'color': 'purple', 'price': 66},
#    {'color': 'yellow', 'price': 54}],
#   'average': 59.125,
#   'date': '12/13/2018'},
#  {'name': 'Smile Tee',
#   'search': 'supreme-Smile-Tee-black',
#   'colors': [{'color': 'black', 'price': 104},
#    {'color': 'white', 'price': 90},
#    {'color': 'red', 'price': 88},
#    {'color': 'clay', 'price': 80},
#    {'color': 'heather-grey', 'price': 73},
#    {'color': 'purple', 'price': 91},
#    {'color': 'yellow', 'price': 90},
#    {'color': 'slate', 'price': 71}],
# ...
#    {'color': 'light-pink', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'light-blue', 'price': 82},
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5,
#   'date': '6/27/2019'},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444,
#   'date': '6/27/2019'},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75,
#   'date': '6/27/2019'},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75,
#   'date': '6/27/2019'},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375,
#   'date': '6/27/2019'},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25,
#   'date': '6/27/2019'},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75,
#   'date': '6/27/2019'},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375,
#   'date': '6/27/2019'},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875,
#   'date': '8/22/2019'},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857,
#   'date': '8/22/2019'},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5,
#   'date': '8/22/2019'},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285,
#   'date': '8/22/2019'},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0,
#   'date': '8/22/2019'},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0,
#   'date': '8/22/2019'},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125,
#   'date': '8/22/2019'},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854,
#   'date': '8/22/2019'},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5,
#   'date': '8/22/2019'},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143,
#   'date': '8/22/2019'},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2,
#   'date': '9/19/2019'},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429,
#   'date': '10/10/2019'},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375,
#   'date': '10/10/2019'},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25,
#   'date': '10/10/2019'},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285,
#   'date': '10/10/2019'},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125,
#   'date': '10/10/2019'},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146,
#   'date': '10/10/2019'},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5,
#   'date': '10/10/2019'},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875,
#   'date': '10/10/2019'},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336,
#   'date': '10/10/2019'},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0,
#   'date': '10/24/2019'},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6,
#   'date': '12/5/2019'},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4,
#   'date': '12/5/2019'},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25,
#   'date': '12/19/2019'},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854,
#   'date': '12/19/2019'},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285,
#   'date': '12/19/2019'},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0,
#   'date': '12/19/2019'},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875,
#   'date': '12/19/2019'},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0,
#   'date': '12/19/2019'},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5,
#   'date': '12/19/2019'},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664,
#   'date': '12/19/2019'}]

# %%
len(full2)
# Out:
# 187

# %%
ss18tees = csv_to_object('ss18.csv')

# %%
get_all_info(ss18tees, 0, 7)
# Out:
# 18:04:42 :: Retrieving search results for supreme-rocks-tee
# Got 8 colors
# 18:04:44 :: Retrieving search results for supreme-mona-lisa-tee
# Got 8 colors
# 18:04:44 :: Retrieving search results for supreme-tentacles-tee
# Got 8 colors
# 18:04:45 :: Retrieving search results for supreme-swimmers-tee
# Got 7 colors
# 18:04:45 :: Retrieving search results for supreme-ganesha-tee
# Got 7 colors
# 18:04:45 :: Retrieving search results for supreme-hardware-tee
# Got 8 colors
# 18:04:46 :: Retrieving search results for supreme-gonz-logo-tee
# Got 8 colors
# [{'name': 'Rocks Tee',
#   'search': 'supreme-Rocks-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white-ss18', 'price': 159},
#    {'color': 'black-ss18', 'price': 159},
#    {'color': 'red-ss18', 'price': 98},
#    {'color': 'ash-grey-ss18', 'price': 88},
#    {'color': 'light-purple-ss18', 'price': 92},
#    {'color': 'dark-slate-ss18', 'price': 101},
#    {'color': 'light-pink-ss18', 'price': 118},
#    {'color': 'orange-ss18', 'price': 96}],
#   'average': 113.875},
#  {'name': 'Mona Lisa Tee',
#   'search': 'supreme-Mona-Lisa-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black-ss18', 'price': 174},
#    {'color': 'white-ss18', 'price': 129},
#    {'color': 'hot-pink-ss18', 'price': 91},
#    {'color': 'pale-yellow-ss18', 'price': 98},
#    {'color': 'heather-grey-ss18', 'price': 91},
#    {'color': 'red-ss18', 'price': 123},
#    {'color': 'royal-ss18', 'price': 119},
#    {'color': 'light-purple-ss18', 'price': 69}],
#   'average': 111.75},
#  {'name': 'Tentacles Tee',
#   'search': 'supreme-Tentacles-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white-ss18', 'price': 147},
#    {'color': 'black-ss18', 'price': 128},
#    {'color': 'brick-ss18', 'price': 80},
#    {'color': 'heather-grey-ss18', 'price': 100},
#    {'color': 'red-ss18', 'price': 89},
#    {'color': 'hot-pink-ss18', 'price': 82},
#    {'color': 'royal-ss18', 'price': 107},
#    {'color': 'pale-yellow-ss18', 'price': 96}],
#   'average': 103.625},
#  {'name': 'Swimmers Tee',
#   'search': 'supreme-Swimmers-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black-ss18', 'price': 82},
#    {'color': 'white-ss18', 'price': 74},
#    {'color': 'heather-grey-ss18', 'price': 65},
#    {'color': 'red-ss18', 'price': 68},
#    {'color': 'mustard-ss18', 'price': 88},
#    {'color': 'dark-slate-ss18', 'price': 64},
#    {'color': 'light-pink-ss18', 'price': 134}],
#   'average': 82.14285714285714},
#  {'name': 'Ganesha Tee',
#   'search': 'supreme-Ganesha-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black-ss18', 'price': 69},
#    {'color': 'light-pink-ss18', 'price': 105},
#    {'color': 'white-ss18', 'price': 76},
#    {'color': 'heather-grey-ss18', 'price': 61},
#    {'color': 'brick-ss18', 'price': 63},
#    {'color': 'orange-ss18', 'price': 72},
#    {'color': 'dark-slate-ss18', 'price': 76}],
#   'average': 74.57142857142857},
#  {'name': 'Hardware Tee',
#   'search': 'supreme-Hardware-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black-ss18', 'price': 79},
#    {'color': 'white-ss18', 'price': 87},
#    {'color': 'ash-grey-ss18', 'price': 54},
#    {'color': 'red-ss18', 'price': 47},
#    {'color': 'royal-ss18', 'price': 59},
#    {'color': 'navy-ss18', 'price': 64},
#    {'color': 'pale-yellow-ss18', 'price': 58},
#    {'color': 'light-purple-ss18', 'price': 53}],
#   'average': 62.625},
#  {'name': 'Gonz Logo Tee',
#   'search': 'supreme-Gonz-Logo-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black-ss18', 'price': 59},
#    {'color': 'white-ss18', 'price': 56},
#    {'color': 'warm-grey-ss18', 'price': 56},
#    {'color': 'red-ss18', 'price': 54},
#    {'color': 'heather-grey-ss18', 'price': 58},
#    {'color': 'royal-ss18', 'price': 49},
#    {'color': 'light-purple-ss18', 'price': 49},
#    {'color': 'mustard-ss18', 'price': 53}],
#   'average': 54.25}]

# %%
complete = []
read_json(complete, 'alldata.json')
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208},
#    {'color': 'black', 'price': 246},
#    {'color': 'white', 'price': 212},
#    {'color': 'heather-grey', 'price': 172},
#    {'color': 'navy', 'price': 191},
#    {'color': 'lime-green', 'price': 218},
#    {'color': 'lt-pink', 'price': 196},
#    {'color': 'aqua', 'price': 189},
#    {'color': 'red', 'price': None}],
#   'average': 204.0,
#   'date': '2/16/2017'},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318},
#    {'color': 'grey', 'price': 121},
#    {'color': 'white', 'price': 233},
#    {'color': 'black', 'price': 315},
#    {'color': 'lt-green', 'price': 165},
#    {'color': 'mocha', 'price': 150},
#    {'color': 'aqua', 'price': 180},
#    {'color': 'red', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 211.71428571428572,
#   'date': '2/16/2017'},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107},
#    {'color': 'navy', 'price': 110},
#    {'color': 'black', 'price': 138},
#    {'color': 'red', 'price': 95},
#    {'color': 'bright-coral', 'price': 80},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'mocha', 'price': None}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '2/16/2017'},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61},
#    {'color': 'black', 'price': 127},
#    {'color': 'white', 'price': 146},
#    {'color': 'lt-teal', 'price': 90},
#    {'color': 'mocha', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'red', 'price': 115},
#    {'color': 'lt-pink', 'price': None}],
#   'average': 107.8,
#   'date': '2/16/2017'},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'bright-coral', 'price': 44},
#    {'color': 'navy', 'price': 70},
#    {'color': 'mocha', 'price': 46},
#    {'color': 'white', 'price': 66},
#    {'color': 'aqua', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 60.8,
#   'date': '2/16/2017'},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120},
#    {'color': 'red', 'price': 90},
#    {'color': 'white', 'price': 145},
#    {'color': 'navy', 'price': 83},
#    {'color': 'grey', 'price': 65},
#    {'color': 'mocha', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'aqua', 'price': 133}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '2/16/2017'},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137},
#    {'color': 'white', 'price': 137},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 137.0,
#   'date': '2/16/2017'},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 90},
#    {'color': 'heather-grey', 'price': 71},
#    {'color': 'pale-pink', 'price': 72},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 79.0,
#   'date': '2/16/2017'},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95},
#    {'color': 'white', 'price': 73},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'black', 'price': 60},
#    {'color': 'light-blue', 'price': 91},
#    {'color': 'navy', 'price': 50},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 76.5,
#   'date': '6/29/2017'},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84},
#    {'color': 'black', 'price': 76},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 66},
#    {'color': 'hot-pink', 'price': 50},
#    {'color': 'orange', 'price': 64},
#    {'color': 'light-blue', 'price': None},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'navy', 'price': 64}],
#   'average': 65.85714285714286,
#   'date': '6/29/2017'},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 55},
#    {'color': 'navy', 'price': 57},
#    {'color': 'red', 'price': 40},
#    {'color': 'teal', 'price': 55},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 57.0,
#   'date': '6/29/2017'},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'navy', 'price': 95},
#    {'color': 'white', 'price': 99},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'orange', 'price': None}],
#   'average': 98.33333333333333,
#   'date': '6/29/2017'},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 56},
#    {'color': 'teal', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 77.5,
#   'date': '6/29/2017'},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88},
#    {'color': 'heather-grey', 'price': 64},
#    {'color': 'white', 'price': 75},
#    {'color': 'navy', 'price': 66},
#    {'color': 'red', 'price': 53},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'dusty-pink', 'price': 60}],
#   'average': 67.66666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'black', 'price': 75},
#    {'color': 'lime', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'light-brown', 'price': None}],
#   'average': 64.75,
#   'date': '6/29/2017'},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76},
#    {'color': 'orange', 'price': 60},
#    {'color': 'black', 'price': 87},
#    {'color': 'red', 'price': 72},
#    {'color': 'dark-pink', 'price': 48},
#    {'color': 'teal', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'pale-yellow', 'price': 48}],
#   'average': 65.16666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238},
#    {'color': 'black', 'price': 297},
#    {'color': 'heather-grey', 'price': 224},
#    {'color': 'pale-blue', 'price': 224},
#    {'color': 'red', 'price': 226},
#    {'color': 'brown', 'price': 266},
#    {'color': 'lime', 'price': 201}],
#   'average': 239.42857142857142,
#   'date': '8/24/2017'},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175},
#    {'color': 'white', 'price': 162},
#    {'color': 'heather-grey', 'price': 110},
#    {'color': 'red', 'price': 123},
#    {'color': 'bright-orange', 'price': 93},
#    {'color': 'navy', 'price': 108},
#    {'color': 'royal', 'price': 208},
#    {'color': 'lime', 'price': 70},
#    {'color': 'brown', 'price': None}],
#   'average': 131.125,
#   'date': '8/24/2017'},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'red', 'price': 100},
#    {'color': 'white', 'price': 116},
#    {'color': 'heather-grey', 'price': 95},
#    {'color': 'navy', 'price': 89},
#    {'color': 'lime', 'price': 61},
#    {'color': 'bright-orange', 'price': 121},
#    {'color': 'brown', 'price': 80}],
#   'average': 101.875,
#   'date': '8/24/2017'},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'white', 'price': 82},
#    {'color': 'navy', 'price': 72},
#    {'color': 'light-pink', 'price': 63},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 75.5,
#   'date': '8/24/2017'},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 50},
#    {'color': 'brown', 'price': 100},
#    {'color': 'lime', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 83.0,
#   'date': '8/24/2017'},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58},
#    {'color': 'black', 'price': 113},
#    {'color': 'white', 'price': 122},
#    {'color': 'navy', 'price': 59},
#    {'color': 'lime', 'price': 60},
#    {'color': 'red', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 82.4,
#   'date': '8/24/2017'},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73},
#    {'color': 'black', 'price': 71},
#    {'color': 'white', 'price': 71},
#    {'color': 'red', 'price': 63},
#    {'color': 'brown', 'price': 60},
#    {'color': 'navy', 'price': 55},
#    {'color': 'light-pink', 'price': 55},
#    {'color': 'lime', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 64.0,
#   'date': '8/24/2017'},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '8/24/2017'},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 92},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'navy', 'price': 60},
#    {'color': 'royal', 'price': 75},
#    {'color': 'heather-grey', 'price': 75},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 73.0,
#   'date': '8/24/2017'},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'heather-grey', 'price': 79},
#    {'color': 'white', 'price': 95},
#    {'color': 'red', 'price': 79},
#    {'color': 'navy', 'price': 71},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'pale-blue', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 80.66666666666667,
#   'date': '9/21/2017'},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71},
#    {'color': 'black', 'price': 95},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 59},
#    {'color': 'brick', 'price': 70},
#    {'color': 'lime', 'price': 50},
#    {'color': 'pale-blue', 'price': 108},
#    {'color': 'navy', 'price': None}],
#   'average': 71.71428571428571,
#   'date': '9/21/2017'},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57},
#    {'color': 'black', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'pale-blue', 'price': 90},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'red', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 59.2,
#   'date': '9/21/2017'},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88}, {'color': 'black', 'price': 98}],
#   'average': 93.0,
#   'date': '9/21/2017'},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65}, {'color': 'white', 'price': 64}],
#   'average': 64.5,
#   'date': '9/21/2017'},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'heather-grey', 'price': 48},
#    {'color': 'lime', 'price': 50},
#    {'color': 'white', 'price': 50},
#    {'color': 'royal', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 48.75,
#   'date': '9/21/2017'},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266},
#    {'color': 'red', 'price': 221},
#    {'color': 'white', 'price': 233},
#    {'color': 'heather-grey', 'price': 200}],
#   'average': 230.0,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134},
#    {'color': 'black', 'price': 208},
#    {'color': 'white', 'price': 180},
#    {'color': 'red', 'price': 148}],
#   'average': 167.5,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 140},
#    {'color': 'red', 'price': 119}],
#   'average': 143.25,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144},
#    {'color': 'white', 'price': 120},
#    {'color': 'heather-grey', 'price': 108},
#    {'color': 'red', 'price': 125}],
#   'average': 124.25,
#   'date': '10/12/2017'},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253},
#    {'color': 'white', 'price': 273},
#    {'color': 'lime', 'price': 105},
#    {'color': 'cardinal', 'price': 132},
#    {'color': 'slate', 'price': 128}],
#   'average': 178.2,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230},
#    {'color': 'white', 'price': 190},
#    {'color': 'cardinal', 'price': 157},
#    {'color': 'slate', 'price': 153},
#    {'color': 'lime', 'price': 173}],
#   'average': 180.6,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 141},
#    {'color': 'slate', 'price': 120},
#    {'color': 'lime', 'price': 109}],
#   'average': 129.8,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150},
#    {'color': 'white', 'price': 116},
#    {'color': 'lime', 'price': 97},
#    {'color': 'slate', 'price': 127},
#    {'color': 'cardinal', 'price': 150}],
#   'average': 128.0,
#   'date': '11/2/2017'},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104},
#    {'color': 'black', 'price': 80},
#    {'color': 'dark-slate', 'price': 59},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': None},
#    {'color': 'olive-green', 'price': None}],
#   'average': 76.0,
#   'date': '11/16/2017'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': [],
#   'date': '11/30/2017'},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201},
#    {'color': 'white', 'price': 140},
#    {'color': 'heather-grey', 'price': 120},
#    {'color': 'lime', 'price': 110},
#    {'color': 'red', 'price': 150},
#    {'color': 'brown', 'price': 153},
#    {'color': 'dark-slate', 'price': 130},
#    {'color': 'bright-orange', 'price': 131}],
#   'average': 141.875,
#   'date': '12/14/2017'},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127},
#    {'color': 'navy', 'price': 121},
#    {'color': 'white', 'price': 104},
#    {'color': 'heather-grey', 'price': 105},
#    {'color': 'light-pink', 'price': 176},
#    {'color': 'mustard', 'price': 125},
#    {'color': 'red', 'price': 100},
#    {'color': 'brown', 'price': 70},
#    {'color': 'lime', 'price': 65}],
#   'average': 110.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133},
#    {'color': 'white', 'price': 127},
#    {'color': 'brick', 'price': 101},
#    {'color': 'green', 'price': 71},
#    {'color': 'light-purple', 'price': 105},
#    {'color': 'dark-slate', 'price': 85},
#    {'color': 'heather-grey', 'price': 50}],
#   'average': 96.0,
#   'date': '12/14/2017'},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93},
#    {'color': 'red', 'price': 69},
#    {'color': 'white', 'price': 89}],
#   'average': 83.66666666666667,
#   'date': '12/14/2017'},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'green', 'price': 63},
#    {'color': 'light-purple', 'price': 55},
#    {'color': 'navy', 'price': 50},
#    {'color': 'brick', 'price': None}],
#   'average': 78.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 39},
#    {'color': 'white', 'price': 51},
#    {'color': 'mustard', 'price': 44},
#    {'color': 'grey', 'price': 41},
#    {'color': 'light-purple', 'price': 65},
#    {'color': 'dark-slate', 'price': 54},
#    {'color': 'green', 'price': 54}],
#   'average': 52.625,
#   'date': '12/14/2017'},
#  {'name': 'Christmas Tee',
#   'search': 'supreme-christmas-tee-white',
#   'colors': [{'color': 'white', 'price': 72}],
#   'average': 72,
#   'date': '12/14/2017'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/15/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/15/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/15/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/15/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/15/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/15/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/15/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/15/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/15/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/15/2018'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/22/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/22/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/22/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/22/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/22/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/22/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/22/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/22/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/22/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/22/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89},
#    {'color': 'white', 'price': 86},
#    {'color': 'red', 'price': 69},
#    {'color': 'royal', 'price': 79}],
#   'average': 80.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 66}],
#   'average': 64.33333333333333,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 73},
#    {'color': 'royal', 'price': 81},
#    {'color': 'red', 'price': 66}],
#   'average': 76.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 74},
#    {'color': 'royal', 'price': 58}],
#   'average': 72.25,
#   'date': '3/15/2018'},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172},
#    {'color': 'white', 'price': 148},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'navy', 'price': 122},
#    {'color': 'red', 'price': 100},
#    {'color': 'light-purple', 'price': 143},
#    {'color': 'light-pink', 'price': 193},
#    {'color': 'pale-blue', 'price': 140},
#    {'color': 'bright-yellow', 'price': 130}],
#   'average': 138.66666666666666,
#   'date': '3/29/2018'},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129},
#    {'color': 'black', 'price': 125},
#    {'color': 'heather-grey', 'price': 78},
#    {'color': 'navy', 'price': 98},
#    {'color': 'pale-blue', 'price': 82},
#    {'color': 'green', 'price': 87},
#    {'color': 'red', 'price': 106},
#    {'color': 'bright-yellow', 'price': 61},
#    {'color': 'light-purple', 'price': 117}],
#   'average': 98.11111111111111,
#   'date': '3/29/2018'},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55},
#    {'color': 'black', 'price': 68},
#    {'color': 'white', 'price': 65},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 52},
#    {'color': 'bright-yellow', 'price': 58},
#    {'color': 'pale-blue', 'price': 73}],
#   'average': 60.5,
#   'date': '3/29/2018'},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'light-purple', 'price': 47},
#    {'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 53},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 66},
#    {'color': 'pale-blue', 'price': 54},
#    {'color': 'bright-yellow', 'price': 45},
#    {'color': 'green', 'price': 44}],
#   'average': 52.77777777777778,
#   'date': '3/29/2018'},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 53},
#    {'color': 'pale-blue', 'price': 65},
#    {'color': 'light-purple', 'price': 53},
#    {'color': 'bright-yellow', 'price': 43},
#    {'color': 'green', 'price': 45},
#    {'color': 'navy', 'price': 65}],
#   'average': 58.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'heather-grey', 'price': 70},
#    {'color': 'white', 'price': 79},
#    {'color': 'royal', 'price': 53},
#    {'color': 'red', 'price': 58},
#    {'color': 'pale-yellow', 'price': 20}],
#   'average': 59.666666666666664,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65},
#    {'color': 'red', 'price': 43},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 62.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62},
#    {'color': 'hot-pink', 'price': 35},
#    {'color': 'white', 'price': 52},
#    {'color': 'royal', 'price': 50},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 48.8,
#   'date': '3/29/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': [],
#   'date': '4/5/2018'},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98}, {'color': 'white', 'price': 90}],
#   'average': 94.0,
#   'date': '4/26/2018'},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'white', 'price': 81}],
#   'average': 91.0,
#   'date': '4/26/2018'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '5/31/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 81},
#    {'color': 'red', 'price': 71},
#    {'color': 'dark-green', 'price': 73},
#    {'color': 'light-purple', 'price': 84},
#    {'color': 'bright-orange', 'price': 68}],
#   'average': 74.0,
#   'date': '6/21/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'red', 'price': 58},
#    {'color': 'white', 'price': 84},
#    {'color': 'dark-green', 'price': 79},
#    {'color': 'bright-orange', 'price': 43},
#    {'color': 'light-purple', 'price': 75}],
#   'average': 67.14285714285714,
#   'date': '6/21/2018'},
#  {'name': 'Rocks Tee',
#   'search': 'supreme-Rocks-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white', 'price': 159},
#    {'color': 'black', 'price': 159},
#    {'color': 'red', 'price': 98},
#    {'color': 'ash-grey', 'price': 88},
#    {'color': 'light-purple', 'price': 92},
#    {'color': 'dark-slate', 'price': 101},
#    {'color': 'light-pink', 'price': 118},
#    {'color': 'orange', 'price': 96}],
#   'average': 113.875},
#  {'name': 'Mona Lisa Tee',
#   'search': 'supreme-Mona-Lisa-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 174},
#    {'color': 'white', 'price': 129},
#    {'color': 'hot-pink', 'price': 91},
#    {'color': 'pale-yellow', 'price': 98},
#    {'color': 'heather-grey', 'price': 91},
#    {'color': 'red', 'price': 123},
#    {'color': 'royal', 'price': 119},
#    {'color': 'light-purple', 'price': 69}],
#   'average': 111.75},
#  {'name': 'Tentacles Tee',
#   'search': 'supreme-Tentacles-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white', 'price': 147},
#    {'color': 'black', 'price': 128},
#    {'color': 'brick', 'price': 80},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'red', 'price': 89},
#    {'color': 'hot-pink', 'price': 82},
#    {'color': 'royal', 'price': 107},
#    {'color': 'pale-yellow', 'price': 96}],
#   'average': 103.625},
#  {'name': 'Swimmers Tee',
#   'search': 'supreme-Swimmers-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 74},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'red', 'price': 68},
#    {'color': 'mustard', 'price': 88},
#    {'color': 'dark-slate', 'price': 64},
#    {'color': 'light-pink', 'price': 134}],
#   'average': 82.14285714285714},
#  {'name': 'Ganesha Tee',
#   'search': 'supreme-Ganesha-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'light-pink', 'price': 105},
#    {'color': 'white', 'price': 76},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'brick', 'price': 63},
#    {'color': 'orange', 'price': 72},
#    {'color': 'dark-slate', 'price': 76}],
#   'average': 74.57142857142857},
#  {'name': 'Hardware Tee',
#   'search': 'supreme-Hardware-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 87},
#    {'color': 'ash-grey', 'price': 54},
#    {'color': 'red', 'price': 47},
#    {'color': 'royal', 'price': 59},
#    {'color': 'navy', 'price': 64},
#    {'color': 'pale-yellow', 'price': 58},
#    {'color': 'light-purple', 'price': 53}],
#   'average': 62.625},
#  {'name': 'Gonz Logo Tee',
#   'search': 'supreme-Gonz-Logo-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'warm-grey', 'price': 56},
#    {'color': 'red', 'price': 54},
#    {'color': 'heather-grey', 'price': 58},
#    {'color': 'royal', 'price': 49},
#    {'color': 'light-purple', 'price': 49},
#    {'color': 'mustard', 'price': 53}],
#   'average': 54.25},
#  {'name': 'Madonna Tee',
#   'search': 'supreme-Madonna-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 100},
#    {'color': 'black', 'price': 178},
#    {'color': 'dark-green', 'price': 102},
#    {'color': 'heather-grey', 'price': 109},
#    {'color': 'white', 'price': 167},
#    {'color': 'navy', 'price': 114},
#    {'color': 'red', 'price': 95},
#    {'color': 'pink', 'price': 97},
#    {'color': 'pale-yellow', 'price': 102}],
#   'average': 118.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Liquid Tee',
#   'search': 'supreme-Liquid-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 84},
#    {'color': 'navy', 'price': 76},
#    {'color': 'black', 'price': 94},
#    {'color': 'white', 'price': 88},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'burgundy', 'price': 71},
#    {'color': 'pink', 'price': 80},
#    {'color': 'natural', 'price': 76}],
#   'average': 79.5,
#   'date': '8/16/2018'},
#  {'name': 'Still Life Tee',
#   'search': 'supreme-Still-Life-Tee-black',
#   'colors': [{'color': 'red', 'price': 49},
#    {'color': 'bright-blue', 'price': 55},
#    {'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 62},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'pink', 'price': 87},
#    {'color': 'dark-green', 'price': 62}],
#   'average': 64.625,
#   'date': '8/16/2018'},
#  {'name': '1994 L/S Tee',
#   'search': 'supreme-1994-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'heather-grey', 'price': 88},
#    {'color': 'white', 'price': 102},
#    {'color': 'navy', 'price': 98},
#    {'color': 'natural', 'price': 101},
#    {'color': 'dark-green', 'price': 94},
#    {'color': 'burgundy', 'price': 83},
#    {'color': 'pink', 'price': 93},
#    {'color': 'red', 'price': 82}],
#   'average': 93.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Bottle Cap Tee',
#   'search': 'supreme-Bottle-Cap-Tee-black',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'white', 'price': 64},
#    {'color': 'red', 'price': 52},
#    {'color': 'bright-blue', 'price': 58},
#    {'color': 'navy', 'price': 63},
#    {'color': 'pale-yellow', 'price': 51},
#    {'color': 'pink', 'price': 62},
#    {'color': 'dark-green', 'price': 60}],
#   'average': 59.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Cutouts Tee',
#   'search': 'supreme-Cutouts-Tee-black',
#   'colors': [{'color': 'black', 'price': 75},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'bright-blue', 'price': 73},
#    {'color': 'pink', 'price': 56}],
#   'average': 60.75,
#   'date': '8/16/2018'},
#  {'name': 'Life Sucks Die Tee',
#   'search': 'supreme-Life-Sucks-Die-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 54},
#    {'color': 'black', 'price': 64},
#    {'color': 'red', 'price': 55},
#    {'color': 'natural', 'price': 66},
#    {'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 52},
#    {'color': 'dark-green', 'price': 77},
#    {'color': 'bright-blue', 'price': 48},
#    {'color': 'pink', 'price': 53}],
#   'average': 58.888888888888886,
#   'date': '8/16/2018'},
#  {'name': 'Bedroom Tee',
#   'search': 'supreme-Bedroom-Tee-black',
#   'colors': [{'color': 'navy', 'price': 59},
#    {'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 64},
#    {'color': 'light-pink', 'price': 80},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-green', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'natural', 'price': 70},
#    {'color': 'bright-blue', 'price': 51},
#    {'color': 'pink', 'price': 77}],
#   'average': 62.3,
#   'date': '8/16/2018'},
#  {'name': 'Fuck You Tee',
#   'search': 'supreme-Fuck-You-Tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'bright-blue', 'price': 53},
#    {'color': 'dark-green', 'price': 56},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 57},
#    {'color': 'orange', 'price': 62},
#    {'color': 'red', 'price': 58}],
#   'average': 59.5,
#   'date': '8/16/2018'},
#  {'name': 'Guts Tee',
#   'search': 'supreme-Guts-Tee-black',
#   'colors': [{'color': 'white', 'price': 57},
#    {'color': 'red', 'price': 47},
#    {'color': 'natural', 'price': 51},
#    {'color': 'black', 'price': 56},
#    {'color': 'navy', 'price': 51},
#    {'color': 'ash-grey', 'price': 50},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'bright-blue', 'price': 63},
#    {'color': 'pink', 'price': 56}],
#   'average': 54.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Mike Kelley/Supreme The Empire State Building Tee',
#   'search': 'supreme-mike-kelley-supreme-the-empire-state-building-tee-black',
#   'colors': [{'color': 'white', 'price': 66},
#    {'color': 'burgundy', 'price': 47},
#    {'color': 'ash-grey', 'price': 49},
#    {'color': 'black', 'price': 70},
#    {'color': 'dark-green', 'price': 49},
#    {'color': 'slate', 'price': 49},
#    {'color': 'clay', 'price': 51},
#    {'color': 'bright-orange', 'price': 51}],
#   'average': 54.0,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 77},
#    {'color': 'slate', 'price': 73},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'clay', 'price': 77},
#    {'color': 'black', 'price': 126},
#    {'color': 'white', 'price': 108},
#    {'color': 'dark-green', 'price': 84},
#    {'color': 'bright-orange', 'price': 94}],
#   'average': 89.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! L/S Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 166},
#    {'color': 'white', 'price': 134},
#    {'color': 'clay', 'price': 95},
#    {'color': 'ash-grey', 'price': 103},
#    {'color': 'slate', 'price': 93},
#    {'color': 'dark-green', 'price': 103},
#    {'color': 'burgundy', 'price': 104},
#    {'color': 'bright-orange', 'price': 105}],
#   'average': 112.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Hiding From Indians Tee',
#   'search': 'supreme-mike-kelley-supreme-hiding-from-indians-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 46},
#    {'color': 'black', 'price': 59},
#    {'color': 'clay', 'price': 55},
#    {'color': 'white', 'price': 58},
#    {'color': 'burgundy', 'price': 48},
#    {'color': 'bright-orange', 'price': 59},
#    {'color': 'dark-green', 'price': 61},
#    {'color': 'slate', 'price': 57}],
#   'average': 55.375,
#   'date': '9/6/2018'},
#  {'name': 'SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee',
#   'search': 'supreme-comme-des-garcons-shirt-split-box-logo-tee-black',
#   'colors': [],
#   'date': '9/13/2018'},
#  {'name': 'Group Tee',
#   'search': 'supreme-Group-Tee-black',
#   'colors': [{'color': 'slate', 'price': 65},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 82},
#    {'color': 'red', 'price': 76},
#    {'color': 'dark-pink', 'price': 76},
#    {'color': 'bright-orange', 'price': 68},
#    {'color': 'navy', 'price': 75},
#    {'color': 'dark-green', 'price': 72}],
#   'average': 74.0,
#   'date': '9/20/2018'},
#  {'name': 'Remember Tee',
#   'search': 'supreme-Remember-Tee-black',
#   'colors': [{'color': 'black', 'price': 81},
#    {'color': 'dark-pink', 'price': 63},
#    {'color': 'white', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'heather-grey', 'price': 74},
#    {'color': 'red', 'price': 68},
#    {'color': 'slate', 'price': 74},
#    {'color': 'bright-orange', 'price': 66}],
#   'average': 72.5,
#   'date': '9/20/2018'},
#  {'name': 'Liquid Swords Tee',
#   'search': 'supreme-Liquid-Swords-Tee-black',
#   'colors': [{'color': 'dark-green', 'price': 89},
#    {'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 81},
#    {'color': 'heather-grey', 'price': 81},
#    {'color': 'navy', 'price': 94},
#    {'color': 'slate', 'price': 96},
#    {'color': 'red', 'price': 80},
#    {'color': 'bright-orange', 'price': 85}],
#   'average': 88.125,
#   'date': '9/20/2018'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'black', 'price': 72},
#    {'color': 'slate', 'price': 65},
#    {'color': 'white', 'price': 63},
#    {'color': 'navy', 'price': 65},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'pale-yellow', 'price': 69},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-pink', 'price': 62}],
#   'average': 66.88888888888889,
#   'date': '9/20/2018'},
#  {'name': 'Payphone Tee',
#   'search': 'supreme-Payphone-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 52},
#    {'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 57},
#    {'color': 'natural', 'price': 53},
#    {'color': 'red', 'price': 48},
#    {'color': 'bright-orange', 'price': 48},
#    {'color': 'dark-pink', 'price': 47},
#    {'color': 'navy', 'price': 56},
#    {'color': 'slate', 'price': 61}],
#   'average': 53.0,
#   'date': '9/20/2018'},
#  {'name': 'Faces Tee',
#   'search': 'supreme-Faces-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'slate', 'price': 55},
#    {'color': 'dark-pink', 'price': 49},
#    {'color': 'bright-orange', 'price': 39},
#    {'color': 'navy', 'price': 59},
#    {'color': 'red', 'price': 51}],
#   'average': 51.625,
#   'date': '9/20/2018'},
#  {'name': 'System Tee',
#   'search': 'supreme-System-Tee-black',
#   'colors': [{'color': 'black', 'price': 45},
#    {'color': 'ash-grey', 'price': 40},
#    {'color': 'white', 'price': 49},
#    {'color': 'navy', 'price': 45},
#    {'color': 'dark-pink', 'price': 40},
#    {'color': 'slate', 'price': 44},
#    {'color': 'bright-orange', 'price': 42},
#    {'color': 'burgundy', 'price': 41}],
#   'average': 43.25,
#   'date': '9/20/2018'},
#  {'name': 'The Killer Trust Tee',
#   'search': 'supreme-The-Killer-Trust-Tee-black',
#   'colors': [{'color': 'black', 'price': 238},
#    {'color': 'olive', 'price': 147},
#    {'color': 'white', 'price': 183},
# ...
#    {'color': 'light-pink', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'light-blue', 'price': 82},
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5,
#   'date': '6/27/2019'},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444,
#   'date': '6/27/2019'},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75,
#   'date': '6/27/2019'},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75,
#   'date': '6/27/2019'},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375,
#   'date': '6/27/2019'},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25,
#   'date': '6/27/2019'},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75,
#   'date': '6/27/2019'},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375,
#   'date': '6/27/2019'},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875,
#   'date': '8/22/2019'},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857,
#   'date': '8/22/2019'},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5,
#   'date': '8/22/2019'},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285,
#   'date': '8/22/2019'},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0,
#   'date': '8/22/2019'},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0,
#   'date': '8/22/2019'},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125,
#   'date': '8/22/2019'},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854,
#   'date': '8/22/2019'},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5,
#   'date': '8/22/2019'},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143,
#   'date': '8/22/2019'},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2,
#   'date': '9/19/2019'},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429,
#   'date': '10/10/2019'},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375,
#   'date': '10/10/2019'},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25,
#   'date': '10/10/2019'},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285,
#   'date': '10/10/2019'},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125,
#   'date': '10/10/2019'},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146,
#   'date': '10/10/2019'},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5,
#   'date': '10/10/2019'},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875,
#   'date': '10/10/2019'},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336,
#   'date': '10/10/2019'},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0,
#   'date': '10/24/2019'},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6,
#   'date': '12/5/2019'},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4,
#   'date': '12/5/2019'},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25,
#   'date': '12/19/2019'},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854,
#   'date': '12/19/2019'},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285,
#   'date': '12/19/2019'},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0,
#   'date': '12/19/2019'},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875,
#   'date': '12/19/2019'},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0,
#   'date': '12/19/2019'},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5,
#   'date': '12/19/2019'},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664,
#   'date': '12/19/2019'}]

# %%
len(complete)
# Out:
# 194

# %%
colorset = set()
for c in complete:
    for color in c['colors']:
        colorset.add(color['color'])

# %%
def list_with_color(lst, colors):
    colorlist = []
    for entry in lst:
        for c in entry['colors']:
            if c['color'] in colors and c['color'][:
                colorlist.append(entry)
    return colorlist

def find_most_popular_colors(lst, cset):
    popular = []
    for color in cset:
        popular.append({'amount': len(list_with_color(lst, color)), 'name': color})
    popular = sorted(popular, key=lambda x: x['amount'])[:-1]
    popular.reverse()
    return popular

# %%
len(list_with_color(complete, {'white'}))
# Out:
# 187

# %%
colorset
# Out:
# {'acid-yellow',
#  'aqua',
#  'ash-grey',
#  'black',
#  'blue',
#  'brick',
#  'bright-blue',
#  'bright-coral',
#  'bright-orange',
#  'bright-yellow',
#  'brown',
#  'burgundy',
#  'burnt-orange',
#  'cardinal',
#  'clay',
#  'cyan',
#  'dark-green',
#  'dark-pink',
#  'dark-sage',
#  'dark-slate',
#  'dusty-pink',
#  'dusty-teal',
#  'green',
#  'grey',
#  'heather-grey',
#  'heather-light-pink',
#  'hot-pink',
#  'light-blue',
#  'light-brown',
#  'light-green',
#  'light-pink',
#  'light-purple',
#  'light-slate',
#  'lime',
#  'lime-green',
#  'lt-green',
#  'lt-pink',
#  'lt-teal',
#  'magenta',
#  'mint',
#  'mocha',
#  'mustard',
#  'natural',
#  'navy',
#  'neon-green',
#  'neon-orange',
#  'olive',
#  'olive-green',
#  'orange',
#  'pale-blue',
#  'pale-mint',
#  'pale-pink',
#  'pale-yellow',
#  'peach',
#  'pink',
#  'purple',
#  'red',
#  'royal',
#  'rust',
#  'slate',
#  'sulfer',
#  'sulfur',
#  'taupe',
#  'teal',
#  'warm-grey',
#  'white',
#  'woodland-camo',
#  'yellow'}

# %%
most_popular_colors = find_most_popular_colors(complete, colorset)

# %% [markdown]
# colorset

# %%
complete
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208},
#    {'color': 'black', 'price': 246},
#    {'color': 'white', 'price': 212},
#    {'color': 'heather-grey', 'price': 172},
#    {'color': 'navy', 'price': 191},
#    {'color': 'lime-green', 'price': 218},
#    {'color': 'lt-pink', 'price': 196},
#    {'color': 'aqua', 'price': 189},
#    {'color': 'red', 'price': None}],
#   'average': 204.0,
#   'date': '2/16/2017'},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318},
#    {'color': 'grey', 'price': 121},
#    {'color': 'white', 'price': 233},
#    {'color': 'black', 'price': 315},
#    {'color': 'lt-green', 'price': 165},
#    {'color': 'mocha', 'price': 150},
#    {'color': 'aqua', 'price': 180},
#    {'color': 'red', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 211.71428571428572,
#   'date': '2/16/2017'},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107},
#    {'color': 'navy', 'price': 110},
#    {'color': 'black', 'price': 138},
#    {'color': 'red', 'price': 95},
#    {'color': 'bright-coral', 'price': 80},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'mocha', 'price': None}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '2/16/2017'},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61},
#    {'color': 'black', 'price': 127},
#    {'color': 'white', 'price': 146},
#    {'color': 'lt-teal', 'price': 90},
#    {'color': 'mocha', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'red', 'price': 115},
#    {'color': 'lt-pink', 'price': None}],
#   'average': 107.8,
#   'date': '2/16/2017'},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'bright-coral', 'price': 44},
#    {'color': 'navy', 'price': 70},
#    {'color': 'mocha', 'price': 46},
#    {'color': 'white', 'price': 66},
#    {'color': 'aqua', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 60.8,
#   'date': '2/16/2017'},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120},
#    {'color': 'red', 'price': 90},
#    {'color': 'white', 'price': 145},
#    {'color': 'navy', 'price': 83},
#    {'color': 'grey', 'price': 65},
#    {'color': 'mocha', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'aqua', 'price': 133}],
#   'average': 106.0,
#   'date': '2/16/2017'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '2/16/2017'},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137},
#    {'color': 'white', 'price': 137},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 137.0,
#   'date': '2/16/2017'},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 90},
#    {'color': 'heather-grey', 'price': 71},
#    {'color': 'pale-pink', 'price': 72},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 79.0,
#   'date': '2/16/2017'},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95},
#    {'color': 'white', 'price': 73},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'black', 'price': 60},
#    {'color': 'light-blue', 'price': 91},
#    {'color': 'navy', 'price': 50},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 76.5,
#   'date': '6/29/2017'},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84},
#    {'color': 'black', 'price': 76},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 66},
#    {'color': 'hot-pink', 'price': 50},
#    {'color': 'orange', 'price': 64},
#    {'color': 'light-blue', 'price': None},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'navy', 'price': 64}],
#   'average': 65.85714285714286,
#   'date': '6/29/2017'},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 55},
#    {'color': 'navy', 'price': 57},
#    {'color': 'red', 'price': 40},
#    {'color': 'teal', 'price': 55},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 57.0,
#   'date': '6/29/2017'},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'navy', 'price': 95},
#    {'color': 'white', 'price': 99},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'orange', 'price': None}],
#   'average': 98.33333333333333,
#   'date': '6/29/2017'},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 56},
#    {'color': 'teal', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 77.5,
#   'date': '6/29/2017'},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88},
#    {'color': 'heather-grey', 'price': 64},
#    {'color': 'white', 'price': 75},
#    {'color': 'navy', 'price': 66},
#    {'color': 'red', 'price': 53},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'dusty-pink', 'price': 60}],
#   'average': 67.66666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'black', 'price': 75},
#    {'color': 'lime', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'light-brown', 'price': None}],
#   'average': 64.75,
#   'date': '6/29/2017'},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76},
#    {'color': 'orange', 'price': 60},
#    {'color': 'black', 'price': 87},
#    {'color': 'red', 'price': 72},
#    {'color': 'dark-pink', 'price': 48},
#    {'color': 'teal', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'pale-yellow', 'price': 48}],
#   'average': 65.16666666666667,
#   'date': '6/29/2017'},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238},
#    {'color': 'black', 'price': 297},
#    {'color': 'heather-grey', 'price': 224},
#    {'color': 'pale-blue', 'price': 224},
#    {'color': 'red', 'price': 226},
#    {'color': 'brown', 'price': 266},
#    {'color': 'lime', 'price': 201}],
#   'average': 239.42857142857142,
#   'date': '8/24/2017'},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175},
#    {'color': 'white', 'price': 162},
#    {'color': 'heather-grey', 'price': 110},
#    {'color': 'red', 'price': 123},
#    {'color': 'bright-orange', 'price': 93},
#    {'color': 'navy', 'price': 108},
#    {'color': 'royal', 'price': 208},
#    {'color': 'lime', 'price': 70},
#    {'color': 'brown', 'price': None}],
#   'average': 131.125,
#   'date': '8/24/2017'},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'red', 'price': 100},
#    {'color': 'white', 'price': 116},
#    {'color': 'heather-grey', 'price': 95},
#    {'color': 'navy', 'price': 89},
#    {'color': 'lime', 'price': 61},
#    {'color': 'bright-orange', 'price': 121},
#    {'color': 'brown', 'price': 80}],
#   'average': 101.875,
#   'date': '8/24/2017'},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'white', 'price': 82},
#    {'color': 'navy', 'price': 72},
#    {'color': 'light-pink', 'price': 63},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 75.5,
#   'date': '8/24/2017'},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 50},
#    {'color': 'brown', 'price': 100},
#    {'color': 'lime', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 83.0,
#   'date': '8/24/2017'},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58},
#    {'color': 'black', 'price': 113},
#    {'color': 'white', 'price': 122},
#    {'color': 'navy', 'price': 59},
#    {'color': 'lime', 'price': 60},
#    {'color': 'red', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 82.4,
#   'date': '8/24/2017'},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73},
#    {'color': 'black', 'price': 71},
#    {'color': 'white', 'price': 71},
#    {'color': 'red', 'price': 63},
#    {'color': 'brown', 'price': 60},
#    {'color': 'navy', 'price': 55},
#    {'color': 'light-pink', 'price': 55},
#    {'color': 'lime', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 64.0,
#   'date': '8/24/2017'},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '8/24/2017'},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 92},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'navy', 'price': 60},
#    {'color': 'royal', 'price': 75},
#    {'color': 'heather-grey', 'price': 75},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 73.0,
#   'date': '8/24/2017'},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'heather-grey', 'price': 79},
#    {'color': 'white', 'price': 95},
#    {'color': 'red', 'price': 79},
#    {'color': 'navy', 'price': 71},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'pale-blue', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 80.66666666666667,
#   'date': '9/21/2017'},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71},
#    {'color': 'black', 'price': 95},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 59},
#    {'color': 'brick', 'price': 70},
#    {'color': 'lime', 'price': 50},
#    {'color': 'pale-blue', 'price': 108},
#    {'color': 'navy', 'price': None}],
#   'average': 71.71428571428571,
#   'date': '9/21/2017'},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57},
#    {'color': 'black', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'pale-blue', 'price': 90},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'red', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 59.2,
#   'date': '9/21/2017'},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88}, {'color': 'black', 'price': 98}],
#   'average': 93.0,
#   'date': '9/21/2017'},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65}, {'color': 'white', 'price': 64}],
#   'average': 64.5,
#   'date': '9/21/2017'},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'heather-grey', 'price': 48},
#    {'color': 'lime', 'price': 50},
#    {'color': 'white', 'price': 50},
#    {'color': 'royal', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 48.75,
#   'date': '9/21/2017'},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266},
#    {'color': 'red', 'price': 221},
#    {'color': 'white', 'price': 233},
#    {'color': 'heather-grey', 'price': 200}],
#   'average': 230.0,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134},
#    {'color': 'black', 'price': 208},
#    {'color': 'white', 'price': 180},
#    {'color': 'red', 'price': 148}],
#   'average': 167.5,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 140},
#    {'color': 'red', 'price': 119}],
#   'average': 143.25,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144},
#    {'color': 'white', 'price': 120},
#    {'color': 'heather-grey', 'price': 108},
#    {'color': 'red', 'price': 125}],
#   'average': 124.25,
#   'date': '10/12/2017'},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253},
#    {'color': 'white', 'price': 273},
#    {'color': 'lime', 'price': 105},
#    {'color': 'cardinal', 'price': 132},
#    {'color': 'slate', 'price': 128}],
#   'average': 178.2,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230},
#    {'color': 'white', 'price': 190},
#    {'color': 'cardinal', 'price': 157},
#    {'color': 'slate', 'price': 153},
#    {'color': 'lime', 'price': 173}],
#   'average': 180.6,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 141},
#    {'color': 'slate', 'price': 120},
#    {'color': 'lime', 'price': 109}],
#   'average': 129.8,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150},
#    {'color': 'white', 'price': 116},
#    {'color': 'lime', 'price': 97},
#    {'color': 'slate', 'price': 127},
#    {'color': 'cardinal', 'price': 150}],
#   'average': 128.0,
#   'date': '11/2/2017'},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104},
#    {'color': 'black', 'price': 80},
#    {'color': 'dark-slate', 'price': 59},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': None},
#    {'color': 'olive-green', 'price': None}],
#   'average': 76.0,
#   'date': '11/16/2017'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': [],
#   'date': '11/30/2017'},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201},
#    {'color': 'white', 'price': 140},
#    {'color': 'heather-grey', 'price': 120},
#    {'color': 'lime', 'price': 110},
#    {'color': 'red', 'price': 150},
#    {'color': 'brown', 'price': 153},
#    {'color': 'dark-slate', 'price': 130},
#    {'color': 'bright-orange', 'price': 131}],
#   'average': 141.875,
#   'date': '12/14/2017'},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127},
#    {'color': 'navy', 'price': 121},
#    {'color': 'white', 'price': 104},
#    {'color': 'heather-grey', 'price': 105},
#    {'color': 'light-pink', 'price': 176},
#    {'color': 'mustard', 'price': 125},
#    {'color': 'red', 'price': 100},
#    {'color': 'brown', 'price': 70},
#    {'color': 'lime', 'price': 65}],
#   'average': 110.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133},
#    {'color': 'white', 'price': 127},
#    {'color': 'brick', 'price': 101},
#    {'color': 'green', 'price': 71},
#    {'color': 'light-purple', 'price': 105},
#    {'color': 'dark-slate', 'price': 85},
#    {'color': 'heather-grey', 'price': 50}],
#   'average': 96.0,
#   'date': '12/14/2017'},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93},
#    {'color': 'red', 'price': 69},
#    {'color': 'white', 'price': 89}],
#   'average': 83.66666666666667,
#   'date': '12/14/2017'},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'green', 'price': 63},
#    {'color': 'light-purple', 'price': 55},
#    {'color': 'navy', 'price': 50},
#    {'color': 'brick', 'price': None}],
#   'average': 78.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 39},
#    {'color': 'white', 'price': 51},
#    {'color': 'mustard', 'price': 44},
#    {'color': 'grey', 'price': 41},
#    {'color': 'light-purple', 'price': 65},
#    {'color': 'dark-slate', 'price': 54},
#    {'color': 'green', 'price': 54}],
#   'average': 52.625,
#   'date': '12/14/2017'},
#  {'name': 'Christmas Tee',
#   'search': 'supreme-christmas-tee-white',
#   'colors': [{'color': 'white', 'price': 72}],
#   'average': 72,
#   'date': '12/14/2017'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/15/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/15/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/15/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/15/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/15/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/15/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/15/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/15/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/15/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/15/2018'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/22/2018'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/22/2018'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/22/2018'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/22/2018'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/22/2018'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/22/2018'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/22/2018'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/22/2018'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/22/2018'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/22/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89},
#    {'color': 'white', 'price': 86},
#    {'color': 'red', 'price': 69},
#    {'color': 'royal', 'price': 79}],
#   'average': 80.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 66}],
#   'average': 64.33333333333333,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 73},
#    {'color': 'royal', 'price': 81},
#    {'color': 'red', 'price': 66}],
#   'average': 76.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 74},
#    {'color': 'royal', 'price': 58}],
#   'average': 72.25,
#   'date': '3/15/2018'},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172},
#    {'color': 'white', 'price': 148},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'navy', 'price': 122},
#    {'color': 'red', 'price': 100},
#    {'color': 'light-purple', 'price': 143},
#    {'color': 'light-pink', 'price': 193},
#    {'color': 'pale-blue', 'price': 140},
#    {'color': 'bright-yellow', 'price': 130}],
#   'average': 138.66666666666666,
#   'date': '3/29/2018'},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129},
#    {'color': 'black', 'price': 125},
#    {'color': 'heather-grey', 'price': 78},
#    {'color': 'navy', 'price': 98},
#    {'color': 'pale-blue', 'price': 82},
#    {'color': 'green', 'price': 87},
#    {'color': 'red', 'price': 106},
#    {'color': 'bright-yellow', 'price': 61},
#    {'color': 'light-purple', 'price': 117}],
#   'average': 98.11111111111111,
#   'date': '3/29/2018'},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55},
#    {'color': 'black', 'price': 68},
#    {'color': 'white', 'price': 65},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 52},
#    {'color': 'bright-yellow', 'price': 58},
#    {'color': 'pale-blue', 'price': 73}],
#   'average': 60.5,
#   'date': '3/29/2018'},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'light-purple', 'price': 47},
#    {'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 53},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 66},
#    {'color': 'pale-blue', 'price': 54},
#    {'color': 'bright-yellow', 'price': 45},
#    {'color': 'green', 'price': 44}],
#   'average': 52.77777777777778,
#   'date': '3/29/2018'},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 53},
#    {'color': 'pale-blue', 'price': 65},
#    {'color': 'light-purple', 'price': 53},
#    {'color': 'bright-yellow', 'price': 43},
#    {'color': 'green', 'price': 45},
#    {'color': 'navy', 'price': 65}],
#   'average': 58.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'heather-grey', 'price': 70},
#    {'color': 'white', 'price': 79},
#    {'color': 'royal', 'price': 53},
#    {'color': 'red', 'price': 58},
#    {'color': 'pale-yellow', 'price': 20}],
#   'average': 59.666666666666664,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65},
#    {'color': 'red', 'price': 43},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 62.0,
#   'date': '3/29/2018'},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62},
#    {'color': 'hot-pink', 'price': 35},
#    {'color': 'white', 'price': 52},
#    {'color': 'royal', 'price': 50},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 48.8,
#   'date': '3/29/2018'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': [],
#   'date': '4/5/2018'},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98}, {'color': 'white', 'price': 90}],
#   'average': 94.0,
#   'date': '4/26/2018'},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'white', 'price': 81}],
#   'average': 91.0,
#   'date': '4/26/2018'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '5/31/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 81},
#    {'color': 'red', 'price': 71},
#    {'color': 'dark-green', 'price': 73},
#    {'color': 'light-purple', 'price': 84},
#    {'color': 'bright-orange', 'price': 68}],
#   'average': 74.0,
#   'date': '6/21/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'red', 'price': 58},
#    {'color': 'white', 'price': 84},
#    {'color': 'dark-green', 'price': 79},
#    {'color': 'bright-orange', 'price': 43},
#    {'color': 'light-purple', 'price': 75}],
#   'average': 67.14285714285714,
#   'date': '6/21/2018'},
#  {'name': 'Rocks Tee',
#   'search': 'supreme-Rocks-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white', 'price': 159},
#    {'color': 'black', 'price': 159},
#    {'color': 'red', 'price': 98},
#    {'color': 'ash-grey', 'price': 88},
#    {'color': 'light-purple', 'price': 92},
#    {'color': 'dark-slate', 'price': 101},
#    {'color': 'light-pink', 'price': 118},
#    {'color': 'orange', 'price': 96}],
#   'average': 113.875},
#  {'name': 'Mona Lisa Tee',
#   'search': 'supreme-Mona-Lisa-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 174},
#    {'color': 'white', 'price': 129},
#    {'color': 'hot-pink', 'price': 91},
#    {'color': 'pale-yellow', 'price': 98},
#    {'color': 'heather-grey', 'price': 91},
#    {'color': 'red', 'price': 123},
#    {'color': 'royal', 'price': 119},
#    {'color': 'light-purple', 'price': 69}],
#   'average': 111.75},
#  {'name': 'Tentacles Tee',
#   'search': 'supreme-Tentacles-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white', 'price': 147},
#    {'color': 'black', 'price': 128},
#    {'color': 'brick', 'price': 80},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'red', 'price': 89},
#    {'color': 'hot-pink', 'price': 82},
#    {'color': 'royal', 'price': 107},
#    {'color': 'pale-yellow', 'price': 96}],
#   'average': 103.625},
#  {'name': 'Swimmers Tee',
#   'search': 'supreme-Swimmers-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 74},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'red', 'price': 68},
#    {'color': 'mustard', 'price': 88},
#    {'color': 'dark-slate', 'price': 64},
#    {'color': 'light-pink', 'price': 134}],
#   'average': 82.14285714285714},
#  {'name': 'Ganesha Tee',
#   'search': 'supreme-Ganesha-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'light-pink', 'price': 105},
#    {'color': 'white', 'price': 76},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'brick', 'price': 63},
#    {'color': 'orange', 'price': 72},
#    {'color': 'dark-slate', 'price': 76}],
#   'average': 74.57142857142857},
#  {'name': 'Hardware Tee',
#   'search': 'supreme-Hardware-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 87},
#    {'color': 'ash-grey', 'price': 54},
#    {'color': 'red', 'price': 47},
#    {'color': 'royal', 'price': 59},
#    {'color': 'navy', 'price': 64},
#    {'color': 'pale-yellow', 'price': 58},
#    {'color': 'light-purple', 'price': 53}],
#   'average': 62.625},
#  {'name': 'Gonz Logo Tee',
#   'search': 'supreme-Gonz-Logo-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'warm-grey', 'price': 56},
#    {'color': 'red', 'price': 54},
#    {'color': 'heather-grey', 'price': 58},
#    {'color': 'royal', 'price': 49},
#    {'color': 'light-purple', 'price': 49},
#    {'color': 'mustard', 'price': 53}],
#   'average': 54.25},
#  {'name': 'Madonna Tee',
#   'search': 'supreme-Madonna-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 100},
#    {'color': 'black', 'price': 178},
#    {'color': 'dark-green', 'price': 102},
#    {'color': 'heather-grey', 'price': 109},
#    {'color': 'white', 'price': 167},
#    {'color': 'navy', 'price': 114},
#    {'color': 'red', 'price': 95},
#    {'color': 'pink', 'price': 97},
#    {'color': 'pale-yellow', 'price': 102}],
#   'average': 118.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Liquid Tee',
#   'search': 'supreme-Liquid-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 84},
#    {'color': 'navy', 'price': 76},
#    {'color': 'black', 'price': 94},
#    {'color': 'white', 'price': 88},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'burgundy', 'price': 71},
#    {'color': 'pink', 'price': 80},
#    {'color': 'natural', 'price': 76}],
#   'average': 79.5,
#   'date': '8/16/2018'},
#  {'name': 'Still Life Tee',
#   'search': 'supreme-Still-Life-Tee-black',
#   'colors': [{'color': 'red', 'price': 49},
#    {'color': 'bright-blue', 'price': 55},
#    {'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 62},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'pink', 'price': 87},
#    {'color': 'dark-green', 'price': 62}],
#   'average': 64.625,
#   'date': '8/16/2018'},
#  {'name': '1994 L/S Tee',
#   'search': 'supreme-1994-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'heather-grey', 'price': 88},
#    {'color': 'white', 'price': 102},
#    {'color': 'navy', 'price': 98},
#    {'color': 'natural', 'price': 101},
#    {'color': 'dark-green', 'price': 94},
#    {'color': 'burgundy', 'price': 83},
#    {'color': 'pink', 'price': 93},
#    {'color': 'red', 'price': 82}],
#   'average': 93.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Bottle Cap Tee',
#   'search': 'supreme-Bottle-Cap-Tee-black',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'white', 'price': 64},
#    {'color': 'red', 'price': 52},
#    {'color': 'bright-blue', 'price': 58},
#    {'color': 'navy', 'price': 63},
#    {'color': 'pale-yellow', 'price': 51},
#    {'color': 'pink', 'price': 62},
#    {'color': 'dark-green', 'price': 60}],
#   'average': 59.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Cutouts Tee',
#   'search': 'supreme-Cutouts-Tee-black',
#   'colors': [{'color': 'black', 'price': 75},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'bright-blue', 'price': 73},
#    {'color': 'pink', 'price': 56}],
#   'average': 60.75,
#   'date': '8/16/2018'},
#  {'name': 'Life Sucks Die Tee',
#   'search': 'supreme-Life-Sucks-Die-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 54},
#    {'color': 'black', 'price': 64},
#    {'color': 'red', 'price': 55},
#    {'color': 'natural', 'price': 66},
#    {'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 52},
#    {'color': 'dark-green', 'price': 77},
#    {'color': 'bright-blue', 'price': 48},
#    {'color': 'pink', 'price': 53}],
#   'average': 58.888888888888886,
#   'date': '8/16/2018'},
#  {'name': 'Bedroom Tee',
#   'search': 'supreme-Bedroom-Tee-black',
#   'colors': [{'color': 'navy', 'price': 59},
#    {'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 64},
#    {'color': 'light-pink', 'price': 80},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-green', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'natural', 'price': 70},
#    {'color': 'bright-blue', 'price': 51},
#    {'color': 'pink', 'price': 77}],
#   'average': 62.3,
#   'date': '8/16/2018'},
#  {'name': 'Fuck You Tee',
#   'search': 'supreme-Fuck-You-Tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'bright-blue', 'price': 53},
#    {'color': 'dark-green', 'price': 56},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 57},
#    {'color': 'orange', 'price': 62},
#    {'color': 'red', 'price': 58}],
#   'average': 59.5,
#   'date': '8/16/2018'},
#  {'name': 'Guts Tee',
#   'search': 'supreme-Guts-Tee-black',
#   'colors': [{'color': 'white', 'price': 57},
#    {'color': 'red', 'price': 47},
#    {'color': 'natural', 'price': 51},
#    {'color': 'black', 'price': 56},
#    {'color': 'navy', 'price': 51},
#    {'color': 'ash-grey', 'price': 50},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'bright-blue', 'price': 63},
#    {'color': 'pink', 'price': 56}],
#   'average': 54.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Mike Kelley/Supreme The Empire State Building Tee',
#   'search': 'supreme-mike-kelley-supreme-the-empire-state-building-tee-black',
#   'colors': [{'color': 'white', 'price': 66},
#    {'color': 'burgundy', 'price': 47},
#    {'color': 'ash-grey', 'price': 49},
#    {'color': 'black', 'price': 70},
#    {'color': 'dark-green', 'price': 49},
#    {'color': 'slate', 'price': 49},
#    {'color': 'clay', 'price': 51},
#    {'color': 'bright-orange', 'price': 51}],
#   'average': 54.0,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 77},
#    {'color': 'slate', 'price': 73},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'clay', 'price': 77},
#    {'color': 'black', 'price': 126},
#    {'color': 'white', 'price': 108},
#    {'color': 'dark-green', 'price': 84},
#    {'color': 'bright-orange', 'price': 94}],
#   'average': 89.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! L/S Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 166},
#    {'color': 'white', 'price': 134},
#    {'color': 'clay', 'price': 95},
#    {'color': 'ash-grey', 'price': 103},
#    {'color': 'slate', 'price': 93},
#    {'color': 'dark-green', 'price': 103},
#    {'color': 'burgundy', 'price': 104},
#    {'color': 'bright-orange', 'price': 105}],
#   'average': 112.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Hiding From Indians Tee',
#   'search': 'supreme-mike-kelley-supreme-hiding-from-indians-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 46},
#    {'color': 'black', 'price': 59},
#    {'color': 'clay', 'price': 55},
#    {'color': 'white', 'price': 58},
#    {'color': 'burgundy', 'price': 48},
#    {'color': 'bright-orange', 'price': 59},
#    {'color': 'dark-green', 'price': 61},
#    {'color': 'slate', 'price': 57}],
#   'average': 55.375,
#   'date': '9/6/2018'},
#  {'name': 'SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee',
#   'search': 'supreme-comme-des-garcons-shirt-split-box-logo-tee-black',
#   'colors': [],
#   'date': '9/13/2018'},
#  {'name': 'Group Tee',
#   'search': 'supreme-Group-Tee-black',
#   'colors': [{'color': 'slate', 'price': 65},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 82},
#    {'color': 'red', 'price': 76},
#    {'color': 'dark-pink', 'price': 76},
#    {'color': 'bright-orange', 'price': 68},
#    {'color': 'navy', 'price': 75},
#    {'color': 'dark-green', 'price': 72}],
#   'average': 74.0,
#   'date': '9/20/2018'},
#  {'name': 'Remember Tee',
#   'search': 'supreme-Remember-Tee-black',
#   'colors': [{'color': 'black', 'price': 81},
#    {'color': 'dark-pink', 'price': 63},
#    {'color': 'white', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'heather-grey', 'price': 74},
#    {'color': 'red', 'price': 68},
#    {'color': 'slate', 'price': 74},
#    {'color': 'bright-orange', 'price': 66}],
#   'average': 72.5,
#   'date': '9/20/2018'},
#  {'name': 'Liquid Swords Tee',
#   'search': 'supreme-Liquid-Swords-Tee-black',
#   'colors': [{'color': 'dark-green', 'price': 89},
#    {'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 81},
#    {'color': 'heather-grey', 'price': 81},
#    {'color': 'navy', 'price': 94},
#    {'color': 'slate', 'price': 96},
#    {'color': 'red', 'price': 80},
#    {'color': 'bright-orange', 'price': 85}],
#   'average': 88.125,
#   'date': '9/20/2018'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'black', 'price': 72},
#    {'color': 'slate', 'price': 65},
#    {'color': 'white', 'price': 63},
#    {'color': 'navy', 'price': 65},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'pale-yellow', 'price': 69},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-pink', 'price': 62}],
#   'average': 66.88888888888889,
#   'date': '9/20/2018'},
#  {'name': 'Payphone Tee',
#   'search': 'supreme-Payphone-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 52},
#    {'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 57},
#    {'color': 'natural', 'price': 53},
#    {'color': 'red', 'price': 48},
#    {'color': 'bright-orange', 'price': 48},
#    {'color': 'dark-pink', 'price': 47},
#    {'color': 'navy', 'price': 56},
#    {'color': 'slate', 'price': 61}],
#   'average': 53.0,
#   'date': '9/20/2018'},
#  {'name': 'Faces Tee',
#   'search': 'supreme-Faces-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'slate', 'price': 55},
#    {'color': 'dark-pink', 'price': 49},
#    {'color': 'bright-orange', 'price': 39},
#    {'color': 'navy', 'price': 59},
#    {'color': 'red', 'price': 51}],
#   'average': 51.625,
#   'date': '9/20/2018'},
#  {'name': 'System Tee',
#   'search': 'supreme-System-Tee-black',
#   'colors': [{'color': 'black', 'price': 45},
#    {'color': 'ash-grey', 'price': 40},
#    {'color': 'white', 'price': 49},
#    {'color': 'navy', 'price': 45},
#    {'color': 'dark-pink', 'price': 40},
#    {'color': 'slate', 'price': 44},
#    {'color': 'bright-orange', 'price': 42},
#    {'color': 'burgundy', 'price': 41}],
#   'average': 43.25,
#   'date': '9/20/2018'},
#  {'name': 'The Killer Trust Tee',
#   'search': 'supreme-The-Killer-Trust-Tee-black',
#   'colors': [{'color': 'black', 'price': 238},
#    {'color': 'olive', 'price': 147},
#    {'color': 'white', 'price': 183},
# ...
#    {'color': 'light-pink', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'light-blue', 'price': 82},
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5,
#   'date': '6/27/2019'},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444,
#   'date': '6/27/2019'},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75,
#   'date': '6/27/2019'},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75,
#   'date': '6/27/2019'},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375,
#   'date': '6/27/2019'},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25,
#   'date': '6/27/2019'},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75,
#   'date': '6/27/2019'},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375,
#   'date': '6/27/2019'},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875,
#   'date': '8/22/2019'},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857,
#   'date': '8/22/2019'},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5,
#   'date': '8/22/2019'},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285,
#   'date': '8/22/2019'},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0,
#   'date': '8/22/2019'},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0,
#   'date': '8/22/2019'},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125,
#   'date': '8/22/2019'},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854,
#   'date': '8/22/2019'},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5,
#   'date': '8/22/2019'},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143,
#   'date': '8/22/2019'},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2,
#   'date': '9/19/2019'},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429,
#   'date': '10/10/2019'},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375,
#   'date': '10/10/2019'},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25,
#   'date': '10/10/2019'},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285,
#   'date': '10/10/2019'},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125,
#   'date': '10/10/2019'},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146,
#   'date': '10/10/2019'},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5,
#   'date': '10/10/2019'},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875,
#   'date': '10/10/2019'},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336,
#   'date': '10/10/2019'},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0,
#   'date': '10/24/2019'},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6,
#   'date': '12/5/2019'},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4,
#   'date': '12/5/2019'},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25,
#   'date': '12/19/2019'},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854,
#   'date': '12/19/2019'},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285,
#   'date': '12/19/2019'},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0,
#   'date': '12/19/2019'},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875,
#   'date': '12/19/2019'},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0,
#   'date': '12/19/2019'},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5,
#   'date': '12/19/2019'},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664,
#   'date': '12/19/2019'}]

# %%
black = list_with_color(complete, 'black')
red = list_with_color(complete, 'red')
navy = list_with_color(complete, 'navy')
heatherGrey = list_with_color(complete, 'heather-grey')
white = list_with_color(complete, 'white')

# %%
supreme_com = get_all_tees()

# %%
supreme_com
# Out:
# [[{'week': '2017-02-16',
#    'tees': [{'name': 'Sade Tee', 'retail': '44'},
#     {'name': 'Elephant Tee', 'retail': '32'},
#     {'name': 'Abstract Tee', 'retail': '32'},
#     {'name': 'Eternal Tee', 'retail': '32'},
#     {'name': 'FTP Tee', 'retail': '32'},
#     {'name': 'Automatic Tee', 'retail': '32'},
#     {'name': 'Joe Roberts Swirl Tee', 'retail': '32'},
#     {'name': 'Dream Tee', 'retail': '44'},
#     {'name': 'Been Hit L/S Tee', 'retail': '44'},
#     {'name': 'Larry Clark Girl Tee', 'retail': '44'}]},
#   {'week': '2017-03-02', 'tees': []},
#   {'week': '2017-03-09', 'tees': []},
#   {'week': '2017-03-16', 'tees': []},
#   {'week': '2017-03-23', 'tees': []},
#   {'week': '2017-03-30', 'tees': []},
#   {'week': '2017-04-06', 'tees': []},
#   {'week': '2017-04-13', 'tees': []},
#   {'week': '2017-04-20', 'tees': []},
#   {'week': '2017-04-27', 'tees': []},
#   {'week': '2017-05-04', 'tees': []},
#   {'week': '2017-05-11', 'tees': []},
#   {'week': '2017-05-18', 'tees': []},
#   {'week': '2017-05-25', 'tees': []},
#   {'week': '2017-06-01', 'tees': []},
#   {'week': '2017-06-08', 'tees': []},
#   {'week': '2017-06-15', 'tees': []},
#   {'week': '2017-06-22', 'tees': []},
#   {'week': '2017-06-29',
#    'tees': [{'name': 'Mirage Tee', 'retail': '44'},
#     {'name': 'Digi Tee', 'retail': '44'},
#     {'name': 'Punany Train Tee', 'retail': '48'},
#     {'name': 'Super Supreme Tee', 'retail': '48'},
#     {'name': 'Undercover Lover Tee', 'retail': '48'},
#     {'name': 'Orgy Tee', 'retail': '44'},
#     {'name': 'Go Fuck Yourself Tee', 'retail': '46'},
#     {'name': 'Buy Off The Bar Tee', 'retail': '48'},
#     {'name': 'Know Your Rights Tee', 'retail': '44'}]}],
#  [{'week': '2018-02-15',
#    'tees': [{'name': 'FTW Tee', 'retail': '40'},
#     {'name': 'Cards Tee', 'retail': '36'},
#     {'name': 'Chicken Dinner Tee', 'retail': '36'},
#     {'name': 'Necklace Tee', 'retail': '36'},
#     {'name': 'Jellyfish Tee', 'retail': '36'},
#     {'name': 'Prodigy Tee', 'retail': '40'},
#     {'name': 'Molotov Tee', 'retail': '36'},
#     {'name': 'Chair Tee', 'retail': '36'},
#     {'name': 'Chart Tee', 'retail': '36'},
#     {'name': 'Ripple L/S Tee', 'retail': '44'}]},
#   {'week': '2018-02-22',
#    'tees': [{'name': 'FTW Tee', 'retail': '40'},
#     {'name': 'Cards Tee', 'retail': '36'},
#     {'name': 'Chicken Dinner Tee', 'retail': '36'},
#     {'name': 'Necklace Tee', 'retail': '36'},
#     {'name': 'Jellyfish Tee', 'retail': '36'},
#     {'name': 'Prodigy Tee', 'retail': '40'},
#     {'name': 'Molotov Tee', 'retail': '36'},
#     {'name': 'Chair Tee', 'retail': '36'},
#     {'name': 'Chart Tee', 'retail': '36'},
#     {'name': 'Ripple L/S Tee', 'retail': '44'}]},
#   {'week': '2018-03-01', 'tees': []},
#   {'week': '2018-03-08', 'tees': []},
#   {'week': '2018-03-15',
#    'tees': [{'name': 'Supreme®/UNDERCOVER/Public Enemy White House Tee',
#      'retail': '48'},
#     {'name': 'Supreme®/UNDERCOVER/Public Enemy Tee', 'retail': '48'},
#     {'name': 'Supreme®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#      'retail': '62'},
#     {'name': 'Supreme®/UNDERCOVER/Public Enemy Terrordome Tee',
#      'retail': '48'}]},
#   {'week': '2018-03-22', 'tees': []},
#   {'week': '2018-03-29',
#    'tees': [{'name': 'TV Tee', 'retail': '36'},
#     {'name': 'Diamonds Tee', 'retail': '36'},
#     {'name': 'Fiorenza Tee', 'retail': '36'},
#     {'name': 'Ladybug Tee', 'retail': '36'},
#     {'name': 'Fuck Face Tee', 'retail': '36'},
#     {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee', 'retail': '48'},
#     {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#      'retail': '48'},
#     {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee', 'retail': '48'}]},
#   {'week': '2018-04-05',
#    'tees': [{'name': 'Supreme®/The North Face® Metallic Logo T-Shirt',
#      'retail': '54'}]},
#   {'week': '2018-04-12', 'tees': []},
#   {'week': '2018-04-19', 'tees': []},
#   {'week': '2018-04-26',
#    'tees': [{'name': 'Supreme/Hellraiser Hell on Earth Tee', 'retail': '44'},
#     {'name': 'Supreme/Hellraiser Pinhead Tee', 'retail': '44'}]},
#   {'week': '2018-05-03', 'tees': []},
#   {'week': '2018-05-10', 'tees': []},
#   {'week': '2018-05-17', 'tees': []},
#   {'week': '2018-05-24', 'tees': []},
#   {'week': '2018-05-31', 'tees': [{'name': 'Dream Tee', 'retail': '44'}]},
#   {'week': '2018-06-07', 'tees': []},
#   {'week': '2018-06-14', 'tees': []},
#   {'week': '2018-06-21',
#    'tees': [{'name': 'Supreme®/Spitfire® Classic Swirl T-Shirt',
#      'retail': '44'},
#     {'name': 'Supreme®/Spitfire® Cat T-Shirt', 'retail': '44'}]},
#   {'week': '2018-06-28',
#    'tees': [{'name': 'Rocks Tee', 'retail': '36'},
#     {'name': 'Mona Lisa Tee', 'retail': '36'},
#     {'name': 'Tentacles Tee', 'retail': '36'},
#     {'name': 'Swimmers Tee', 'retail': '36'},
#     {'name': 'Ganesha Tee', 'retail': '36'},
#     {'name': 'Hardware Tee', 'retail': '40'},
#     {'name': 'Gonz Logo Tee', 'retail': '36'}]},
#   {'week': '2018-07-05', 'tees': []}],
#  [{'week': '2019-02-21',
#    'tees': [{'name': 'Creeper Tee', 'retail': '38'},
#     {'name': 'Christopher Walken King Of New York Tee', 'retail': '48'},
#     {'name': 'The Real Shit L/S Tee', 'retail': '40'},
#     {'name': 'Knot Tee', 'retail': '38'},
#     {'name': 'Fruit Tee', 'retail': '38'},
#     {'name': 'Kids Tee', 'retail': '38'},
#     {'name': 'Fronts Tee', 'retail': '38'},
#     {'name': 'Hard Goods Tee', 'retail': '38'},
#     {'name': 'Leda And The Swan Tee', 'retail': '38'},
#     {'name': 'Original Sin Tee', 'retail': '38'},
#     {'name': 'Middle Finger To The World Tee', 'retail': '38'}]},
#   {'week': '2019-02-25',
#    'tees': [{'name': 'Creeper Tee', 'retail': '38'},
#     {'name': 'Christopher Walken King Of New York Tee', 'retail': '48'},
#     {'name': 'The Real Shit L/S Tee', 'retail': '40'},
#     {'name': 'Knot Tee', 'retail': '38'},
#     {'name': 'Fruit Tee', 'retail': '38'},
#     {'name': 'Kids Tee', 'retail': '38'},
#     {'name': 'Fronts Tee', 'retail': '38'},
#     {'name': 'Hard Goods Tee', 'retail': '38'},
#     {'name': 'Leda And The Swan Tee', 'retail': '38'},
#     {'name': 'Original Sin Tee', 'retail': '38'},
#     {'name': 'Middle Finger To The World Tee', 'retail': '38'}]},
#   {'week': '2019-03-07', 'tees': []},
#   {'week': '2019-03-14', 'tees': []},
#   {'week': '2019-03-21',
#    'tees': [{'name': 'Gilbert & George/Supreme LIFE Tee', 'retail': '48'},
#     {'name': 'Gilbert & George/Supreme DEATH Tee', 'retail': '48'}]},
#   {'week': '2019-03-28', 'tees': []},
#   {'week': '2019-04-04',
#    'tees': [{'name': 'Cupid Tee', 'retail': '38'},
#     {'name': 'Who The Fuck Tee', 'retail': '38'},
#     {'name': 'Ghost Rider© Tee', 'retail': '44'},
#     {'name': 'Riders Tee', 'retail': '38'},
#     {'name': 'The Persistence of Memory Tee', 'retail': '48'},
#     {'name': 'Molotov Kid Tee', 'retail': '38'},
#     {'name': 'Suzie Switchblade Tee', 'retail': '38'},
#     {'name': 'Keyboard Tee', 'retail': '38'},
#     {'name': 'Headline Tee', 'retail': '38'}]},
#   {'week': '2019-04-11',
#    'tees': [{'name': 'Supreme®/Jean Paul Gaultier® Tee', 'retail': '54'}]},
#   {'week': '2019-04-18', 'tees': []},
#   {'week': '2019-04-25',
#    'tees': [{'name': 'Supreme®/Swarovski® Box Logo Tee', 'retail': '398'}]},
#   {'week': '2019-05-02', 'tees': []},
#   {'week': '2019-05-09', 'tees': []},
#   {'week': '2019-05-16', 'tees': []},
#   {'week': '2019-05-23', 'tees': []},
#   {'week': '2019-05-30', 'tees': []},
#   {'week': '2019-06-06', 'tees': []},
#   {'week': '2019-06-13', 'tees': []},
#   {'week': '2019-06-20', 'tees': []},
#   {'week': '2019-06-27',
#    'tees': [{'name': 'Buju Banton Tee', 'retail': '48'},
#     {'name': 'Dynamite Tee', 'retail': '38'},
#     {'name': 'Reaper Tee', 'retail': '44'},
#     {'name': 'Buju Banton Wake The World Tee', 'retail': '44'},
#     {'name': 'Bela Lugosi Tee', 'retail': '38'},
#     {'name': 'Greetings Tee', 'retail': '38'},
#     {'name': 'Cloud Tee', 'retail': '38'},
#     {'name': 'It Gets Better Every Time Tee', 'retail': '38'},
#     {'name': 'Shears Tee', 'retail': '38'}]},
#   {'week': '2019-07-05', 'tees': []},
#   {'week': '2019-07-11', 'tees': []}]]

# %%
print(re.search('\$(.*)/', '$36/$38').group(1))
# Out:
# 36

# %%
s = 'asdf=5/iwantthis123jasd'
result = re.search('asdf=5/(.*)123jasd', s)
print(result.group(1))
# Out:
# iwantthis

# %%
flattened = [item['tees'] for items in supreme_com for item in items]

# %%
flattened = [item for items in flattened for item in items]

# %%
flattened_keys = {item['name'] for item in flattened}

# %%
for c in complete:
    for f in flattened:
        if f['name'] == c['name']:
            c['retail'] = f['retail']

# %%
complete
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208},
#    {'color': 'black', 'price': 246},
#    {'color': 'white', 'price': 212},
#    {'color': 'heather-grey', 'price': 172},
#    {'color': 'navy', 'price': 191},
#    {'color': 'lime-green', 'price': 218},
#    {'color': 'lt-pink', 'price': 196},
#    {'color': 'aqua', 'price': 189},
#    {'color': 'red', 'price': None}],
#   'average': 204.0,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318},
#    {'color': 'grey', 'price': 121},
#    {'color': 'white', 'price': 233},
#    {'color': 'black', 'price': 315},
#    {'color': 'lt-green', 'price': 165},
#    {'color': 'mocha', 'price': 150},
#    {'color': 'aqua', 'price': 180},
#    {'color': 'red', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 211.71428571428572,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107},
#    {'color': 'navy', 'price': 110},
#    {'color': 'black', 'price': 138},
#    {'color': 'red', 'price': 95},
#    {'color': 'bright-coral', 'price': 80},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'mocha', 'price': None}],
#   'average': 106.0,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'black', 'price': 80}],
#   'average': 66.88888888888889,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61},
#    {'color': 'black', 'price': 127},
#    {'color': 'white', 'price': 146},
#    {'color': 'lt-teal', 'price': 90},
#    {'color': 'mocha', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'red', 'price': 115},
#    {'color': 'lt-pink', 'price': None}],
#   'average': 107.8,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'bright-coral', 'price': 44},
#    {'color': 'navy', 'price': 70},
#    {'color': 'mocha', 'price': 46},
#    {'color': 'white', 'price': 66},
#    {'color': 'aqua', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 60.8,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120},
#    {'color': 'red', 'price': 90},
#    {'color': 'white', 'price': 145},
#    {'color': 'navy', 'price': 83},
#    {'color': 'grey', 'price': 65},
#    {'color': 'mocha', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'lt-green', 'price': None},
#    {'color': 'aqua', 'price': 133}],
#   'average': 106.0,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137},
#    {'color': 'white', 'price': 137},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 137.0,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 90},
#    {'color': 'heather-grey', 'price': 71},
#    {'color': 'pale-pink', 'price': 72},
#    {'color': 'light-green', 'price': None},
#    {'color': 'aqua', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'mocha', 'price': None},
#    {'color': 'navy', 'price': None}],
#   'average': 79.0,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95},
#    {'color': 'white', 'price': 73},
#    {'color': 'heather-grey', 'price': 90},
#    {'color': 'black', 'price': 60},
#    {'color': 'light-blue', 'price': 91},
#    {'color': 'navy', 'price': 50},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 76.5,
#   'date': '6/29/2017',
#   'retail': '44'},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84},
#    {'color': 'black', 'price': 76},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 66},
#    {'color': 'hot-pink', 'price': 50},
#    {'color': 'orange', 'price': 64},
#    {'color': 'light-blue', 'price': None},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'navy', 'price': 64}],
#   'average': 65.85714285714286,
#   'date': '6/29/2017',
#   'retail': '44'},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 55},
#    {'color': 'navy', 'price': 57},
#    {'color': 'red', 'price': 40},
#    {'color': 'teal', 'price': 55},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 57.0,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'navy', 'price': 95},
#    {'color': 'white', 'price': 99},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'orange', 'price': None}],
#   'average': 98.33333333333333,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 56},
#    {'color': 'teal', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'orange', 'price': None},
#    {'color': 'dark-pink', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 77.5,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88},
#    {'color': 'heather-grey', 'price': 64},
#    {'color': 'white', 'price': 75},
#    {'color': 'navy', 'price': 66},
#    {'color': 'red', 'price': 53},
#    {'color': 'bright-yellow', 'price': None},
#    {'color': 'teal', 'price': None},
#    {'color': 'dusty-pink', 'price': 60}],
#   'average': 67.66666666666667,
#   'date': '6/29/2017',
#   'retail': '44'},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'black', 'price': 75},
#    {'color': 'lime', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'light-brown', 'price': None}],
#   'average': 64.75,
#   'date': '6/29/2017',
#   'retail': '46'},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76},
#    {'color': 'orange', 'price': 60},
#    {'color': 'black', 'price': 87},
#    {'color': 'red', 'price': 72},
#    {'color': 'dark-pink', 'price': 48},
#    {'color': 'teal', 'price': None},
#    {'color': 'white', 'price': None},
#    {'color': 'pale-yellow', 'price': 48}],
#   'average': 65.16666666666667,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238},
#    {'color': 'black', 'price': 297},
#    {'color': 'heather-grey', 'price': 224},
#    {'color': 'pale-blue', 'price': 224},
#    {'color': 'red', 'price': 226},
#    {'color': 'brown', 'price': 266},
#    {'color': 'lime', 'price': 201}],
#   'average': 239.42857142857142,
#   'date': '8/24/2017'},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175},
#    {'color': 'white', 'price': 162},
#    {'color': 'heather-grey', 'price': 110},
#    {'color': 'red', 'price': 123},
#    {'color': 'bright-orange', 'price': 93},
#    {'color': 'navy', 'price': 108},
#    {'color': 'royal', 'price': 208},
#    {'color': 'lime', 'price': 70},
#    {'color': 'brown', 'price': None}],
#   'average': 131.125,
#   'date': '8/24/2017'},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'red', 'price': 100},
#    {'color': 'white', 'price': 116},
#    {'color': 'heather-grey', 'price': 95},
#    {'color': 'navy', 'price': 89},
#    {'color': 'lime', 'price': 61},
#    {'color': 'bright-orange', 'price': 121},
#    {'color': 'brown', 'price': 80}],
#   'average': 101.875,
#   'date': '8/24/2017'},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'white', 'price': 82},
#    {'color': 'navy', 'price': 72},
#    {'color': 'light-pink', 'price': 63},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 75.5,
#   'date': '8/24/2017'},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 50},
#    {'color': 'brown', 'price': 100},
#    {'color': 'lime', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'heather-grey', 'price': None},
#    {'color': 'navy', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 83.0,
#   'date': '8/24/2017'},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58},
#    {'color': 'black', 'price': 113},
#    {'color': 'white', 'price': 122},
#    {'color': 'navy', 'price': 59},
#    {'color': 'lime', 'price': 60},
#    {'color': 'red', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 82.4,
#   'date': '8/24/2017'},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73},
#    {'color': 'black', 'price': 71},
#    {'color': 'white', 'price': 71},
#    {'color': 'red', 'price': 63},
#    {'color': 'brown', 'price': 60},
#    {'color': 'navy', 'price': 55},
#    {'color': 'light-pink', 'price': 55},
#    {'color': 'lime', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 64.0,
#   'date': '8/24/2017'},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'brown', 'price': None},
#    {'color': 'royal', 'price': None},
#    {'color': 'light-pink', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'red', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '8/24/2017'},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'white', 'price': 92},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'navy', 'price': 60},
#    {'color': 'royal', 'price': 75},
#    {'color': 'heather-grey', 'price': 75},
#    {'color': 'bright-orange', 'price': None},
#    {'color': 'brown', 'price': None},
#    {'color': 'lime', 'price': None}],
#   'average': 73.0,
#   'date': '8/24/2017'},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85},
#    {'color': 'heather-grey', 'price': 79},
#    {'color': 'white', 'price': 95},
#    {'color': 'red', 'price': 79},
#    {'color': 'navy', 'price': 71},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'pale-blue', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 80.66666666666667,
#   'date': '9/21/2017'},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71},
#    {'color': 'black', 'price': 95},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 59},
#    {'color': 'brick', 'price': 70},
#    {'color': 'lime', 'price': 50},
#    {'color': 'pale-blue', 'price': 108},
#    {'color': 'navy', 'price': None}],
#   'average': 71.71428571428571,
#   'date': '9/21/2017'},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57},
#    {'color': 'black', 'price': 51},
#    {'color': 'white', 'price': 53},
#    {'color': 'pale-blue', 'price': 90},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'red', 'price': None},
#    {'color': 'lime', 'price': None},
#    {'color': 'mustard', 'price': None}],
#   'average': 59.2,
#   'date': '9/21/2017'},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88}, {'color': 'black', 'price': 98}],
#   'average': 93.0,
#   'date': '9/21/2017'},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65}, {'color': 'white', 'price': 64}],
#   'average': 64.5,
#   'date': '9/21/2017'},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'heather-grey', 'price': 48},
#    {'color': 'lime', 'price': 50},
#    {'color': 'white', 'price': 50},
#    {'color': 'royal', 'price': None},
#    {'color': 'red', 'price': None},
#    {'color': 'bright-orange', 'price': None}],
#   'average': 48.75,
#   'date': '9/21/2017'},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266},
#    {'color': 'red', 'price': 221},
#    {'color': 'white', 'price': 233},
#    {'color': 'heather-grey', 'price': 200}],
#   'average': 230.0,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134},
#    {'color': 'black', 'price': 208},
#    {'color': 'white', 'price': 180},
#    {'color': 'red', 'price': 148}],
#   'average': 167.5,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 140},
#    {'color': 'red', 'price': 119}],
#   'average': 143.25,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144},
#    {'color': 'white', 'price': 120},
#    {'color': 'heather-grey', 'price': 108},
#    {'color': 'red', 'price': 125}],
#   'average': 124.25,
#   'date': '10/12/2017'},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253},
#    {'color': 'white', 'price': 273},
#    {'color': 'lime', 'price': 105},
#    {'color': 'cardinal', 'price': 132},
#    {'color': 'slate', 'price': 128}],
#   'average': 178.2,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230},
#    {'color': 'white', 'price': 190},
#    {'color': 'cardinal', 'price': 157},
#    {'color': 'slate', 'price': 153},
#    {'color': 'lime', 'price': 173}],
#   'average': 180.6,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112},
#    {'color': 'black', 'price': 167},
#    {'color': 'white', 'price': 141},
#    {'color': 'slate', 'price': 120},
#    {'color': 'lime', 'price': 109}],
#   'average': 129.8,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150},
#    {'color': 'white', 'price': 116},
#    {'color': 'lime', 'price': 97},
#    {'color': 'slate', 'price': 127},
#    {'color': 'cardinal', 'price': 150}],
#   'average': 128.0,
#   'date': '11/2/2017'},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104},
#    {'color': 'black', 'price': 80},
#    {'color': 'dark-slate', 'price': 59},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': None},
#    {'color': 'olive-green', 'price': None}],
#   'average': 76.0,
#   'date': '11/16/2017'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': [],
#   'date': '11/30/2017'},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201},
#    {'color': 'white', 'price': 140},
#    {'color': 'heather-grey', 'price': 120},
#    {'color': 'lime', 'price': 110},
#    {'color': 'red', 'price': 150},
#    {'color': 'brown', 'price': 153},
#    {'color': 'dark-slate', 'price': 130},
#    {'color': 'bright-orange', 'price': 131}],
#   'average': 141.875,
#   'date': '12/14/2017'},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127},
#    {'color': 'navy', 'price': 121},
#    {'color': 'white', 'price': 104},
#    {'color': 'heather-grey', 'price': 105},
#    {'color': 'light-pink', 'price': 176},
#    {'color': 'mustard', 'price': 125},
#    {'color': 'red', 'price': 100},
#    {'color': 'brown', 'price': 70},
#    {'color': 'lime', 'price': 65}],
#   'average': 110.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133},
#    {'color': 'white', 'price': 127},
#    {'color': 'brick', 'price': 101},
#    {'color': 'green', 'price': 71},
#    {'color': 'light-purple', 'price': 105},
#    {'color': 'dark-slate', 'price': 85},
#    {'color': 'heather-grey', 'price': 50}],
#   'average': 96.0,
#   'date': '12/14/2017'},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93},
#    {'color': 'red', 'price': 69},
#    {'color': 'white', 'price': 89}],
#   'average': 83.66666666666667,
#   'date': '12/14/2017'},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131},
#    {'color': 'white', 'price': 89},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'green', 'price': 63},
#    {'color': 'light-purple', 'price': 55},
#    {'color': 'navy', 'price': 50},
#    {'color': 'brick', 'price': None}],
#   'average': 78.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 39},
#    {'color': 'white', 'price': 51},
#    {'color': 'mustard', 'price': 44},
#    {'color': 'grey', 'price': 41},
#    {'color': 'light-purple', 'price': 65},
#    {'color': 'dark-slate', 'price': 54},
#    {'color': 'green', 'price': 54}],
#   'average': 52.625,
#   'date': '12/14/2017'},
#  {'name': 'Christmas Tee',
#   'search': 'supreme-christmas-tee-white',
#   'colors': [{'color': 'white', 'price': 72}],
#   'average': 72,
#   'date': '12/14/2017'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/15/2018',
#   'retail': '40'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/15/2018',
#   'retail': '40'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/15/2018',
#   'retail': '44'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125},
#    {'color': 'white', 'price': 117},
#    {'color': 'navy', 'price': 86},
#    {'color': 'ash-grey', 'price': 104},
#    {'color': 'mint', 'price': 106},
#    {'color': 'brown', 'price': 76},
#    {'color': 'peach', 'price': 109},
#    {'color': 'red', 'price': 105},
#    {'color': 'cyan', 'price': None}],
#   'average': 103.5,
#   'date': '2/22/2018',
#   'retail': '40'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91},
#    {'color': 'peach', 'price': 68},
#    {'color': 'navy', 'price': 57},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 82},
#    {'color': 'mint', 'price': 45},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'brown', 'price': 75},
#    {'color': 'cyan', 'price': None}],
#   'average': 69.125,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90},
#    {'color': 'black', 'price': 117},
#    {'color': 'white', 'price': 98},
#    {'color': 'navy', 'price': 99},
#    {'color': 'ash-grey', 'price': 75},
#    {'color': 'cyan', 'price': 59},
#    {'color': 'mint', 'price': 75},
#    {'color': 'brown', 'price': 57},
#    {'color': 'red', 'price': 55}],
#   'average': 80.55555555555556,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153},
#    {'color': 'white', 'price': 129},
#    {'color': 'navy', 'price': 100},
#    {'color': 'heather-grey', 'price': 77},
#    {'color': 'light-pink', 'price': 120},
#    {'color': 'mint', 'price': 143},
#    {'color': 'red', 'price': 150},
#    {'color': 'cyan', 'price': 70},
#    {'color': 'peach', 'price': 75}],
#   'average': 113.0,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'white', 'price': 114},
#    {'color': 'heather-grey', 'price': 69},
#    {'color': 'mint', 'price': 77},
#    {'color': 'light-pink', 'price': 75},
#    {'color': 'peach', 'price': 53},
#    {'color': 'red', 'price': 70},
#    {'color': 'navy', 'price': None},
#    {'color': 'cyan', 'price': None}],
#   'average': 79.42857142857143,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'white', 'price': 71},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 41},
#    {'color': 'pale-yellow', 'price': 63},
#    {'color': 'orange', 'price': 58},
#    {'color': 'cyan', 'price': 39},
#    {'color': 'mint', 'price': 50},
#    {'color': 'navy', 'price': None}],
#   'average': 53.625,
#   'date': '2/22/2018',
#   'retail': '40'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 57},
#    {'color': 'grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'mint', 'price': 67},
#    {'color': 'peach', 'price': 87},
#    {'color': 'navy', 'price': 49},
#    {'color': 'brown', 'price': 70},
#    {'color': 'cyan', 'price': None}],
#   'average': 62.125,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 69},
#    {'color': 'red', 'price': 62},
#    {'color': 'light-pink', 'price': 64},
#    {'color': 'navy', 'price': 47},
#    {'color': 'peach', 'price': 43},
#    {'color': 'grey', 'price': None},
#    {'color': 'brown', 'price': None}],
#   'average': 56.666666666666664,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84},
#    {'color': 'white', 'price': 79},
#    {'color': 'heather-grey', 'price': 68},
#    {'color': 'peach', 'price': 57},
#    {'color': 'navy', 'price': 69},
#    {'color': 'cyan', 'price': 62},
#    {'color': 'red', 'price': 66},
#    {'color': 'mint', 'price': 40}],
#   'average': 65.625,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95},
#    {'color': 'white', 'price': 80},
#    {'color': 'heather-grey', 'price': 89},
#    {'color': 'navy', 'price': 89},
#    {'color': 'peach', 'price': 35},
#    {'color': 'red', 'price': None},
#    {'color': 'mint', 'price': None},
#    {'color': 'blue', 'price': None}],
#   'average': 77.6,
#   'date': '2/22/2018',
#   'retail': '44'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89},
#    {'color': 'white', 'price': 86},
#    {'color': 'red', 'price': 69},
#    {'color': 'royal', 'price': 79}],
#   'average': 80.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 73},
#    {'color': 'red', 'price': 66}],
#   'average': 64.33333333333333,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 73},
#    {'color': 'royal', 'price': 81},
#    {'color': 'red', 'price': 66}],
#   'average': 76.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 75},
#    {'color': 'red', 'price': 74},
#    {'color': 'royal', 'price': 58}],
#   'average': 72.25,
#   'date': '3/15/2018'},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172},
#    {'color': 'white', 'price': 148},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'navy', 'price': 122},
#    {'color': 'red', 'price': 100},
#    {'color': 'light-purple', 'price': 143},
#    {'color': 'light-pink', 'price': 193},
#    {'color': 'pale-blue', 'price': 140},
#    {'color': 'bright-yellow', 'price': 130}],
#   'average': 138.66666666666666,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129},
#    {'color': 'black', 'price': 125},
#    {'color': 'heather-grey', 'price': 78},
#    {'color': 'navy', 'price': 98},
#    {'color': 'pale-blue', 'price': 82},
#    {'color': 'green', 'price': 87},
#    {'color': 'red', 'price': 106},
#    {'color': 'bright-yellow', 'price': 61},
#    {'color': 'light-purple', 'price': 117}],
#   'average': 98.11111111111111,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55},
#    {'color': 'black', 'price': 68},
#    {'color': 'white', 'price': 65},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 52},
#    {'color': 'bright-yellow', 'price': 58},
#    {'color': 'pale-blue', 'price': 73}],
#   'average': 60.5,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'light-purple', 'price': 47},
#    {'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 53},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 66},
#    {'color': 'pale-blue', 'price': 54},
#    {'color': 'bright-yellow', 'price': 45},
#    {'color': 'green', 'price': 44}],
#   'average': 52.77777777777778,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'white', 'price': 67},
#    {'color': 'heather-grey', 'price': 57},
#    {'color': 'red', 'price': 53},
#    {'color': 'pale-blue', 'price': 65},
#    {'color': 'light-purple', 'price': 53},
#    {'color': 'bright-yellow', 'price': 43},
#    {'color': 'green', 'price': 45},
#    {'color': 'navy', 'price': 65}],
#   'average': 58.0,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78},
#    {'color': 'heather-grey', 'price': 70},
#    {'color': 'white', 'price': 79},
#    {'color': 'royal', 'price': 53},
#    {'color': 'red', 'price': 58},
#    {'color': 'pale-yellow', 'price': 20}],
#   'average': 59.666666666666664,
#   'date': '3/29/2018',
#   'retail': '48'},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65},
#    {'color': 'red', 'price': 43},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 82},
#    {'color': 'pale-yellow', 'price': None},
#    {'color': 'royal', 'price': None}],
#   'average': 62.0,
#   'date': '3/29/2018',
#   'retail': '48'},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62},
#    {'color': 'hot-pink', 'price': 35},
#    {'color': 'white', 'price': 52},
#    {'color': 'royal', 'price': 50},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'pale-yellow', 'price': None}],
#   'average': 48.8,
#   'date': '3/29/2018',
#   'retail': '48'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': [],
#   'date': '4/5/2018'},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98}, {'color': 'white', 'price': 90}],
#   'average': 94.0,
#   'date': '4/26/2018',
#   'retail': '44'},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101},
#    {'color': 'white', 'price': 81}],
#   'average': 91.0,
#   'date': '4/26/2018',
#   'retail': '44'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123},
#    {'color': 'white', 'price': 73},
#    {'color': 'mocha', 'price': 60},
#    {'color': 'aqua', 'price': None},
#    {'color': 'pale-pink', 'price': None},
#    {'color': 'light-green', 'price': None}],
#   'average': 85.33333333333333,
#   'date': '5/31/2018',
#   'retail': '44'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67},
#    {'color': 'white', 'price': 81},
#    {'color': 'red', 'price': 71},
#    {'color': 'dark-green', 'price': 73},
#    {'color': 'light-purple', 'price': 84},
#    {'color': 'bright-orange', 'price': 68}],
#   'average': 74.0,
#   'date': '6/21/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71},
#    {'color': 'ash-grey', 'price': 60},
#    {'color': 'red', 'price': 58},
#    {'color': 'white', 'price': 84},
#    {'color': 'dark-green', 'price': 79},
#    {'color': 'bright-orange', 'price': 43},
#    {'color': 'light-purple', 'price': 75}],
#   'average': 67.14285714285714,
#   'date': '6/21/2018'},
#  {'name': 'Rocks Tee',
#   'search': 'supreme-Rocks-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white', 'price': 159},
#    {'color': 'black', 'price': 159},
#    {'color': 'red', 'price': 98},
#    {'color': 'ash-grey', 'price': 88},
#    {'color': 'light-purple', 'price': 92},
#    {'color': 'dark-slate', 'price': 101},
#    {'color': 'light-pink', 'price': 118},
#    {'color': 'orange', 'price': 96}],
#   'average': 113.875,
#   'retail': '36'},
#  {'name': 'Mona Lisa Tee',
#   'search': 'supreme-Mona-Lisa-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 174},
#    {'color': 'white', 'price': 129},
#    {'color': 'hot-pink', 'price': 91},
#    {'color': 'pale-yellow', 'price': 98},
#    {'color': 'heather-grey', 'price': 91},
#    {'color': 'red', 'price': 123},
#    {'color': 'royal', 'price': 119},
#    {'color': 'light-purple', 'price': 69}],
#   'average': 111.75,
#   'retail': '36'},
#  {'name': 'Tentacles Tee',
#   'search': 'supreme-Tentacles-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'white', 'price': 147},
#    {'color': 'black', 'price': 128},
#    {'color': 'brick', 'price': 80},
#    {'color': 'heather-grey', 'price': 100},
#    {'color': 'red', 'price': 89},
#    {'color': 'hot-pink', 'price': 82},
#    {'color': 'royal', 'price': 107},
#    {'color': 'pale-yellow', 'price': 96}],
#   'average': 103.625,
#   'retail': '36'},
#  {'name': 'Swimmers Tee',
#   'search': 'supreme-Swimmers-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 74},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'red', 'price': 68},
#    {'color': 'mustard', 'price': 88},
#    {'color': 'dark-slate', 'price': 64},
#    {'color': 'light-pink', 'price': 134}],
#   'average': 82.14285714285714,
#   'retail': '36'},
#  {'name': 'Ganesha Tee',
#   'search': 'supreme-Ganesha-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'light-pink', 'price': 105},
#    {'color': 'white', 'price': 76},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'brick', 'price': 63},
#    {'color': 'orange', 'price': 72},
#    {'color': 'dark-slate', 'price': 76}],
#   'average': 74.57142857142857,
#   'retail': '36'},
#  {'name': 'Hardware Tee',
#   'search': 'supreme-Hardware-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 87},
#    {'color': 'ash-grey', 'price': 54},
#    {'color': 'red', 'price': 47},
#    {'color': 'royal', 'price': 59},
#    {'color': 'navy', 'price': 64},
#    {'color': 'pale-yellow', 'price': 58},
#    {'color': 'light-purple', 'price': 53}],
#   'average': 62.625,
#   'retail': '40'},
#  {'name': 'Gonz Logo Tee',
#   'search': 'supreme-Gonz-Logo-Tee-black',
#   'week': '6/28/2018',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 56},
#    {'color': 'warm-grey', 'price': 56},
#    {'color': 'red', 'price': 54},
#    {'color': 'heather-grey', 'price': 58},
#    {'color': 'royal', 'price': 49},
#    {'color': 'light-purple', 'price': 49},
#    {'color': 'mustard', 'price': 53}],
#   'average': 54.25,
#   'retail': '36'},
#  {'name': 'Madonna Tee',
#   'search': 'supreme-Madonna-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 100},
#    {'color': 'black', 'price': 178},
#    {'color': 'dark-green', 'price': 102},
#    {'color': 'heather-grey', 'price': 109},
#    {'color': 'white', 'price': 167},
#    {'color': 'navy', 'price': 114},
#    {'color': 'red', 'price': 95},
#    {'color': 'pink', 'price': 97},
#    {'color': 'pale-yellow', 'price': 102}],
#   'average': 118.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Liquid Tee',
#   'search': 'supreme-Liquid-Tee-black',
#   'colors': [{'color': 'bright-blue', 'price': 84},
#    {'color': 'navy', 'price': 76},
#    {'color': 'black', 'price': 94},
#    {'color': 'white', 'price': 88},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'burgundy', 'price': 71},
#    {'color': 'pink', 'price': 80},
#    {'color': 'natural', 'price': 76}],
#   'average': 79.5,
#   'date': '8/16/2018'},
#  {'name': 'Still Life Tee',
#   'search': 'supreme-Still-Life-Tee-black',
#   'colors': [{'color': 'red', 'price': 49},
#    {'color': 'bright-blue', 'price': 55},
#    {'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 62},
#    {'color': 'heather-grey', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'pink', 'price': 87},
#    {'color': 'dark-green', 'price': 62}],
#   'average': 64.625,
#   'date': '8/16/2018'},
#  {'name': '1994 L/S Tee',
#   'search': 'supreme-1994-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 98},
#    {'color': 'heather-grey', 'price': 88},
#    {'color': 'white', 'price': 102},
#    {'color': 'navy', 'price': 98},
#    {'color': 'natural', 'price': 101},
#    {'color': 'dark-green', 'price': 94},
#    {'color': 'burgundy', 'price': 83},
#    {'color': 'pink', 'price': 93},
#    {'color': 'red', 'price': 82}],
#   'average': 93.22222222222223,
#   'date': '8/16/2018'},
#  {'name': 'Bottle Cap Tee',
#   'search': 'supreme-Bottle-Cap-Tee-black',
#   'colors': [{'color': 'black', 'price': 69},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'white', 'price': 64},
#    {'color': 'red', 'price': 52},
#    {'color': 'bright-blue', 'price': 58},
#    {'color': 'navy', 'price': 63},
#    {'color': 'pale-yellow', 'price': 51},
#    {'color': 'pink', 'price': 62},
#    {'color': 'dark-green', 'price': 60}],
#   'average': 59.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Cutouts Tee',
#   'search': 'supreme-Cutouts-Tee-black',
#   'colors': [{'color': 'black', 'price': 75},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 45},
#    {'color': 'navy', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'bright-blue', 'price': 73},
#    {'color': 'pink', 'price': 56}],
#   'average': 60.75,
#   'date': '8/16/2018'},
#  {'name': 'Life Sucks Die Tee',
#   'search': 'supreme-Life-Sucks-Die-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 54},
#    {'color': 'black', 'price': 64},
#    {'color': 'red', 'price': 55},
#    {'color': 'natural', 'price': 66},
#    {'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 52},
#    {'color': 'dark-green', 'price': 77},
#    {'color': 'bright-blue', 'price': 48},
#    {'color': 'pink', 'price': 53}],
#   'average': 58.888888888888886,
#   'date': '8/16/2018'},
#  {'name': 'Bedroom Tee',
#   'search': 'supreme-Bedroom-Tee-black',
#   'colors': [{'color': 'navy', 'price': 59},
#    {'color': 'black', 'price': 59},
#    {'color': 'white', 'price': 64},
#    {'color': 'light-pink', 'price': 80},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-green', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'natural', 'price': 70},
#    {'color': 'bright-blue', 'price': 51},
#    {'color': 'pink', 'price': 77}],
#   'average': 62.3,
#   'date': '8/16/2018'},
#  {'name': 'Fuck You Tee',
#   'search': 'supreme-Fuck-You-Tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'bright-blue', 'price': 53},
#    {'color': 'dark-green', 'price': 56},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 57},
#    {'color': 'orange', 'price': 62},
#    {'color': 'red', 'price': 58}],
#   'average': 59.5,
#   'date': '8/16/2018'},
#  {'name': 'Guts Tee',
#   'search': 'supreme-Guts-Tee-black',
#   'colors': [{'color': 'white', 'price': 57},
#    {'color': 'red', 'price': 47},
#    {'color': 'natural', 'price': 51},
#    {'color': 'black', 'price': 56},
#    {'color': 'navy', 'price': 51},
#    {'color': 'ash-grey', 'price': 50},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'bright-blue', 'price': 63},
#    {'color': 'pink', 'price': 56}],
#   'average': 54.333333333333336,
#   'date': '8/16/2018'},
#  {'name': 'Mike Kelley/Supreme The Empire State Building Tee',
#   'search': 'supreme-mike-kelley-supreme-the-empire-state-building-tee-black',
#   'colors': [{'color': 'white', 'price': 66},
#    {'color': 'burgundy', 'price': 47},
#    {'color': 'ash-grey', 'price': 49},
#    {'color': 'black', 'price': 70},
#    {'color': 'dark-green', 'price': 49},
#    {'color': 'slate', 'price': 49},
#    {'color': 'clay', 'price': 51},
#    {'color': 'bright-orange', 'price': 51}],
#   'average': 54.0,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 77},
#    {'color': 'slate', 'price': 73},
#    {'color': 'burgundy', 'price': 80},
#    {'color': 'clay', 'price': 77},
#    {'color': 'black', 'price': 126},
#    {'color': 'white', 'price': 108},
#    {'color': 'dark-green', 'price': 84},
#    {'color': 'bright-orange', 'price': 94}],
#   'average': 89.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Ahhâ€¦Youth! L/S Tee',
#   'search': 'supreme-mike-kelley-supreme-ahhyouth-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 166},
#    {'color': 'white', 'price': 134},
#    {'color': 'clay', 'price': 95},
#    {'color': 'ash-grey', 'price': 103},
#    {'color': 'slate', 'price': 93},
#    {'color': 'dark-green', 'price': 103},
#    {'color': 'burgundy', 'price': 104},
#    {'color': 'bright-orange', 'price': 105}],
#   'average': 112.875,
#   'date': '9/6/2018'},
#  {'name': 'Mike Kelley/Supreme Hiding From Indians Tee',
#   'search': 'supreme-mike-kelley-supreme-hiding-from-indians-tee-black',
#   'colors': [{'color': 'ash-grey', 'price': 46},
#    {'color': 'black', 'price': 59},
#    {'color': 'clay', 'price': 55},
#    {'color': 'white', 'price': 58},
#    {'color': 'burgundy', 'price': 48},
#    {'color': 'bright-orange', 'price': 59},
#    {'color': 'dark-green', 'price': 61},
#    {'color': 'slate', 'price': 57}],
#   'average': 55.375,
#   'date': '9/6/2018'},
#  {'name': 'SupremeÂ®/Comme des GarÃ§ons SHIRTÂ® Split Box Logo Tee',
#   'search': 'supreme-comme-des-garcons-shirt-split-box-logo-tee-black',
#   'colors': [],
#   'date': '9/13/2018'},
#  {'name': 'Group Tee',
#   'search': 'supreme-Group-Tee-black',
#   'colors': [{'color': 'slate', 'price': 65},
#    {'color': 'heather-grey', 'price': 65},
#    {'color': 'black', 'price': 87},
#    {'color': 'white', 'price': 82},
#    {'color': 'red', 'price': 76},
#    {'color': 'dark-pink', 'price': 76},
#    {'color': 'bright-orange', 'price': 68},
#    {'color': 'navy', 'price': 75},
#    {'color': 'dark-green', 'price': 72}],
#   'average': 74.0,
#   'date': '9/20/2018'},
#  {'name': 'Remember Tee',
#   'search': 'supreme-Remember-Tee-black',
#   'colors': [{'color': 'black', 'price': 81},
#    {'color': 'dark-pink', 'price': 63},
#    {'color': 'white', 'price': 86},
#    {'color': 'navy', 'price': 68},
#    {'color': 'heather-grey', 'price': 74},
#    {'color': 'red', 'price': 68},
#    {'color': 'slate', 'price': 74},
#    {'color': 'bright-orange', 'price': 66}],
#   'average': 72.5,
#   'date': '9/20/2018'},
#  {'name': 'Liquid Swords Tee',
#   'search': 'supreme-Liquid-Swords-Tee-black',
#   'colors': [{'color': 'dark-green', 'price': 89},
#    {'color': 'black', 'price': 99},
#    {'color': 'white', 'price': 81},
#    {'color': 'heather-grey', 'price': 81},
#    {'color': 'navy', 'price': 94},
#    {'color': 'slate', 'price': 96},
#    {'color': 'red', 'price': 80},
#    {'color': 'bright-orange', 'price': 85}],
#   'average': 88.125,
#   'date': '9/20/2018'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'black', 'price': 72},
#    {'color': 'slate', 'price': 65},
#    {'color': 'white', 'price': 63},
#    {'color': 'navy', 'price': 65},
#    {'color': 'dark-green', 'price': 67},
#    {'color': 'pale-yellow', 'price': 69},
#    {'color': 'red', 'price': 59},
#    {'color': 'dark-pink', 'price': 62}],
#   'average': 66.88888888888889,
#   'date': '9/20/2018',
#   'retail': '32'},
#  {'name': 'Payphone Tee',
#   'search': 'supreme-Payphone-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 52},
#    {'color': 'black', 'price': 55},
#    {'color': 'white', 'price': 57},
#    {'color': 'natural', 'price': 53},
#    {'color': 'red', 'price': 48},
#    {'color': 'bright-orange', 'price': 48},
#    {'color': 'dark-pink', 'price': 47},
#    {'color': 'navy', 'price': 56},
#    {'color': 'slate', 'price': 61}],
#   'average': 53.0,
#   'date': '9/20/2018'},
#  {'name': 'Faces Tee',
#   'search': 'supreme-Faces-Tee-black',
# ...
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444,
#   'date': '6/27/2019',
#   'retail': '44'},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75,
#   'date': '6/27/2019',
#   'retail': '44'},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875,
#   'date': '8/22/2019'},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857,
#   'date': '8/22/2019'},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5,
#   'date': '8/22/2019'},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285,
#   'date': '8/22/2019'},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0,
#   'date': '8/22/2019'},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0,
#   'date': '8/22/2019'},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125,
#   'date': '8/22/2019'},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854,
#   'date': '8/22/2019'},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5,
#   'date': '8/22/2019'},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143,
#   'date': '8/22/2019'},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2,
#   'date': '9/19/2019'},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429,
#   'date': '10/10/2019'},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375,
#   'date': '10/10/2019'},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25,
#   'date': '10/10/2019'},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285,
#   'date': '10/10/2019'},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125,
#   'date': '10/10/2019'},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146,
#   'date': '10/10/2019'},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5,
#   'date': '10/10/2019'},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875,
#   'date': '10/10/2019'},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336,
#   'date': '10/10/2019'},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0,
#   'date': '10/24/2019'},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6,
#   'date': '12/5/2019'},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4,
#   'date': '12/5/2019'},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25,
#   'date': '12/19/2019'},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854,
#   'date': '12/19/2019'},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285,
#   'date': '12/19/2019'},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0,
#   'date': '12/19/2019'},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875,
#   'date': '12/19/2019'},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0,
#   'date': '12/19/2019'},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5,
#   'date': '12/19/2019'},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664,
#   'date': '12/19/2019'}]

# %%
d = Downloader()
cloud = d.get_raw_details('supreme-cloud-tee-black')
# Out:
# 09:34:02 :: Retrieving raw details for supreme-cloud-tee-black

# %%
cloud['Product']['market']
# Out:
# {'productId': 0,
#  'skuUuid': None,
#  'productUuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#  'lowestAsk': 68,
#  'lowestAskSize': None,
#  'parentLowestAsk': 68,
#  'numberOfAsks': 23,
#  'hasAsks': 1,
#  'salesThisPeriod': 3,
#  'salesLastPeriod': 0,
#  'highestBid': 58,
#  'highestBidSize': None,
#  'numberOfBids': 13,
#  'hasBids': 1,
#  'annualHigh': 115,
#  'annualLow': 45,
#  'deadstockRangeLow': 59,
#  'deadstockRangeHigh': 77,
#  'volatility': 0.129021,
#  'deadstockSold': 251,
#  'pricePremium': 0.789,
#  'averageDeadstockPrice': 60,
#  'lastSale': 68,
#  'lastSaleSize': 'M',
#  'salesLast72Hours': 3,
#  'changeValue': -10,
#  'changePercentage': -0.128205,
#  'absChangePercentage': 0.128205,
#  'totalDollars': 15040,
#  'updatedAt': 1594989214,
#  'lastLowestAskTime': 1594948961,
#  'lastHighestBidTime': 1594604421,
#  'lastSaleDate': '2020-07-16T21:22:46+00:00',
#  'createdAt': '2019-06-27T12:52:34+00:00',
#  'deadstockSoldRank': 71,
#  'pricePremiumRank': 44,
#  'averageDeadstockPriceRank': 35,
#  'featured': None,
#  'lowestAskFloat': 68,
#  'highestBidFloat': 58}

# %%
def get_deadstock_sold(lst, start, end):
    d = Downloader()
    for entry in lst[start:end]:
        for color in entry['colors']:
            search = entry['search'].replace('black', color['color'])
            j = d.get_raw_details(search)
            color['deadstockSold'] = j['Product']['market']['deadstockSold']
    return lst

# %%
get_deadstock_sold(complete_data, 190, 194)
# Out:
# 17:16:04 :: Retrieving raw details for supreme-Bridge-Tee-white

# %%
with open('complete_data.json', 'w') as outfile:
    json.dump(complete_data, outfile)

# %%
d.get_raw_details('supreme-rocks-tee-white')
# Out:
# 10:39:30 :: Retrieving raw details for supreme-rocks-tee-white
# {'Product': {'id': '1c0a2018-2275-4cdc-ae95-26ef93c8b0f8',
#   'uuid': '1c0a2018-2275-4cdc-ae95-26ef93c8b0f8',
#   'brand': 'Supreme',
#   'condition': 'New',
#   'countryOfManufacture': 'CA',
#   'gender': 'men',
#   'contentGroup': 'streetwear-clothing',
#   'minimumBid': 15,
#   'name': 'Tee',
#   'primaryCategory': 'Supreme',
#   'secondaryCategory': 'T-Shirts',
#   'usHtsCode': '6109100012',
#   'usHtsDescription': 'Mens Cotton T-Shirt',
#   'productCategory': 'streetwear',
#   'releaseDate': '2018-06-28',
#   'shoe': 'Supreme Rocks',
#   'shortDescription': 'Supreme-Rocks-Tee-White',
#   'tickerSymbol': 'SUP-RCKST-WHT',
#   'title': 'Supreme Rocks Tee',
#   'dataType': 'product',
#   'urlKey': 'supreme-rocks-tee-white',
#   'sizeLocale': 'us',
#   'sizeTitle': "U.S. Men's Size",
#   'sizeDescriptor': 'Size',
#   'sizeAllDescriptor': 'All',
#   'description': '',
#   'lithiumIonBattery': False,
#   'type': False,
#   'aLim': 3000000,
#   'year': 2018,
#   'shippingGroup': 'streetwear',
#   'traits': [{'name': 'Season',
#     'value': 'SS18',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2018-06-28',
#     'filterable': True,
#     'visible': True,
#     'highlight': False}],
#   'meta': {'charity': False,
#    'raffle': False,
#    'mobile_only': False,
#    'restock': False,
#    'deleted': True,
#    'hidden': True,
#    'lock_buying': True,
#    'lock_selling': True,
#    'redirected': False},
#   'PortfolioItems': [],
#   'shipping': {'totalDaysToShip': 2,
#    'hasAdditionalDaysToShip': False,
#    'deliveryDaysLowerBound': 6,
#    'deliveryDaysUpperBound': 10},
#   'enhancedImage': {},
#   'media': {'360': [],
#    'imageUrl': 'https://stockx-assets.imgix.net/media/New-Product-Placeholder-Default.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&q=90&dpr=2&trim=color&updated_at=false',
#    'smallImageUrl': 'https://stockx-assets.imgix.net/media/New-Product-Placeholder-Default.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&q=90&dpr=2&trim=color&updated_at=false',
#    'thumbUrl': 'https://stockx-assets.imgix.net/media/New-Product-Placeholder-Default.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&q=90&dpr=2&trim=color&updated_at=false',
#    'has360': False,
#    'gallery': []},
#   'charityCondition': 0,
#   'breadcrumbs': [{'level': 1, 'name': 'Home', 'url': '/', 'isBrand': False},
#    {'level': 2, 'name': 'streetwear', 'url': '/streetwear', 'isBrand': False},
#    {'level': 3, 'name': 'Supreme', 'url': '/supreme', 'isBrand': True},
#    {'level': 4,
#     'name': 'T-Shirts',
#     'url': '/supreme/t-shirts',
#     'isBrand': False},
#    {'level': 5,
#     'name': 'Supreme Rocks Tee',
#     'url': '/supreme-rocks-tee-white',
#     'isBrand': False}],
#   'market': {'lowestAskFloat': 0,
#    'lowestAsk': 0,
#    'highestBidFloat': 0,
#    'highestBid': 0,
#    'lowestAskSize': None,
#    'highestBidSize': None},
#   'children': {}}}

# %%
complete_data = []
read_json(complete_data, "complete_data.json")
# Out:
# [{'name': 'Sade Tee',
#   'search': 'supreme-Sade-Tee-black',
#   'colors': [{'color': 'mocha', 'price': 208, 'deadstockSold': 5},
#    {'color': 'black', 'price': 246, 'deadstockSold': 35},
#    {'color': 'white', 'price': 212, 'deadstockSold': 19},
#    {'color': 'heather-grey', 'price': 172, 'deadstockSold': 16},
#    {'color': 'navy', 'price': 191, 'deadstockSold': 9},
#    {'color': 'lime-green', 'price': 218, 'deadstockSold': 6},
#    {'color': 'lt-pink', 'price': 196, 'deadstockSold': 4},
#    {'color': 'aqua', 'price': 189, 'deadstockSold': 4},
#    {'color': 'red', 'price': None, 'deadstockSold': 0}],
#   'average': 204.0,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Elephant Tee',
#   'search': 'supreme-Elephant-Tee-black',
#   'colors': [{'color': 'pink', 'price': 318, 'deadstockSold': 4},
#    {'color': 'grey', 'price': 121, 'deadstockSold': 3},
#    {'color': 'white', 'price': 233, 'deadstockSold': 2},
#    {'color': 'black', 'price': 315, 'deadstockSold': 1},
#    {'color': 'lt-green', 'price': 165, 'deadstockSold': 1},
#    {'color': 'mocha', 'price': 150, 'deadstockSold': 1},
#    {'color': 'aqua', 'price': 180, 'deadstockSold': 1},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0}],
#   'average': 211.71428571428572,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Abstract Tee',
#   'search': 'supreme-Abstract-Tee-black',
#   'colors': [{'color': 'white', 'price': 107, 'deadstockSold': 6},
#    {'color': 'navy', 'price': 110, 'deadstockSold': 2},
#    {'color': 'black', 'price': 138, 'deadstockSold': 8},
#    {'color': 'red', 'price': 95, 'deadstockSold': 1},
#    {'color': 'bright-coral', 'price': 80, 'deadstockSold': 1},
#    {'color': 'lt-green', 'price': None, 'deadstockSold': 0},
#    {'color': 'mocha', 'price': None, 'deadstockSold': 0}],
#   'average': 106.0,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Eternal Tee',
#   'search': 'supreme-Eternal-Tee-black',
#   'colors': [{'color': 'black', 'price': 80, 'deadstockSold': 3}],
#   'average': 66.88888888888889,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'FTP Tee',
#   'search': 'supreme-FTP-Tee-black',
#   'colors': [{'color': 'navy', 'price': 61, 'deadstockSold': 1},
#    {'color': 'black', 'price': 127, 'deadstockSold': 11},
#    {'color': 'white', 'price': 146, 'deadstockSold': 4},
#    {'color': 'lt-teal', 'price': 90, 'deadstockSold': 1},
#    {'color': 'mocha', 'price': None, 'deadstockSold': 0},
#    {'color': 'lt-green', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': 115, 'deadstockSold': 1},
#    {'color': 'lt-pink', 'price': None, 'deadstockSold': 0}],
#   'average': 107.8,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Automatic Tee',
#   'search': 'supreme-Automatic-Tee-black',
#   'colors': [{'color': 'black', 'price': 78, 'deadstockSold': 3},
#    {'color': 'bright-coral', 'price': 44, 'deadstockSold': 8},
#    {'color': 'navy', 'price': 70, 'deadstockSold': 4},
#    {'color': 'mocha', 'price': 46, 'deadstockSold': 1},
#    {'color': 'white', 'price': 66, 'deadstockSold': 1},
#    {'color': 'aqua', 'price': None, 'deadstockSold': 0},
#    {'color': 'heather-grey', 'price': None, 'deadstockSold': 0},
#    {'color': 'light-green', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0}],
#   'average': 60.8,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Joe Roberts Swirl Tee',
#   'search': 'supreme-Joe-Roberts-Swirl-Tee-black',
#   'colors': [{'color': 'black', 'price': 120, 'deadstockSold': 5},
#    {'color': 'red', 'price': 90, 'deadstockSold': 3},
#    {'color': 'white', 'price': 145, 'deadstockSold': 3},
#    {'color': 'navy', 'price': 83, 'deadstockSold': 3},
#    {'color': 'grey', 'price': 65, 'deadstockSold': 1},
#    {'color': 'mocha', 'price': None, 'deadstockSold': 0},
#    {'color': 'pale-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'lt-green', 'price': None, 'deadstockSold': 0},
#    {'color': 'aqua', 'price': 133, 'deadstockSold': 1}],
#   'average': 106.0,
#   'date': '2/16/2017',
#   'retail': '32'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123, 'deadstockSold': 6},
#    {'color': 'white', 'price': 73, 'deadstockSold': 2},
#    {'color': 'mocha', 'price': 60, 'deadstockSold': 1},
#    {'color': 'aqua', 'price': None, 'deadstockSold': 0},
#    {'color': 'pale-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'light-green', 'price': None, 'deadstockSold': 0}],
#   'average': 85.33333333333333,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Been Hit L/S Tee',
#   'search': 'supreme-Been-Hit-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 137, 'deadstockSold': 9},
#    {'color': 'white', 'price': 137, 'deadstockSold': 3},
#    {'color': 'pale-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'light-green', 'price': None, 'deadstockSold': 0},
#    {'color': 'aqua', 'price': None, 'deadstockSold': 0},
#    {'color': 'mocha', 'price': None, 'deadstockSold': 0},
#    {'color': 'heather-grey', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0}],
#   'average': 137.0,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Larry Clark Girl Tee',
#   'search': 'supreme-Larry-Clark-Girl-Tee-black',
#   'colors': [{'color': 'black', 'price': 83, 'deadstockSold': 13},
#    {'color': 'white', 'price': 90, 'deadstockSold': 7},
#    {'color': 'heather-grey', 'price': 71, 'deadstockSold': 4},
#    {'color': 'pale-pink', 'price': 72, 'deadstockSold': 3},
#    {'color': 'light-green', 'price': None, 'deadstockSold': 0},
#    {'color': 'aqua', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'mocha', 'price': None, 'deadstockSold': 0},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0}],
#   'average': 79.0,
#   'date': '2/16/2017',
#   'retail': '44'},
#  {'name': 'Mirage Tee',
#   'search': 'supreme-Mirage-Tee-black',
#   'colors': [{'color': 'purple', 'price': 95, 'deadstockSold': 2},
#    {'color': 'white', 'price': 73, 'deadstockSold': 4},
#    {'color': 'heather-grey', 'price': 90, 'deadstockSold': 1},
#    {'color': 'black', 'price': 60, 'deadstockSold': 1},
#    {'color': 'light-blue', 'price': 91, 'deadstockSold': 1},
#    {'color': 'navy', 'price': 50, 'deadstockSold': 1},
#    {'color': 'pale-yellow', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0}],
#   'average': 76.5,
#   'date': '6/29/2017',
#   'retail': '44'},
#  {'name': 'Digi Tee',
#   'search': 'supreme-Digi-Tee-black',
#   'colors': [{'color': 'white', 'price': 84, 'deadstockSold': 6},
#    {'color': 'black', 'price': 76, 'deadstockSold': 4},
#    {'color': 'heather-grey', 'price': 57, 'deadstockSold': 4},
#    {'color': 'red', 'price': 66, 'deadstockSold': 3},
#    {'color': 'hot-pink', 'price': 50, 'deadstockSold': 1},
#    {'color': 'orange', 'price': 64, 'deadstockSold': 1},
#    {'color': 'light-blue', 'price': None, 'deadstockSold': 0},
#    {'color': 'bright-yellow', 'price': None, 'deadstockSold': 0},
#    {'color': 'navy', 'price': 64, 'deadstockSold': 8}],
#   'average': 65.85714285714286,
#   'date': '6/29/2017',
#   'retail': '44'},
#  {'name': 'Punany Train Tee',
#   'search': 'supreme-wilfred-limonius-punany-train-tee-black',
#   'colors': [{'color': 'black', 'price': 78, 'deadstockSold': 4},
#    {'color': 'white', 'price': 55, 'deadstockSold': 2},
#    {'color': 'navy', 'price': 57, 'deadstockSold': 2},
#    {'color': 'red', 'price': 40, 'deadstockSold': 1},
#    {'color': 'teal', 'price': 55, 'deadstockSold': 1},
#    {'color': 'dark-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'orange', 'price': None, 'deadstockSold': 0},
#    {'color': 'pale-yellow', 'price': None, 'deadstockSold': 0}],
#   'average': 57.0,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Super Supreme Tee',
#   'search': 'supreme-wilfred-limonius-super-supreme-tee-black',
#   'colors': [{'color': 'black', 'price': 101, 'deadstockSold': 1},
#    {'color': 'navy', 'price': 95, 'deadstockSold': 1},
#    {'color': 'white', 'price': 99, 'deadstockSold': 1},
#    {'color': 'dark-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'teal', 'price': None, 'deadstockSold': 0},
#    {'color': 'pale-yellow', 'price': None, 'deadstockSold': 0},
#    {'color': 'orange', 'price': None, 'deadstockSold': 0}],
#   'average': 98.33333333333333,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Undercover Lover Tee',
#   'search': 'supreme-wilfred-limonius-undercover-lover-tee-black',
#   'colors': [{'color': 'black', 'price': 99, 'deadstockSold': 5},
#    {'color': 'white', 'price': 56, 'deadstockSold': 4},
#    {'color': 'teal', 'price': None, 'deadstockSold': 0},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0},
#    {'color': 'orange', 'price': None, 'deadstockSold': 0},
#    {'color': 'dark-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'pale-yellow', 'price': None, 'deadstockSold': 0}],
#   'average': 77.5,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Orgy Tee',
#   'search': 'supreme-Orgy-Tee-black',
#   'colors': [{'color': 'black', 'price': 88, 'deadstockSold': 5},
#    {'color': 'heather-grey', 'price': 64, 'deadstockSold': 4},
#    {'color': 'white', 'price': 75, 'deadstockSold': 4},
#    {'color': 'navy', 'price': 66, 'deadstockSold': 3},
#    {'color': 'red', 'price': 53, 'deadstockSold': 2},
#    {'color': 'bright-yellow', 'price': None, 'deadstockSold': 0},
#    {'color': 'teal', 'price': None, 'deadstockSold': 0},
#    {'color': 'dusty-pink', 'price': 60, 'deadstockSold': 1}],
#   'average': 67.66666666666667,
#   'date': '6/29/2017',
#   'retail': '44'},
#  {'name': 'Go Fuck Yourself Tee',
#   'search': 'supreme-go-fuck-yourself-pocket-tee-black',
#   'colors': [{'color': 'pink', 'price': 57, 'deadstockSold': 4},
#    {'color': 'navy', 'price': 58, 'deadstockSold': 3},
#    {'color': 'heather-grey', 'price': 69, 'deadstockSold': 2},
#    {'color': 'black', 'price': 75, 'deadstockSold': 2},
#    {'color': 'lime', 'price': None, 'deadstockSold': 0},
#    {'color': 'white', 'price': None, 'deadstockSold': 0},
#    {'color': 'light-brown', 'price': None, 'deadstockSold': 0}],
#   'average': 64.75,
#   'date': '6/29/2017',
#   'retail': '46'},
#  {'name': 'Buy Off The Bar Tee',
#   'search': 'supreme-wilfred-limonius-buy-off-the-bar-tee-black',
#   'colors': [{'color': 'navy', 'price': 76, 'deadstockSold': 4},
#    {'color': 'orange', 'price': 60, 'deadstockSold': 2},
#    {'color': 'black', 'price': 87, 'deadstockSold': 7},
#    {'color': 'red', 'price': 72, 'deadstockSold': 3},
#    {'color': 'dark-pink', 'price': 48, 'deadstockSold': 2},
#    {'color': 'teal', 'price': None, 'deadstockSold': 0},
#    {'color': 'white', 'price': None, 'deadstockSold': 0},
#    {'color': 'pale-yellow', 'price': 48, 'deadstockSold': 2}],
#   'average': 65.16666666666667,
#   'date': '6/29/2017',
#   'retail': '48'},
#  {'name': 'Nas Tee',
#   'search': 'supreme-Nas-Tee-black',
#   'colors': [{'color': 'white', 'price': 238, 'deadstockSold': 119},
#    {'color': 'black', 'price': 297, 'deadstockSold': 117},
#    {'color': 'heather-grey', 'price': 224, 'deadstockSold': 81},
#    {'color': 'pale-blue', 'price': 224, 'deadstockSold': 31},
#    {'color': 'red', 'price': 226, 'deadstockSold': 23},
#    {'color': 'brown', 'price': 266, 'deadstockSold': 23},
#    {'color': 'lime', 'price': 201, 'deadstockSold': 10}],
#   'average': 239.42857142857142,
#   'date': '8/24/2017'},
#  {'name': 'Crash Tee',
#   'search': 'supreme-Crash-Tee-black',
#   'colors': [{'color': 'black', 'price': 175, 'deadstockSold': 16},
#    {'color': 'white', 'price': 162, 'deadstockSold': 8},
#    {'color': 'heather-grey', 'price': 110, 'deadstockSold': 5},
#    {'color': 'red', 'price': 123, 'deadstockSold': 3},
#    {'color': 'bright-orange', 'price': 93, 'deadstockSold': 3},
#    {'color': 'navy', 'price': 108, 'deadstockSold': 3},
#    {'color': 'royal', 'price': 208, 'deadstockSold': 2},
#    {'color': 'lime', 'price': 70, 'deadstockSold': 1},
#    {'color': 'brown', 'price': None, 'deadstockSold': 0}],
#   'average': 131.125,
#   'date': '8/24/2017'},
#  {'name': 'Dollar Tee',
#   'search': 'supreme-Dollar-Tee-black',
#   'colors': [{'color': 'black', 'price': 153, 'deadstockSold': 28},
#    {'color': 'red', 'price': 100, 'deadstockSold': 1},
#    {'color': 'white', 'price': 116, 'deadstockSold': 22},
#    {'color': 'heather-grey', 'price': 95, 'deadstockSold': 4},
#    {'color': 'navy', 'price': 89, 'deadstockSold': 4},
#    {'color': 'lime', 'price': 61, 'deadstockSold': 3},
#    {'color': 'bright-orange', 'price': 121, 'deadstockSold': 2},
#    {'color': 'brown', 'price': 80, 'deadstockSold': 1}],
#   'average': 101.875,
#   'date': '8/24/2017'},
#  {'name': 'DNA Tee',
#   'search': 'supreme-DNA-Tee-black',
#   'colors': [{'color': 'black', 'price': 85, 'deadstockSold': 28},
#    {'color': 'white', 'price': 82, 'deadstockSold': 4},
#    {'color': 'navy', 'price': 72, 'deadstockSold': 3},
#    {'color': 'light-pink', 'price': 63, 'deadstockSold': 2},
#    {'color': 'bright-orange', 'price': None, 'deadstockSold': 0},
#    {'color': 'brown', 'price': None, 'deadstockSold': 0},
#    {'color': 'royal', 'price': None, 'deadstockSold': 0},
#    {'color': 'lime', 'price': None, 'deadstockSold': 0}],
#   'average': 75.5,
#   'date': '8/24/2017'},
#  {'name': 'Gonz Heads Tee',
#   'search': 'supreme-Gonz-Heads-Tee-black',
#   'colors': [{'color': 'black', 'price': 99, 'deadstockSold': 1},
#    {'color': 'white', 'price': 50, 'deadstockSold': 1},
#    {'color': 'brown', 'price': 100, 'deadstockSold': 1},
#    {'color': 'lime', 'price': None, 'deadstockSold': 0},
#    {'color': 'light-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'heather-grey', 'price': None, 'deadstockSold': 0},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0},
#    {'color': 'royal', 'price': None, 'deadstockSold': 0}],
#   'average': 83.0,
#   'date': '8/24/2017'},
#  {'name': 'Fuck With Your Head Tee',
#   'search': 'supreme-Fuck-With-Your-Head-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 58, 'deadstockSold': 4},
#    {'color': 'black', 'price': 113, 'deadstockSold': 4},
#    {'color': 'white', 'price': 122, 'deadstockSold': 2},
#    {'color': 'navy', 'price': 59, 'deadstockSold': 1},
#    {'color': 'lime', 'price': 60, 'deadstockSold': 1},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'royal', 'price': None, 'deadstockSold': 0},
#    {'color': 'bright-orange', 'price': None, 'deadstockSold': 0}],
#   'average': 82.4,
#   'date': '8/24/2017'},
#  {'name': 'Venus Tee',
#   'search': 'supreme-Venus-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 73, 'deadstockSold': 9},
#    {'color': 'black', 'price': 71, 'deadstockSold': 7},
#    {'color': 'white', 'price': 71, 'deadstockSold': 3},
#    {'color': 'red', 'price': 63, 'deadstockSold': 2},
#    {'color': 'brown', 'price': 60, 'deadstockSold': 1},
#    {'color': 'navy', 'price': 55, 'deadstockSold': 1},
#    {'color': 'light-pink', 'price': 55, 'deadstockSold': 1},
#    {'color': 'lime', 'price': None, 'deadstockSold': 0},
#    {'color': 'bright-orange', 'price': None, 'deadstockSold': 0}],
#   'average': 64.0,
#   'date': '8/24/2017'},
#  {'name': 'Bloom L/S Tee',
#   'search': 'supreme-Bloom-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 67, 'deadstockSold': 2},
#    {'color': 'white', 'price': 89, 'deadstockSold': 2},
#    {'color': 'heather-grey', 'price': 100, 'deadstockSold': 2},
#    {'color': 'brown', 'price': None, 'deadstockSold': 0},
#    {'color': 'royal', 'price': None, 'deadstockSold': 0},
#    {'color': 'light-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'lime', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0}],
#   'average': 85.33333333333333,
#   'date': '8/24/2017'},
#  {'name': 'Kiss Tee',
#   'search': 'supreme-Kiss-Tee-black',
#   'colors': [{'color': 'black', 'price': 78, 'deadstockSold': 5},
#    {'color': 'white', 'price': 92, 'deadstockSold': 11},
#    {'color': 'light-pink', 'price': 58, 'deadstockSold': 1},
#    {'color': 'navy', 'price': 60, 'deadstockSold': 1},
#    {'color': 'royal', 'price': 75, 'deadstockSold': 1},
#    {'color': 'heather-grey', 'price': 75, 'deadstockSold': 1},
#    {'color': 'bright-orange', 'price': None, 'deadstockSold': 0},
#    {'color': 'brown', 'price': None, 'deadstockSold': 0},
#    {'color': 'lime', 'price': None, 'deadstockSold': 0}],
#   'average': 73.0,
#   'date': '8/24/2017'},
#  {'name': 'Plant Tee',
#   'search': 'supreme-Plant-Tee-black',
#   'colors': [{'color': 'black', 'price': 85, 'deadstockSold': 15},
#    {'color': 'heather-grey', 'price': 79, 'deadstockSold': 9},
#    {'color': 'white', 'price': 95, 'deadstockSold': 4},
#    {'color': 'red', 'price': 79, 'deadstockSold': 2},
#    {'color': 'navy', 'price': 71, 'deadstockSold': 2},
#    {'color': 'light-pink', 'price': 75, 'deadstockSold': 1},
#    {'color': 'pale-blue', 'price': None, 'deadstockSold': 0},
#    {'color': 'mustard', 'price': None, 'deadstockSold': 0}],
#   'average': 80.66666666666667,
#   'date': '9/21/2017'},
#  {'name': 'Friends Tee',
#   'search': 'supreme-Friends-Tee-black',
#   'colors': [{'color': 'white', 'price': 71, 'deadstockSold': 7},
#    {'color': 'black', 'price': 95, 'deadstockSold': 6},
#    {'color': 'heather-grey', 'price': 49, 'deadstockSold': 3},
#    {'color': 'red', 'price': 59, 'deadstockSold': 1},
#    {'color': 'brick', 'price': 70, 'deadstockSold': 1},
#    {'color': 'lime', 'price': 50, 'deadstockSold': 1},
#    {'color': 'pale-blue', 'price': 108, 'deadstockSold': 1},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0}],
#   'average': 71.71428571428571,
#   'date': '9/21/2017'},
#  {'name': 'Candle Tee',
#   'search': 'supreme-Candle-Tee-black',
#   'colors': [{'color': 'navy', 'price': 57, 'deadstockSold': 6},
#    {'color': 'black', 'price': 51, 'deadstockSold': 5},
#    {'color': 'white', 'price': 53, 'deadstockSold': 3},
#    {'color': 'pale-blue', 'price': 90, 'deadstockSold': 1},
#    {'color': 'heather-grey', 'price': 45, 'deadstockSold': 1},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'lime', 'price': None, 'deadstockSold': 0},
#    {'color': 'mustard', 'price': None, 'deadstockSold': 0}],
#   'average': 59.2,
#   'date': '9/21/2017'},
#  {'name': 'Piss Christ Tee',
#   'search': 'supreme-Piss-Christ-Tee-black',
#   'colors': [{'color': 'white', 'price': 88, 'deadstockSold': 24},
#    {'color': 'black', 'price': 98, 'deadstockSold': 39}],
#   'average': 93.0,
#   'date': '9/21/2017'},
#  {'name': 'Madonna & Child Tee',
#   'search': 'supreme-Madonna-Child-Tee-black',
#   'colors': [{'color': 'black', 'price': 65, 'deadstockSold': 17},
#    {'color': 'white', 'price': 64, 'deadstockSold': 11}],
#   'average': 64.5,
#   'date': '9/21/2017'},
#  {'name': 'Decline of Western Civilization Tee',
#   'search': 'supreme-Decline-of-Western-Civilization-Tee-black',
#   'colors': [{'color': 'black', 'price': 47, 'deadstockSold': 12},
#    {'color': 'heather-grey', 'price': 48, 'deadstockSold': 3},
#    {'color': 'lime', 'price': 50, 'deadstockSold': 1},
#    {'color': 'white', 'price': 50, 'deadstockSold': 1},
#    {'color': 'royal', 'price': None, 'deadstockSold': 0},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'bright-orange', 'price': None, 'deadstockSold': 0}],
#   'average': 48.75,
#   'date': '9/21/2017'},
#  {'name': 'Scarfaceâ„¢ Split Tee',
#   'search': 'supreme-Scarface-Split-Tee-black',
#   'colors': [{'color': 'black', 'price': 266, 'deadstockSold': 127},
#    {'color': 'red', 'price': 221, 'deadstockSold': 42},
#    {'color': 'white', 'price': 233, 'deadstockSold': 44},
#    {'color': 'heather-grey', 'price': 200, 'deadstockSold': 45}],
#   'average': 230.0,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Blimp Tee',
#   'search': 'supreme-Scarface-Blimp-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 134, 'deadstockSold': 17},
#    {'color': 'black', 'price': 208, 'deadstockSold': 64},
#    {'color': 'white', 'price': 180, 'deadstockSold': 46},
#    {'color': 'red', 'price': 148, 'deadstockSold': 18}],
#   'average': 167.5,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Friend Tee',
#   'search': 'supreme-Scarface-Friend-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 147, 'deadstockSold': 25},
#    {'color': 'black', 'price': 167, 'deadstockSold': 67},
#    {'color': 'white', 'price': 140, 'deadstockSold': 48},
#    {'color': 'red', 'price': 119, 'deadstockSold': 22}],
#   'average': 143.25,
#   'date': '10/12/2017'},
#  {'name': 'Scarfaceâ„¢ Shower Tee',
#   'search': 'supreme-Scarface-Shower-Tee-black',
#   'colors': [{'color': 'black', 'price': 144, 'deadstockSold': 59},
#    {'color': 'white', 'price': 120, 'deadstockSold': 34},
#    {'color': 'heather-grey', 'price': 108, 'deadstockSold': 22},
#    {'color': 'red', 'price': 125, 'deadstockSold': 15}],
#   'average': 124.25,
#   'date': '10/12/2017'},
#  {'name': 'AKIRA/Supreme Pill Tee',
#   'search': 'supreme-akirasupreme-pill-tee-black',
#   'colors': [{'color': 'black', 'price': 253, 'deadstockSold': 27},
#    {'color': 'white', 'price': 273, 'deadstockSold': 10},
#    {'color': 'lime', 'price': 105, 'deadstockSold': 3},
#    {'color': 'cardinal', 'price': 132, 'deadstockSold': 3},
#    {'color': 'slate', 'price': 128, 'deadstockSold': 3}],
#   'average': 178.2,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Arm Tee',
#   'search': 'supreme-akirasupreme-arm-tee-black',
#   'colors': [{'color': 'black', 'price': 230, 'deadstockSold': 40},
#    {'color': 'white', 'price': 190, 'deadstockSold': 28},
#    {'color': 'cardinal', 'price': 157, 'deadstockSold': 14},
#    {'color': 'slate', 'price': 153, 'deadstockSold': 8},
#    {'color': 'lime', 'price': 173, 'deadstockSold': 4}],
#   'average': 180.6,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Yamagata Tee',
#   'search': 'supreme-akirasupreme-yamagata-tee-black',
#   'colors': [{'color': 'cardinal', 'price': 112, 'deadstockSold': 6},
#    {'color': 'black', 'price': 167, 'deadstockSold': 31},
#    {'color': 'white', 'price': 141, 'deadstockSold': 10},
#    {'color': 'slate', 'price': 120, 'deadstockSold': 8},
#    {'color': 'lime', 'price': 109, 'deadstockSold': 2}],
#   'average': 129.8,
#   'date': '11/2/2017'},
#  {'name': 'AKIRA/Supreme Syringe Tee',
#   'search': 'supreme-akirasupreme-syringe-tee-black',
#   'colors': [{'color': 'black', 'price': 150, 'deadstockSold': 22},
#    {'color': 'white', 'price': 116, 'deadstockSold': 11},
#    {'color': 'lime', 'price': 97, 'deadstockSold': 4},
#    {'color': 'slate', 'price': 127, 'deadstockSold': 4},
#    {'color': 'cardinal', 'price': 150, 'deadstockSold': 2}],
#   'average': 128.0,
#   'date': '11/2/2017'},
#  {'name': 'SupremeÂ®/IndependentÂ® Old English Tee',
#   'search': 'supreme-independent-old-english-tee-black',
#   'colors': [{'color': 'white', 'price': 104, 'deadstockSold': 3},
#    {'color': 'black', 'price': 80, 'deadstockSold': 3},
#    {'color': 'dark-slate', 'price': 59, 'deadstockSold': 2},
#    {'color': 'heather-grey', 'price': 61, 'deadstockSold': 2},
#    {'color': 'red', 'price': None, 'deadstockSold': 1},
#    {'color': 'olive-green', 'price': None, 'deadstockSold': 0}],
#   'average': 76.0,
#   'date': '11/16/2017'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Mountain Tee',
#   'search': 'supreme-the-north-face-mountain-tee-black',
#   'colors': [],
#   'date': '11/30/2017'},
#  {'name': 'Arabic Logo L/S Tee',
#   'search': 'supreme-Arabic-Logo-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 201, 'deadstockSold': 46},
#    {'color': 'white', 'price': 140, 'deadstockSold': 40},
#    {'color': 'heather-grey', 'price': 120, 'deadstockSold': 22},
#    {'color': 'lime', 'price': 110, 'deadstockSold': 11},
#    {'color': 'red', 'price': 150, 'deadstockSold': 10},
#    {'color': 'brown', 'price': 153, 'deadstockSold': 9},
#    {'color': 'dark-slate', 'price': 130, 'deadstockSold': 5},
#    {'color': 'bright-orange', 'price': 131, 'deadstockSold': 3}],
#   'average': 141.875,
#   'date': '12/14/2017'},
#  {'name': 'Gonz Tee',
#   'search': 'supreme-Gonz-Tee-black',
#   'colors': [{'color': 'black', 'price': 127, 'deadstockSold': 50},
#    {'color': 'navy', 'price': 121, 'deadstockSold': 13},
#    {'color': 'white', 'price': 104, 'deadstockSold': 11},
#    {'color': 'heather-grey', 'price': 105, 'deadstockSold': 9},
#    {'color': 'light-pink', 'price': 176, 'deadstockSold': 4},
#    {'color': 'mustard', 'price': 125, 'deadstockSold': 2},
#    {'color': 'red', 'price': 100, 'deadstockSold': 2},
#    {'color': 'brown', 'price': 70, 'deadstockSold': 2},
#    {'color': 'lime', 'price': 65, 'deadstockSold': 1}],
#   'average': 110.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Fire Tee',
#   'search': 'supreme-Fire-Tee-black',
#   'colors': [{'color': 'black', 'price': 133, 'deadstockSold': 29},
#    {'color': 'white', 'price': 127, 'deadstockSold': 26},
#    {'color': 'brick', 'price': 101, 'deadstockSold': 5},
#    {'color': 'green', 'price': 71, 'deadstockSold': 3},
#    {'color': 'light-purple', 'price': 105, 'deadstockSold': 2},
#    {'color': 'dark-slate', 'price': 85, 'deadstockSold': 1},
#    {'color': 'heather-grey', 'price': 50, 'deadstockSold': 1}],
#   'average': 96.0,
#   'date': '12/14/2017'},
#  {'name': 'Fuck Wool Scarf',
#   'search': 'supreme-Fuck-Wool-Scarf-black',
#   'colors': [{'color': 'black', 'price': 93, 'deadstockSold': 9},
#    {'color': 'red', 'price': 69, 'deadstockSold': 9},
#    {'color': 'white', 'price': 89, 'deadstockSold': 1}],
#   'average': 83.66666666666667,
#   'date': '12/14/2017'},
#  {'name': 'Horror Tee',
#   'search': 'supreme-Horror-Tee-black',
#   'colors': [{'color': 'black', 'price': 131, 'deadstockSold': 17},
#    {'color': 'white', 'price': 89, 'deadstockSold': 12},
#    {'color': 'heather-grey', 'price': 82, 'deadstockSold': 8},
#    {'color': 'green', 'price': 63, 'deadstockSold': 2},
#    {'color': 'light-purple', 'price': 55, 'deadstockSold': 2},
#    {'color': 'navy', 'price': 50, 'deadstockSold': 1},
#    {'color': 'brick', 'price': None, 'deadstockSold': 0}],
#   'average': 78.33333333333333,
#   'date': '12/14/2017'},
#  {'name': 'Dog Shit Tee',
#   'search': 'supreme-Dog-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 73, 'deadstockSold': 20},
#    {'color': 'red', 'price': 39, 'deadstockSold': 9},
#    {'color': 'white', 'price': 51, 'deadstockSold': 8},
#    {'color': 'mustard', 'price': 44, 'deadstockSold': 3},
#    {'color': 'grey', 'price': 41, 'deadstockSold': 2},
#    {'color': 'light-purple', 'price': 65, 'deadstockSold': 2},
#    {'color': 'dark-slate', 'price': 54, 'deadstockSold': 2},
#    {'color': 'green', 'price': 54, 'deadstockSold': 1}],
#   'average': 52.625,
#   'date': '12/14/2017'},
#  {'name': 'Christmas Tee',
#   'search': 'supreme-christmas-tee-white',
#   'colors': [{'color': 'white', 'price': 72}],
#   'average': 72,
#   'date': '12/14/2017'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125, 'deadstockSold': 27},
#    {'color': 'white', 'price': 117, 'deadstockSold': 17},
#    {'color': 'navy', 'price': 86, 'deadstockSold': 6},
#    {'color': 'ash-grey', 'price': 104, 'deadstockSold': 3},
#    {'color': 'mint', 'price': 106, 'deadstockSold': 4},
#    {'color': 'brown', 'price': 76, 'deadstockSold': 3},
#    {'color': 'peach', 'price': 109, 'deadstockSold': 2},
#    {'color': 'red', 'price': 105, 'deadstockSold': 2},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 103.5,
#   'date': '2/15/2018',
#   'retail': '40'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91, 'deadstockSold': 21},
#    {'color': 'peach', 'price': 68, 'deadstockSold': 6},
#    {'color': 'navy', 'price': 57, 'deadstockSold': 4},
#    {'color': 'white', 'price': 75, 'deadstockSold': 3},
#    {'color': 'red', 'price': 82, 'deadstockSold': 3},
#    {'color': 'mint', 'price': 45, 'deadstockSold': 2},
#    {'color': 'ash-grey', 'price': 60, 'deadstockSold': 2},
#    {'color': 'brown', 'price': 75, 'deadstockSold': 2},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 69.125,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90, 'deadstockSold': 4},
#    {'color': 'black', 'price': 117, 'deadstockSold': 28},
#    {'color': 'white', 'price': 98, 'deadstockSold': 23},
#    {'color': 'navy', 'price': 99, 'deadstockSold': 7},
#    {'color': 'ash-grey', 'price': 75, 'deadstockSold': 7},
#    {'color': 'cyan', 'price': 59, 'deadstockSold': 4},
#    {'color': 'mint', 'price': 75, 'deadstockSold': 4},
#    {'color': 'brown', 'price': 57, 'deadstockSold': 3},
#    {'color': 'red', 'price': 55, 'deadstockSold': 2}],
#   'average': 80.55555555555556,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153, 'deadstockSold': 32},
#    {'color': 'white', 'price': 129, 'deadstockSold': 15},
#    {'color': 'navy', 'price': 100, 'deadstockSold': 9},
#    {'color': 'heather-grey', 'price': 77, 'deadstockSold': 9},
#    {'color': 'light-pink', 'price': 120, 'deadstockSold': 4},
#    {'color': 'mint', 'price': 143, 'deadstockSold': 3},
#    {'color': 'red', 'price': 150, 'deadstockSold': 3},
#    {'color': 'cyan', 'price': 70, 'deadstockSold': 1},
#    {'color': 'peach', 'price': 75, 'deadstockSold': 1}],
#   'average': 113.0,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98, 'deadstockSold': 25},
#    {'color': 'white', 'price': 114, 'deadstockSold': 7},
#    {'color': 'heather-grey', 'price': 69, 'deadstockSold': 8},
#    {'color': 'mint', 'price': 77, 'deadstockSold': 4},
#    {'color': 'light-pink', 'price': 75, 'deadstockSold': 3},
#    {'color': 'peach', 'price': 53, 'deadstockSold': 2},
#    {'color': 'red', 'price': 70, 'deadstockSold': 1},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 79.42857142857143,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58, 'deadstockSold': 43},
#    {'color': 'white', 'price': 71, 'deadstockSold': 31},
#    {'color': 'heather-grey', 'price': 49, 'deadstockSold': 17},
#    {'color': 'red', 'price': 41, 'deadstockSold': 9},
#    {'color': 'pale-yellow', 'price': 63, 'deadstockSold': 7},
#    {'color': 'orange', 'price': 58, 'deadstockSold': 5},
#    {'color': 'cyan', 'price': 39, 'deadstockSold': 4},
#    {'color': 'mint', 'price': 50, 'deadstockSold': 1},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0}],
#   'average': 53.625,
#   'date': '2/15/2018',
#   'retail': '40'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59, 'deadstockSold': 22},
#    {'color': 'white', 'price': 57, 'deadstockSold': 16},
#    {'color': 'grey', 'price': 51, 'deadstockSold': 10},
#    {'color': 'red', 'price': 57, 'deadstockSold': 7},
#    {'color': 'mint', 'price': 67, 'deadstockSold': 2},
#    {'color': 'peach', 'price': 87, 'deadstockSold': 2},
#    {'color': 'navy', 'price': 49, 'deadstockSold': 2},
#    {'color': 'brown', 'price': 70, 'deadstockSold': 1},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 62.125,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55, 'deadstockSold': 36},
#    {'color': 'white', 'price': 69, 'deadstockSold': 23},
#    {'color': 'red', 'price': 62, 'deadstockSold': 3},
#    {'color': 'light-pink', 'price': 64, 'deadstockSold': 3},
#    {'color': 'navy', 'price': 47, 'deadstockSold': 2},
#    {'color': 'peach', 'price': 43, 'deadstockSold': 2},
#    {'color': 'grey', 'price': None, 'deadstockSold': 0},
#    {'color': 'brown', 'price': None, 'deadstockSold': 0}],
#   'average': 56.666666666666664,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84, 'deadstockSold': 20},
#    {'color': 'white', 'price': 79, 'deadstockSold': 15},
#    {'color': 'heather-grey', 'price': 68, 'deadstockSold': 9},
#    {'color': 'peach', 'price': 57, 'deadstockSold': 4},
#    {'color': 'navy', 'price': 69, 'deadstockSold': 4},
#    {'color': 'cyan', 'price': 62, 'deadstockSold': 2},
#    {'color': 'red', 'price': 66, 'deadstockSold': 2},
#    {'color': 'mint', 'price': 40, 'deadstockSold': 1}],
#   'average': 65.625,
#   'date': '2/15/2018',
#   'retail': '36'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95, 'deadstockSold': 14},
#    {'color': 'white', 'price': 80, 'deadstockSold': 7},
#    {'color': 'heather-grey', 'price': 89, 'deadstockSold': 8},
#    {'color': 'navy', 'price': 89, 'deadstockSold': 6},
#    {'color': 'peach', 'price': 35, 'deadstockSold': 1},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'mint', 'price': None, 'deadstockSold': 0},
#    {'color': 'blue', 'price': None, 'deadstockSold': 0}],
#   'average': 77.6,
#   'date': '2/15/2018',
#   'retail': '44'},
#  {'name': 'FTW Tee',
#   'search': 'supreme-FTW-Tee-black',
#   'colors': [{'color': 'black', 'price': 125, 'deadstockSold': 27},
#    {'color': 'white', 'price': 117, 'deadstockSold': 17},
#    {'color': 'navy', 'price': 86, 'deadstockSold': 6},
#    {'color': 'ash-grey', 'price': 104, 'deadstockSold': 3},
#    {'color': 'mint', 'price': 106, 'deadstockSold': 4},
#    {'color': 'brown', 'price': 76, 'deadstockSold': 3},
#    {'color': 'peach', 'price': 109, 'deadstockSold': 2},
#    {'color': 'red', 'price': 105, 'deadstockSold': 2},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 103.5,
#   'date': '2/22/2018',
#   'retail': '40'},
#  {'name': 'Cards Tee',
#   'search': 'supreme-Cards-Tee-black',
#   'colors': [{'color': 'black', 'price': 91, 'deadstockSold': 21},
#    {'color': 'peach', 'price': 68, 'deadstockSold': 6},
#    {'color': 'navy', 'price': 57, 'deadstockSold': 4},
#    {'color': 'white', 'price': 75, 'deadstockSold': 3},
#    {'color': 'red', 'price': 82, 'deadstockSold': 3},
#    {'color': 'mint', 'price': 45, 'deadstockSold': 2},
#    {'color': 'ash-grey', 'price': 60, 'deadstockSold': 2},
#    {'color': 'brown', 'price': 75, 'deadstockSold': 2},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 69.125,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Chicken Dinner Tee',
#   'search': 'supreme-Chicken-Dinner-Tee-black',
#   'colors': [{'color': 'orange', 'price': 90, 'deadstockSold': 4},
#    {'color': 'black', 'price': 117, 'deadstockSold': 28},
#    {'color': 'white', 'price': 98, 'deadstockSold': 23},
#    {'color': 'navy', 'price': 99, 'deadstockSold': 7},
#    {'color': 'ash-grey', 'price': 75, 'deadstockSold': 7},
#    {'color': 'cyan', 'price': 59, 'deadstockSold': 4},
#    {'color': 'mint', 'price': 75, 'deadstockSold': 4},
#    {'color': 'brown', 'price': 57, 'deadstockSold': 3},
#    {'color': 'red', 'price': 55, 'deadstockSold': 2}],
#   'average': 80.55555555555556,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Necklace Tee',
#   'search': 'supreme-Necklace-Tee-black',
#   'colors': [{'color': 'black', 'price': 153, 'deadstockSold': 32},
#    {'color': 'white', 'price': 129, 'deadstockSold': 15},
#    {'color': 'navy', 'price': 100, 'deadstockSold': 9},
#    {'color': 'heather-grey', 'price': 77, 'deadstockSold': 9},
#    {'color': 'light-pink', 'price': 120, 'deadstockSold': 4},
#    {'color': 'mint', 'price': 143, 'deadstockSold': 3},
#    {'color': 'red', 'price': 150, 'deadstockSold': 3},
#    {'color': 'cyan', 'price': 70, 'deadstockSold': 1},
#    {'color': 'peach', 'price': 75, 'deadstockSold': 1}],
#   'average': 113.0,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Jellyfish Tee',
#   'search': 'supreme-Jellyfish-Tee-black',
#   'colors': [{'color': 'black', 'price': 98, 'deadstockSold': 25},
#    {'color': 'white', 'price': 114, 'deadstockSold': 7},
#    {'color': 'heather-grey', 'price': 69, 'deadstockSold': 8},
#    {'color': 'mint', 'price': 77, 'deadstockSold': 4},
#    {'color': 'light-pink', 'price': 75, 'deadstockSold': 3},
#    {'color': 'peach', 'price': 53, 'deadstockSold': 2},
#    {'color': 'red', 'price': 70, 'deadstockSold': 1},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 79.42857142857143,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Prodigy Tee',
#   'search': 'supreme-Prodigy-Tee-black',
#   'colors': [{'color': 'black', 'price': 58, 'deadstockSold': 43},
#    {'color': 'white', 'price': 71, 'deadstockSold': 31},
#    {'color': 'heather-grey', 'price': 49, 'deadstockSold': 17},
#    {'color': 'red', 'price': 41, 'deadstockSold': 9},
#    {'color': 'pale-yellow', 'price': 63, 'deadstockSold': 7},
#    {'color': 'orange', 'price': 58, 'deadstockSold': 5},
#    {'color': 'cyan', 'price': 39, 'deadstockSold': 4},
#    {'color': 'mint', 'price': 50, 'deadstockSold': 1},
#    {'color': 'navy', 'price': None, 'deadstockSold': 0}],
#   'average': 53.625,
#   'date': '2/22/2018',
#   'retail': '40'},
#  {'name': 'Molotov Tee',
#   'search': 'supreme-Molotov-Tee-black',
#   'colors': [{'color': 'black', 'price': 59, 'deadstockSold': 22},
#    {'color': 'white', 'price': 57, 'deadstockSold': 16},
#    {'color': 'grey', 'price': 51, 'deadstockSold': 10},
#    {'color': 'red', 'price': 57, 'deadstockSold': 7},
#    {'color': 'mint', 'price': 67, 'deadstockSold': 2},
#    {'color': 'peach', 'price': 87, 'deadstockSold': 2},
#    {'color': 'navy', 'price': 49, 'deadstockSold': 2},
#    {'color': 'brown', 'price': 70, 'deadstockSold': 1},
#    {'color': 'cyan', 'price': None, 'deadstockSold': 0}],
#   'average': 62.125,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Chair Tee',
#   'search': 'supreme-Chair-Tee-black',
#   'colors': [{'color': 'black', 'price': 55, 'deadstockSold': 36},
#    {'color': 'white', 'price': 69, 'deadstockSold': 23},
#    {'color': 'red', 'price': 62, 'deadstockSold': 3},
#    {'color': 'light-pink', 'price': 64, 'deadstockSold': 3},
#    {'color': 'navy', 'price': 47, 'deadstockSold': 2},
#    {'color': 'peach', 'price': 43, 'deadstockSold': 2},
#    {'color': 'grey', 'price': None, 'deadstockSold': 0},
#    {'color': 'brown', 'price': None, 'deadstockSold': 0}],
#   'average': 56.666666666666664,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Chart Tee',
#   'search': 'supreme-Chart-Tee-black',
#   'colors': [{'color': 'black', 'price': 84, 'deadstockSold': 20},
#    {'color': 'white', 'price': 79, 'deadstockSold': 15},
#    {'color': 'heather-grey', 'price': 68, 'deadstockSold': 9},
#    {'color': 'peach', 'price': 57, 'deadstockSold': 4},
#    {'color': 'navy', 'price': 69, 'deadstockSold': 4},
#    {'color': 'cyan', 'price': 62, 'deadstockSold': 2},
#    {'color': 'red', 'price': 66, 'deadstockSold': 2},
#    {'color': 'mint', 'price': 40, 'deadstockSold': 1}],
#   'average': 65.625,
#   'date': '2/22/2018',
#   'retail': '36'},
#  {'name': 'Ripple L/S Tee',
#   'search': 'supreme-Ripple-ls-Tee-black',
#   'colors': [{'color': 'black', 'price': 95, 'deadstockSold': 14},
#    {'color': 'white', 'price': 80, 'deadstockSold': 7},
#    {'color': 'heather-grey', 'price': 89, 'deadstockSold': 8},
#    {'color': 'navy', 'price': 89, 'deadstockSold': 6},
#    {'color': 'peach', 'price': 35, 'deadstockSold': 1},
#    {'color': 'red', 'price': None, 'deadstockSold': 0},
#    {'color': 'mint', 'price': None, 'deadstockSold': 0},
#    {'color': 'blue', 'price': None, 'deadstockSold': 0}],
#   'average': 77.6,
#   'date': '2/22/2018',
#   'retail': '44'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy White House Tee',
#   'search': 'supreme-undercoverpublic-enemy-white-house-tee-black',
#   'colors': [{'color': 'black', 'price': 89, 'deadstockSold': 93},
#    {'color': 'white', 'price': 86, 'deadstockSold': 50},
#    {'color': 'red', 'price': 69, 'deadstockSold': 21},
#    {'color': 'royal', 'price': 79, 'deadstockSold': 12}],
#   'average': 80.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Tee',
#   'search': 'supreme-undercoverpublic-enemy-tee-black',
#   'colors': [{'color': 'white', 'price': 54, 'deadstockSold': 39},
#    {'color': 'black', 'price': 73, 'deadstockSold': 104},
#    {'color': 'red', 'price': 66, 'deadstockSold': 20}],
#   'average': 64.33333333333333,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#   'search': 'supreme-undercoverpublic-enemy-counterattack-ls-tee-black',
#   'colors': [{'color': 'black', 'price': 87, 'deadstockSold': 89},
#    {'color': 'white', 'price': 73, 'deadstockSold': 51},
#    {'color': 'royal', 'price': 81, 'deadstockSold': 10},
#    {'color': 'red', 'price': 66, 'deadstockSold': 9}],
#   'average': 76.75,
#   'date': '3/15/2018'},
#  {'name': 'SupremeÂ®/UNDERCOVER/Public Enemy Terrordome Tee',
#   'search': 'supreme-undercoverpublic-enemy-terrordome-tee-black',
#   'colors': [{'color': 'black', 'price': 82, 'deadstockSold': 117},
#    {'color': 'white', 'price': 75, 'deadstockSold': 98},
#    {'color': 'red', 'price': 74, 'deadstockSold': 23},
#    {'color': 'royal', 'price': 58, 'deadstockSold': 12}],
#   'average': 72.25,
#   'date': '3/15/2018'},
#  {'name': 'TV Tee',
#   'search': 'supreme-TV-Tee-black',
#   'colors': [{'color': 'black', 'price': 172, 'deadstockSold': 68},
#    {'color': 'white', 'price': 148, 'deadstockSold': 49},
#    {'color': 'heather-grey', 'price': 100, 'deadstockSold': 17},
#    {'color': 'navy', 'price': 122, 'deadstockSold': 14},
#    {'color': 'red', 'price': 100, 'deadstockSold': 9},
#    {'color': 'light-purple', 'price': 143, 'deadstockSold': 5},
#    {'color': 'light-pink', 'price': 193, 'deadstockSold': 4},
#    {'color': 'pale-blue', 'price': 140, 'deadstockSold': 3},
#    {'color': 'bright-yellow', 'price': 130, 'deadstockSold': 1}],
#   'average': 138.66666666666666,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Diamonds Tee',
#   'search': 'supreme-Diamonds-Tee-black',
#   'colors': [{'color': 'white', 'price': 129, 'deadstockSold': 50},
#    {'color': 'black', 'price': 125, 'deadstockSold': 49},
#    {'color': 'heather-grey', 'price': 78, 'deadstockSold': 33},
#    {'color': 'navy', 'price': 98, 'deadstockSold': 12},
#    {'color': 'pale-blue', 'price': 82, 'deadstockSold': 9},
#    {'color': 'green', 'price': 87, 'deadstockSold': 5},
#    {'color': 'red', 'price': 106, 'deadstockSold': 3},
#    {'color': 'bright-yellow', 'price': 61, 'deadstockSold': 3},
#    {'color': 'light-purple', 'price': 117, 'deadstockSold': 3}],
#   'average': 98.11111111111111,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Fiorenza Tee',
#   'search': 'supreme-Fiorenza-Tee-black',
#   'colors': [{'color': 'light-purple', 'price': 55, 'deadstockSold': 6},
#    {'color': 'black', 'price': 68, 'deadstockSold': 34},
#    {'color': 'white', 'price': 65, 'deadstockSold': 15},
#    {'color': 'heather-grey', 'price': 59, 'deadstockSold': 12},
#    {'color': 'red', 'price': 54, 'deadstockSold': 9},
#    {'color': 'navy', 'price': 52, 'deadstockSold': 7},
#    {'color': 'bright-yellow', 'price': 58, 'deadstockSold': 7},
#    {'color': 'pale-blue', 'price': 73, 'deadstockSold': 5}],
#   'average': 60.5,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Ladybug Tee',
#   'search': 'supreme-Ladybug-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50, 'deadstockSold': 11},
#    {'color': 'light-purple', 'price': 47, 'deadstockSold': 6},
#    {'color': 'black', 'price': 56, 'deadstockSold': 31},
#    {'color': 'white', 'price': 53, 'deadstockSold': 13},
#    {'color': 'navy', 'price': 60, 'deadstockSold': 11},
#    {'color': 'red', 'price': 66, 'deadstockSold': 6},
#    {'color': 'pale-blue', 'price': 54, 'deadstockSold': 6},
#    {'color': 'bright-yellow', 'price': 45, 'deadstockSold': 2},
#    {'color': 'green', 'price': 44, 'deadstockSold': 2}],
#   'average': 52.77777777777778,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Fuck Face Tee',
#   'search': 'supreme-Fuck-Face-Tee-black',
#   'colors': [{'color': 'black', 'price': 74, 'deadstockSold': 25},
#    {'color': 'white', 'price': 67, 'deadstockSold': 13},
#    {'color': 'heather-grey', 'price': 57, 'deadstockSold': 8},
#    {'color': 'red', 'price': 53, 'deadstockSold': 4},
#    {'color': 'pale-blue', 'price': 65, 'deadstockSold': 4},
#    {'color': 'light-purple', 'price': 53, 'deadstockSold': 2},
#    {'color': 'bright-yellow', 'price': 43, 'deadstockSold': 2},
#    {'color': 'green', 'price': 45, 'deadstockSold': 1},
#    {'color': 'navy', 'price': 65, 'deadstockSold': 1}],
#   'average': 58.0,
#   'date': '3/29/2018',
#   'retail': '36'},
#  {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#   'search': 'supreme-nan-goldinsupreme-kim-in-rhinestone-tee-black',
#   'colors': [{'color': 'black', 'price': 78, 'deadstockSold': 27},
#    {'color': 'heather-grey', 'price': 70, 'deadstockSold': 10},
#    {'color': 'white', 'price': 79, 'deadstockSold': 7},
#    {'color': 'royal', 'price': 53, 'deadstockSold': 6},
#    {'color': 'red', 'price': 58, 'deadstockSold': 3},
#    {'color': 'pale-yellow', 'price': 20, 'deadstockSold': 1}],
#   'average': 59.666666666666664,
#   'date': '3/29/2018',
#   'retail': '48'},
#  {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#   'search': 'supreme-nan-goldinsupreme-misty-and-jimmy-paulette-tee-black',
#   'colors': [{'color': 'black', 'price': 65, 'deadstockSold': 11},
#    {'color': 'red', 'price': 43, 'deadstockSold': 3},
#    {'color': 'white', 'price': 58, 'deadstockSold': 3},
#    {'color': 'heather-grey', 'price': 82, 'deadstockSold': 2},
#    {'color': 'pale-yellow', 'price': None, 'deadstockSold': 0},
#    {'color': 'royal', 'price': None, 'deadstockSold': 0}],
#   'average': 62.0,
#   'date': '3/29/2018',
#   'retail': '48'},
#  {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#   'search': 'supreme-nan-goldinsupreme-nan-as-a-dominatrix-tee-black',
#   'colors': [{'color': 'black', 'price': 62, 'deadstockSold': 13},
#    {'color': 'hot-pink', 'price': 35, 'deadstockSold': 2},
#    {'color': 'white', 'price': 52, 'deadstockSold': 2},
#    {'color': 'royal', 'price': 50, 'deadstockSold': 2},
#    {'color': 'heather-grey', 'price': 45, 'deadstockSold': 1},
#    {'color': 'pale-yellow', 'price': None, 'deadstockSold': 0}],
#   'average': 48.8,
#   'date': '3/29/2018',
#   'retail': '48'},
#  {'name': 'SupremeÂ®/The North FaceÂ® Metallic Logo T-Shirt',
#   'search': 'supreme-the-north-face-metallic-logo-t-shirt-black',
#   'colors': [],
#   'date': '4/5/2018'},
#  {'name': 'Supreme/Hellraiser Hell on Earth Tee',
#   'search': 'supreme-hellraiser-hell-on-earth-tee-black',
#   'colors': [{'color': 'black', 'price': 98, 'deadstockSold': 64},
#    {'color': 'white', 'price': 90, 'deadstockSold': 27}],
#   'average': 94.0,
#   'date': '4/26/2018',
#   'retail': '44'},
#  {'name': 'Supreme/Hellraiser Pinhead Tee',
#   'search': 'supreme-hellraiser-pinhead-tee-black',
#   'colors': [{'color': 'black', 'price': 101, 'deadstockSold': 46},
#    {'color': 'white', 'price': 81, 'deadstockSold': 20}],
#   'average': 91.0,
#   'date': '4/26/2018',
#   'retail': '44'},
#  {'name': 'Dream Tee',
#   'search': 'supreme-Dream-Tee-black',
#   'colors': [{'color': 'black', 'price': 123, 'deadstockSold': 6},
#    {'color': 'white', 'price': 73, 'deadstockSold': 2},
#    {'color': 'mocha', 'price': 60, 'deadstockSold': 1},
#    {'color': 'aqua', 'price': None, 'deadstockSold': 0},
#    {'color': 'pale-pink', 'price': None, 'deadstockSold': 0},
#    {'color': 'light-green', 'price': None, 'deadstockSold': 0}],
#   'average': 85.33333333333333,
#   'date': '5/31/2018',
#   'retail': '44'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Classic Swirl T-Shirt',
#   'search': 'supreme-spitfire-classic-swirl-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 67, 'deadstockSold': 92},
#    {'color': 'white', 'price': 81, 'deadstockSold': 83},
#    {'color': 'red', 'price': 71, 'deadstockSold': 28},
#    {'color': 'dark-green', 'price': 73, 'deadstockSold': 20},
#    {'color': 'light-purple', 'price': 84, 'deadstockSold': 11},
#    {'color': 'bright-orange', 'price': 68, 'deadstockSold': 10}],
#   'average': 74.0,
#   'date': '6/21/2018'},
#  {'name': 'SupremeÂ®/SpitfireÂ® Cat T-Shirt',
#   'search': 'supreme-spitfire-cat-t-shirt-black',
#   'colors': [{'color': 'black', 'price': 71, 'deadstockSold': 39},
#    {'color': 'ash-grey', 'price': 60, 'deadstockSold': 14},
#    {'color': 'red', 'price': 58, 'deadstockSold': 13},
#    {'color': 'white', 'price': 84, 'deadstockSold': 13},
#    {'color': 'dark-green', 'price': 79, 'deadstockSold': 4},
# ...
#    {'color': 'acid-yellow', 'price': 60}],
#   'average': 71.5,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Reaper Tee',
#   'search': 'supreme-Reaper-Tee-black',
#   'colors': [{'color': 'white', 'price': 59},
#    {'color': 'dark-sage', 'price': 72},
#    {'color': 'acid-yellow', 'price': 61},
#    {'color': 'light-slate', 'price': 63},
#    {'color': 'black', 'price': 75},
#    {'color': 'ash-grey', 'price': 51},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 56},
#    {'color': 'light-pink', 'price': 68}],
#   'average': 62.44444444444444,
#   'date': '6/27/2019',
#   'retail': '44'},
#  {'name': 'Buju Banton Wake The World Tee',
#   'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#   'colors': [{'color': 'black', 'price': 83},
#    {'color': 'white', 'price': 78},
#    {'color': 'red', 'price': 55},
#    {'color': 'navy', 'price': 66},
#    {'color': 'green', 'price': 56},
#    {'color': 'clay', 'price': 93},
#    {'color': 'neon-orange', 'price': 66},
#    {'color': 'light-blue', 'price': 77}],
#   'average': 71.75,
#   'date': '6/27/2019',
#   'retail': '44'},
#  {'name': 'Bela Lugosi Tee',
#   'search': 'supreme-Bela-Lugosi-Tee-black',
#   'colors': [{'color': 'white', 'price': 54},
#    {'color': 'black', 'price': 61},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'purple', 'price': 58},
#    {'color': 'navy', 'price': 53},
#    {'color': 'light-slate', 'price': 52},
#    {'color': 'acid-yellow', 'price': 47}],
#   'average': 53.75,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Greetings Tee',
#   'search': 'supreme-Greetings-Tee-black',
#   'colors': [{'color': 'black', 'price': 51},
#    {'color': 'light-pink', 'price': 60},
#    {'color': 'white', 'price': 52},
#    {'color': 'heather-grey', 'price': 52},
#    {'color': 'red', 'price': 47},
#    {'color': 'navy', 'price': 48},
#    {'color': 'acid-yellow', 'price': 48},
#    {'color': 'light-slate', 'price': 53}],
#   'average': 51.375,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Cloud Tee',
#   'search': 'supreme-Cloud-Tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 53},
#    {'color': 'light-blue', 'price': 53},
#    {'color': 'acid-yellow', 'price': 51},
#    {'color': 'navy', 'price': 62},
#    {'color': 'light-pink', 'price': 76},
#    {'color': 'red', 'price': 51},
#    {'color': 'brown', 'price': 60}],
#   'average': 58.25,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'It Gets Better Every Time Tee',
#   'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#   'colors': [{'color': 'white', 'price': 52},
#    {'color': 'light-pink', 'price': 58},
#    {'color': 'black', 'price': 49},
#    {'color': 'light-slate', 'price': 48},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'red', 'price': 48},
#    {'color': 'navy', 'price': 51},
#    {'color': 'acid-yellow', 'price': 46}],
#   'average': 49.75,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Shears Tee',
#   'search': 'supreme-Shears-Tee-black',
#   'colors': [{'color': 'black', 'price': 53},
#    {'color': 'white', 'price': 51},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'heather-grey', 'price': 44},
#    {'color': 'red', 'price': 44},
#    {'color': 'light-slate', 'price': 46},
#    {'color': 'acid-yellow', 'price': 44},
#    {'color': 'navy', 'price': 53}],
#   'average': 48.375,
#   'date': '6/27/2019',
#   'retail': '38'},
#  {'name': 'Banner Tee',
#   'search': 'supreme-Banner-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 77},
#    {'color': 'black', 'price': 86},
#    {'color': 'white', 'price': 80},
#    {'color': 'navy', 'price': 73},
#    {'color': 'slate', 'price': 74},
#    {'color': 'red', 'price': 61},
#    {'color': 'natural', 'price': 74},
#    {'color': 'magenta', 'price': 58}],
#   'average': 72.875,
#   'date': '8/22/2019'},
#  {'name': 'Smoke Tee',
#   'search': 'supreme-Smoke-Tee-black',
#   'colors': [{'color': 'black', 'price': 82},
#    {'color': 'white', 'price': 61},
#    {'color': 'natural', 'price': 64},
#    {'color': 'navy', 'price': 68},
#    {'color': 'red', 'price': 60},
#    {'color': 'magenta', 'price': 53},
#    {'color': 'sulfer', 'price': 50}],
#   'average': 62.57142857142857,
#   'date': '8/22/2019'},
#  {'name': 'Mary J. Blige Tee',
#   'search': 'supreme-Mary-J-Blige-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 64},
#    {'color': 'heather-grey', 'price': 61},
#    {'color': 'red', 'price': 59},
#    {'color': 'slate', 'price': 66},
#    {'color': 'magenta', 'price': 77},
#    {'color': 'sulfer', 'price': 55},
#    {'color': 'navy', 'price': 71}],
#   'average': 66.5,
#   'date': '8/22/2019'},
#  {'name': 'Heaven and Earth Tee',
#   'search': 'supreme-Heaven-and-Earth-Tee-black',
#   'colors': [{'color': 'black', 'price': 59},
#    {'color': 'royal', 'price': 54},
#    {'color': 'white', 'price': 60},
#    {'color': 'navy', 'price': 57},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'red', 'price': 52},
#    {'color': 'sulfer', 'price': 51}],
#   'average': 55.285714285714285,
#   'date': '8/22/2019'},
#  {'name': 'Save The Planet Tee',
#   'search': 'supreme-Save-The-Planet-Tee-black',
#   'colors': [{'color': 'black', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'white', 'price': 54},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'slate', 'price': 53},
#    {'color': 'sulfer', 'price': 47},
#    {'color': 'magenta', 'price': 46}],
#   'average': 50.0,
#   'date': '8/22/2019'},
#  {'name': 'New Shit Tee',
#   'search': 'supreme-New-Shit-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'red', 'price': 52},
#    {'color': 'navy', 'price': 54},
#    {'color': 'magenta', 'price': 51},
#    {'color': 'sulfer', 'price': 49}],
#   'average': 53.0,
#   'date': '8/22/2019'},
#  {'name': 'Queen Tee',
#   'search': 'supreme-Queen-Tee-black',
#   'colors': [{'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 62},
#    {'color': 'red', 'price': 57},
#    {'color': 'navy', 'price': 51},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'slate', 'price': 54},
#    {'color': 'sulfer', 'price': 51},
#    {'color': 'magenta', 'price': 62}],
#   'average': 56.125,
#   'date': '8/22/2019'},
#  {'name': 'Levitation Tee',
#   'search': 'supreme-Levitation-Tee-black',
#   'colors': [{'color': 'black', 'price': 68},
#    {'color': 'slate', 'price': 61},
#    {'color': 'red', 'price': 57},
#    {'color': 'white', 'price': 66},
#    {'color': 'dark-green', 'price': 58},
#    {'color': 'heather-grey', 'price': 54},
#    {'color': 'sulfer', 'price': 55}],
#   'average': 59.857142857142854,
#   'date': '8/22/2019'},
#  {'name': 'Faces L/S Tee',
#   'search': 'supreme-faces-l-s-tee-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'white', 'price': 63},
#    {'color': 'heather-grey', 'price': 55},
#    {'color': 'pale-yellow', 'price': 57},
#    {'color': 'navy', 'price': 58},
#    {'color': 'light-slate', 'price': 61},
#    {'color': 'burgundy', 'price': 55},
#    {'color': 'olive', 'price': 48}],
#   'average': 57.5,
#   'date': '8/22/2019'},
#  {'name': 'Super Cream Tee',
#   'search': 'supreme-Super-Cream-Tee-black',
#   'colors': [{'color': 'black', 'price': 47},
#    {'color': 'white', 'price': 50},
#    {'color': 'slate', 'price': 45},
#    {'color': 'sulfer', 'price': 43},
#    {'color': 'red', 'price': 45},
#    {'color': 'navy', 'price': 48},
#    {'color': 'heather-grey', 'price': 47}],
#   'average': 46.42857142857143,
#   'date': '8/22/2019'},
#  {'name': 'Supreme/The Velvet Underground Tee',
#   'search': 'supreme-the-velvet-underground-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-slate', 'price': 50},
#    {'color': 'red', 'price': 50},
#    {'color': 'yellow', 'price': 50}],
#   'average': 52.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground & Nico Tee',
#   'search': 'supreme-the-velvet-underground-nico-tee-black',
#   'colors': [{'color': 'white', 'price': 63},
#    {'color': 'black', 'price': 54},
#    {'color': 'light-slate', 'price': 65},
#    {'color': 'red', 'price': 63},
#    {'color': 'yellow', 'price': 56}],
#   'average': 60.2,
#   'date': '9/19/2019'},
#  {'name': 'Supreme/The Velvet Underground Drawing Tee',
#   'search': 'supreme-the-velvet-underground-drawing-tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 61},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'yellow', 'price': 68},
#    {'color': 'red', 'price': 52}],
#   'average': 58.2,
#   'date': '9/19/2019'},
#  {'name': 'Pillows Tee',
#   'search': 'supreme-Pillows-Tee-black',
#   'colors': [{'color': 'black', 'price': 74},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'navy', 'price': 66},
#    {'color': 'burgundy', 'price': 58},
#    {'color': 'bright-orange', 'price': 65},
#    {'color': 'white', 'price': 70},
#    {'color': 'dusty-teal', 'price': 68}],
#   'average': 65.28571428571429,
#   'date': '10/10/2019'},
#  {'name': 'Life Tee',
#   'search': 'supreme-Life-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 50},
#    {'color': 'black', 'price': 57},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 53},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'slate', 'price': 57},
#    {'color': 'burnt-orange', 'price': 49},
#    {'color': 'red', 'price': 46}],
#   'average': 52.375,
#   'date': '10/10/2019'},
#  {'name': 'Bible Tee',
#   'search': 'supreme-Bible-Tee-black',
#   'colors': [{'color': 'black', 'price': 76},
#    {'color': 'light-slate', 'price': 54},
#    {'color': 'white', 'price': 73},
#    {'color': 'ash-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 60},
#    {'color': 'red', 'price': 54},
#    {'color': 'navy', 'price': 60},
#    {'color': 'burnt-orange', 'price': 57}],
#   'average': 61.25,
#   'date': '10/10/2019'},
#  {'name': 'Mercenary Tee',
#   'search': 'supreme-Mercenary-Tee-black',
#   'colors': [{'color': 'black', 'price': 58},
#    {'color': 'royal', 'price': 53},
#    {'color': 'white', 'price': 58},
#    {'color': 'heather-grey', 'price': 50},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 47},
#    {'color': 'burnt-orange', 'price': 49}],
#   'average': 53.285714285714285,
#   'date': '10/10/2019'},
#  {'name': 'American Picture Tee',
#   'search': 'supreme-American-Picture-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 51},
#    {'color': 'ash-grey', 'price': 46},
#    {'color': 'navy', 'price': 52},
#    {'color': 'burgundy', 'price': 50},
#    {'color': 'dark-green', 'price': 53},
#    {'color': 'burnt-orange', 'price': 53}],
#   'average': 52.125,
#   'date': '10/10/2019'},
#  {'name': 'Cheese Tee',
#   'search': 'supreme-Cheese-Tee-black',
#   'colors': [{'color': 'black', 'price': 52},
#    {'color': 'woodland-camo', 'price': 49},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'navy', 'price': 53},
#    {'color': 'orange', 'price': 54},
#    {'color': 'red', 'price': 52}],
#   'average': 53.142857142857146,
#   'date': '10/10/2019'},
#  {'name': "We're Back Tee",
#   'search': 'supreme-were-back-tee-black',
#   'colors': [{'color': 'black', 'price': 49},
#    {'color': 'heather-grey', 'price': 46},
#    {'color': 'red', 'price': 45},
#    {'color': 'white', 'price': 54},
#    {'color': 'slate', 'price': 48},
#    {'color': 'dark-green', 'price': 55},
#    {'color': 'heather-light-pink', 'price': 45},
#    {'color': 'sulfur', 'price': 54}],
#   'average': 49.5,
#   'date': '10/10/2019'},
#  {'name': 'Inc. Tee',
#   'search': 'supreme-Inc-Tee-black',
#   'colors': [{'color': 'white', 'price': 58},
#    {'color': 'black', 'price': 56},
#    {'color': 'royal', 'price': 56},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'heather-light-pink', 'price': 55},
#    {'color': 'pale-yellow', 'price': 54},
#    {'color': 'dark-green', 'price': 60},
#    {'color': 'red', 'price': 52}],
#   'average': 55.875,
#   'date': '10/10/2019'},
#  {'name': 'Heroines Tee',
#   'search': 'supreme-Heroines-Tee-black',
#   'colors': [{'color': 'white', 'price': 61},
#    {'color': 'navy', 'price': 64},
#    {'color': 'black', 'price': 65},
#    {'color': 'heather-light-pink', 'price': 57},
#    {'color': 'pale-yellow', 'price': 60},
#    {'color': 'dusty-teal', 'price': 70}],
#   'average': 62.833333333333336,
#   'date': '10/10/2019'},
#  {'name': 'SF Box Logo Tee',
#   'search': 'supreme-san-francisco-box-logo-tee-black',
#   'colors': [{'color': 'black', 'price': 452}],
#   'average': 452.0,
#   'date': '10/24/2019'},
#  {'name': 'Supreme/dead prez Tee',
#   'search': 'supreme-dead-prez-tee-black',
#   'colors': [{'color': 'red', 'price': 57},
#    {'color': 'black', 'price': 64},
#    {'color': 'woodland-camo', 'price': 60},
#    {'color': 'white', 'price': 59},
#    {'color': 'heather-grey', 'price': 68}],
#   'average': 61.6,
#   'date': '12/5/2019'},
#  {'name': 'Supreme/dead prez RBG Tee',
#   'search': 'supreme-dead-prez-rbg-tee-black',
#   'colors': [{'color': 'woodland-camo', 'price': 60},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 66},
#    {'color': 'white', 'price': 73},
#    {'color': 'red', 'price': 71}],
#   'average': 67.4,
#   'date': '12/5/2019'},
#  {'name': 'Bandana Box Logo Tee',
#   'search': 'supreme-Bandana-Box-Logo-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 279},
#    {'color': 'red', 'price': 254},
#    {'color': 'black', 'price': 313},
#    {'color': 'white', 'price': 291},
#    {'color': 'navy', 'price': 269},
#    {'color': 'yellow', 'price': 226},
#    {'color': 'light-pink', 'price': 290},
#    {'color': 'brown', 'price': 264}],
#   'average': 273.25,
#   'date': '12/19/2019'},
#  {'name': 'Aguila Tee',
#   'search': 'supreme-Aguila-Tee-black',
#   'colors': [{'color': 'black', 'price': 79},
#    {'color': 'white', 'price': 56},
#    {'color': 'woodland-camo', 'price': 56},
#    {'color': 'navy', 'price': 69},
#    {'color': 'purple', 'price': 62},
#    {'color': 'red', 'price': 64},
#    {'color': 'yellow', 'price': 54}],
#   'average': 62.857142857142854,
#   'date': '12/19/2019'},
#  {'name': 'Bite Tee',
#   'search': 'supreme-Bite-Tee-black',
#   'colors': [{'color': 'heather-grey', 'price': 53},
#    {'color': 'black', 'price': 62},
#    {'color': 'white', 'price': 63},
#    {'color': 'neon-orange', 'price': 57},
#    {'color': 'red', 'price': 59},
#    {'color': 'navy', 'price': 61},
#    {'color': 'light-purple', 'price': 67}],
#   'average': 60.285714285714285,
#   'date': '12/19/2019'},
#  {'name': 'Eat Me Tee',
#   'search': 'supreme-Eat-Me-Tee-black',
#   'colors': [{'color': 'white', 'price': 51}, {'color': 'black', 'price': 53}],
#   'average': 52.0,
#   'date': '12/19/2019'},
#  {'name': 'Bridge Tee',
#   'search': 'supreme-Bridge-Tee-black',
#   'colors': [{'color': 'white', 'price': 72},
#    {'color': 'black', 'price': 67},
#    {'color': 'heather-grey', 'price': 56},
#    {'color': 'navy', 'price': 61},
#    {'color': 'magenta', 'price': 50},
#    {'color': 'slate', 'price': 63},
#    {'color': 'red', 'price': 58},
#    {'color': 'sulfur', 'price': 60}],
#   'average': 60.875,
#   'date': '12/19/2019'},
#  {'name': "D'Hiver Tee",
#   'search': 'supreme-d-hiver-tee-black',
#   'colors': [{'color': 'black', 'price': 60},
#    {'color': 'white', 'price': 56},
#    {'color': 'peach', 'price': 54},
#    {'color': 'heather-grey', 'price': 53},
#    {'color': 'dusty-teal', 'price': 56},
#    {'color': 'navy', 'price': 49},
#    {'color': 'burgundy', 'price': 50}],
#   'average': 54.0,
#   'date': '12/19/2019'},
#  {'name': 'Money Power Respect Tee',
#   'search': 'supreme-Money-Power-Respect-Tee-black',
#   'colors': [{'color': 'black', 'price': 56},
#    {'color': 'white', 'price': 55},
#    {'color': 'light-pink', 'price': 52},
#    {'color': 'dusty-teal', 'price': 52},
#    {'color': 'navy', 'price': 56},
#    {'color': 'heather-grey', 'price': 49},
#    {'color': 'red', 'price': 57},
#    {'color': 'acid-yellow', 'price': 51}],
#   'average': 53.5,
#   'date': '12/19/2019'},
#  {'name': 'Clowns Tee',
#   'search': 'supreme-clowns-tee-bleached-black',
#   'colors': [{'color': 'black', 'price': 63},
#    {'color': 'navy', 'price': 64},
#    {'color': 'red', 'price': 55}],
#   'average': 60.666666666666664,
#   'date': '12/19/2019'}]

# %%
len(complete_data)
# Out:
# 194
