# %%
import requests
import json
import threading
import csv
from datetime import datetime
import time

from pyquery import PyQuery as pq

from requests.packages.urllib3.exceptions import InsecureRequestWarning

# %%
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

def log(t):
    ts = datetime.now().strftime('%H:%M:%S')
    print('{} :: {}'.format(ts, t))

# %%
SPRING_SUMMER = 'spring-summer'
FALL_WINTER = 'fall-winter'
SEASON_TEMPLATE = 'https://www.supremecommunity.com/season/{}{}/droplists/'

USER_AGENT_1 = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
USER_AGENT_2 = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
USER_AGENT_3 = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/605.1.15 (KHTML, like Gecko)'
USER_AGENT_4 = 'Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Mobile/13G36'
USER_AGENT_5 = 'Mozilla/5.0 (iPhone; CPU iPhone OS 13_4_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1 Mobile/15E148 Safari/604.1'


def sc_to_stockx_name(sc):
    sc = sc.replace(' ', '-')
    sc = sc.replace('L/S', 'ls')
    sc = sc.replace('/', '-')
    sc = sc.replace('™', '-')
    sc = sc.replace('®', '-')
    sc = sc.replace('&', '-')
    sc = sc.replace('+', '-')
    sc = sc.replace('"', '')
    sc = sc.replace('--', '-')
    sc = sc.replace('.','')
    sc = sc.replace('Supreme', '')
    sc = sc.replace('--', '-')
    return 'supreme-' + sc + '-black'

# %%
class Downloader(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.S = requests.Session()
        self.S.headers = {
            'user-agent': USER_AGENT_1,
            'content-type': 'application/json'
        }
        self.rawdetails = {}
        
    def get_search_results(self, query):
        log('Retrieving search results for {}'.format(query))
        
        r = self.S.request(
            method='get',
            url='https://stockx.com/api/browse?&_search={}'.format(query),
        )
        try:
            j = r.json()
        except json.decoder.JSONDecodeError:
            log('Product detail retrieval failed [{}]'.format(r.status_code))
            return 'Failed'
        try:
            r.raise_for_status()
        except requests.exceptions.HTTPError:
            log('Product detail retrieval failed [{}] : {}'.format(r.status_code, j['error']))
            return 'Failed'
        return j
    
    def get_raw_details(self, product):
        log('Retrieving raw details for {}'.format(product))
        
        r = self.S.request(
            method='get',
            url='https://stockx.com/api/products/{}?includes=market'.format(product),
            params = {
            }
        )
        try: 
            j = r.json()
        except json.decoder.JSONDecodeError:
            log('Product detail retrieval failed [{}]'.format(r.status_code))
            return 'Failed'
        except requests.exceptions.HTTPError as e:
            log("Error: " + str(e))
            return "Failed"
        try:
            r.raise_for_status()
        except requests.exceptions.HTTPError as e:
#             log('Product detail retrieval failed [{}] : {}'.format(r.status_code, j['error']))
            log("Error: " + str(e))
            return "Failed"
        self.rawdetails = j
        return j

# %%
def get_season_links(season, year):
    response = requests.get(SEASON_TEMPLATE.format(season, year))
    doc = pq(response.content)
    links = [('https://www.supremecommunity.com' + pq(block).attr('href'), pq(block).attr('href')[-11:-1])
            for block in doc('a.block')]
    links.reverse()
    return links

def get_week_tees_from_url(url):
    response = requests.get(url)
    doc = pq(response.content)
    return [{'name': pq(card).find('h2').text()} 
            for card in doc('.card.card-2') 
            if pq(card).find('.category').text() == 't-shirts']

def get_season_tees(season, year):
    return [{"week": link[1],"tees": get_week_tees_from_url(link[0])}
            for link in get_season_links(season,year)]

def get_all_tees():
    return [get_season_tees(s,y) for y in [2018] for s in [SPRING_SUMMER]]

def add_stockx_names(lst):
    for season in lst:
        for week in season:
            for t in week['tees']:
                t['search'] = sc_to_stockx_name(t['name'])
    return lst

# TODO: verify urls, then a getter for colors

def ss18(lst):
    for season in lst:
        for week in season:
            for t in week['tees']:
                if week['week'] == '2018-06-28':
                    t['search'] += '-ss18' 
        
def add_stockx_prices(lst):
    d = Downloader()
    for season in lst:
        for week in season:
            for t in week['tees']:
                # 3 seconds is enough to avoid bans
                time.sleep(3)
                search_result = d.get_raw_details(t['search'])
                try:
                    t['price'] = search_result['Product']['market']['averageDeadstockPrice']
                    if t['price'] == 0:
                        t['price'] = "Bad search: zero average"
                    print('Good search. '+ str(t['price']))
                except (AttributeError, IndexError, TypeError, KeyError):
                    print("{} was a bad search".format(t['search']))
                    t['price'] = "Bad search"
    return lst

# %%
all_tees = get_all_tees()
all_tees
# Out:
# [[{'week': '2019-02-21',
#    'tees': [{'name': 'Creeper Tee'},
#     {'name': 'Christopher Walken King Of New York Tee'},
#     {'name': 'The Real Shit L/S Tee'},
#     {'name': 'Knot Tee'},
#     {'name': 'Fruit Tee'},
#     {'name': 'Kids Tee'},
#     {'name': 'Fronts Tee'},
#     {'name': 'Hard Goods Tee'},
#     {'name': 'Leda And The Swan Tee'},
#     {'name': 'Original Sin Tee'},
#     {'name': 'Middle Finger To The World Tee'}]},
#   {'week': '2019-02-25',
#    'tees': [{'name': 'Creeper Tee'},
#     {'name': 'Christopher Walken King Of New York Tee'},
#     {'name': 'The Real Shit L/S Tee'},
#     {'name': 'Knot Tee'},
#     {'name': 'Fruit Tee'},
#     {'name': 'Kids Tee'},
#     {'name': 'Fronts Tee'},
#     {'name': 'Hard Goods Tee'},
#     {'name': 'Leda And The Swan Tee'},
#     {'name': 'Original Sin Tee'},
#     {'name': 'Middle Finger To The World Tee'}]},
#   {'week': '2019-03-07', 'tees': []},
#   {'week': '2019-03-14', 'tees': []},
#   {'week': '2019-03-21',
#    'tees': [{'name': 'Gilbert & George/Supreme LIFE Tee'},
#     {'name': 'Gilbert & George/Supreme DEATH Tee'}]},
#   {'week': '2019-03-28', 'tees': []},
#   {'week': '2019-04-04',
#    'tees': [{'name': 'Cupid Tee'},
#     {'name': 'Who The Fuck Tee'},
#     {'name': 'Ghost Rider© Tee'},
#     {'name': 'Riders Tee'},
#     {'name': 'The Persistence of Memory Tee'},
#     {'name': 'Molotov Kid Tee'},
#     {'name': 'Suzie Switchblade Tee'},
#     {'name': 'Keyboard Tee'},
#     {'name': 'Headline Tee'}]},
#   {'week': '2019-04-11',
#    'tees': [{'name': 'Supreme®/Jean Paul Gaultier® Tee'}]},
#   {'week': '2019-04-18', 'tees': []},
#   {'week': '2019-04-25',
#    'tees': [{'name': 'Supreme®/Swarovski® Box Logo Tee'}]},
#   {'week': '2019-05-02', 'tees': []},
#   {'week': '2019-05-09', 'tees': []},
#   {'week': '2019-05-16', 'tees': []},
#   {'week': '2019-05-23', 'tees': []},
#   {'week': '2019-05-30', 'tees': []},
#   {'week': '2019-06-06', 'tees': []},
#   {'week': '2019-06-13', 'tees': []},
#   {'week': '2019-06-20', 'tees': []},
#   {'week': '2019-06-27',
#    'tees': [{'name': 'Buju Banton Tee'},
#     {'name': 'Dynamite Tee'},
#     {'name': 'Reaper Tee'},
#     {'name': 'Buju Banton Wake The World Tee'},
#     {'name': 'Bela Lugosi Tee'},
#     {'name': 'Greetings Tee'},
#     {'name': 'Cloud Tee'},
#     {'name': 'It Gets Better Every Time Tee'},
#     {'name': 'Shears Tee'}]},
#   {'week': '2019-07-05', 'tees': []},
#   {'week': '2019-07-11', 'tees': []}],
#  [{'week': '2019-08-22',
#    'tees': [{'name': 'Banner Tee'},
#     {'name': 'Smoke Tee'},
#     {'name': 'Mary J. Blige Tee'},
#     {'name': 'Heaven and Earth Tee'},
#     {'name': 'Save The Planet Tee'},
#     {'name': 'New Shit Tee'},
#     {'name': 'Queen Tee'},
#     {'name': 'Levitation Tee'},
#     {'name': 'Faces L/S Tee'},
#     {'name': 'Super Cream Tee'}]},
#   {'week': '2019-08-26',
#    'tees': [{'name': 'Banner Tee'},
#     {'name': 'Smoke Tee'},
#     {'name': 'Mary J. Blige Tee'},
#     {'name': 'Heaven and Earth Tee'},
#     {'name': 'Save The Planet Tee'},
#     {'name': 'New Shit Tee'},
#     {'name': 'Queen Tee'},
#     {'name': 'Levitation Tee'},
#     {'name': 'Faces L/S Tee'},
#     {'name': 'Super Cream Tee'}]},
#   {'week': '2019-09-05', 'tees': []},
#   {'week': '2019-09-12', 'tees': []},
#   {'week': '2019-09-19',
#    'tees': [{'name': 'Supreme/The Velvet Underground Tee'},
#     {'name': 'Supreme/The Velvet Underground & Nico Tee'},
#     {'name': 'Supreme/The Velvet Underground Drawing Tee'}]},
#   {'week': '2019-09-26', 'tees': []},
#   {'week': '2019-10-03', 'tees': []},
#   {'week': '2019-10-10',
#    'tees': [{'name': 'Pillows Tee'},
#     {'name': 'Life Tee'},
#     {'name': 'Bible Tee'},
#     {'name': 'Mercenary Tee'},
#     {'name': 'American Picture Tee'},
#     {'name': 'Cheese Tee'},
#     {'name': "We're Back Tee"},
#     {'name': 'Inc. Tee'},
#     {'name': 'Heroines Tee'}]},
#   {'week': '2019-10-17', 'tees': []},
#   {'week': '2019-10-24', 'tees': [{'name': 'SF Box Logo Tee'}]},
#   {'week': '2019-10-31', 'tees': []},
#   {'week': '2019-11-07', 'tees': []},
#   {'week': '2019-11-14', 'tees': []},
#   {'week': '2019-11-21', 'tees': []},
#   {'week': '2019-11-29', 'tees': []},
#   {'week': '2019-12-05',
#    'tees': [{'name': 'Supreme/dead prez Tee'},
#     {'name': 'Supreme/dead prez RBG Tee'}]},
#   {'week': '2019-12-12', 'tees': []},
#      'price': 'Bad search'},
#     {'name': 'Knot Tee', 'search': 'supreme-Knot-Tee-black', 'price': 54},
#     {'name': 'Fruit Tee', 'search': 'supreme-Fruit-Tee-black', 'price': 66},
#     {'name': 'Kids Tee', 'search': 'supreme-Kids-Tee-black', 'price': 79},
#     {'name': 'Fronts Tee', 'search': 'supreme-Fronts-Tee-black', 'price': 65},
#     {'name': 'Hard Goods Tee',
#      'search': 'supreme-Hard-Goods-Tee-black',
#      'price': 79},
#     {'name': 'Leda And The Swan Tee',
#      'search': 'supreme-Leda-And-The-Swan-Tee-black',
#      'price': 57},
#     {'name': 'Original Sin Tee',
#      'search': 'supreme-Original-Sin-Tee-black',
#      'price': 64},
#     {'name': 'Middle Finger To The World Tee',
#      'search': 'supreme-Middle-Finger-To-The-World-Tee-black',
#      'price': 49}]},
#   {'week': '2019-02-25',
#    'tees': [{'name': 'Creeper Tee',
#      'search': 'supreme-Creeper-Tee-black',
#      'price': 96},
#     {'name': 'Christopher Walken King Of New York Tee',
#      'search': 'supreme-Christopher-Walken-King-Of-New-York-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'The Real Shit L/S Tee',
#      'search': 'supreme-The-Real-Shit-ls-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Knot Tee', 'search': 'supreme-Knot-Tee-black', 'price': 54},
#     {'name': 'Fruit Tee', 'search': 'supreme-Fruit-Tee-black', 'price': 66},
#     {'name': 'Kids Tee', 'search': 'supreme-Kids-Tee-black', 'price': 79},
#     {'name': 'Fronts Tee', 'search': 'supreme-Fronts-Tee-black', 'price': 65},
#     {'name': 'Hard Goods Tee',
#      'search': 'supreme-Hard-Goods-Tee-black',
#      'price': 79},
#     {'name': 'Leda And The Swan Tee',
#      'search': 'supreme-Leda-And-The-Swan-Tee-black',
#      'price': 57},
#     {'name': 'Original Sin Tee',
#      'search': 'supreme-Original-Sin-Tee-black',
#      'price': 64},
#     {'name': 'Middle Finger To The World Tee',
#      'search': 'supreme-Middle-Finger-To-The-World-Tee-black',
#      'price': 49}]},
#   {'week': '2019-03-07', 'tees': []},
#   {'week': '2019-03-14', 'tees': []},
#   {'week': '2019-03-21',
#    'tees': [{'name': 'Gilbert & George/Supreme LIFE Tee',
#      'search': 'supreme-Gilbert-George-LIFE-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Gilbert & George/Supreme DEATH Tee',
#      'search': 'supreme-Gilbert-George-DEATH-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2019-03-28', 'tees': []},
#   {'week': '2019-04-04',
#    'tees': [{'name': 'Cupid Tee',
#      'search': 'supreme-Cupid-Tee-black',
#      'price': 141},
#     {'name': 'Who The Fuck Tee',
#      'search': 'supreme-Who-The-Fuck-Tee-black',
#      'price': 65},
#     {'name': 'Ghost Rider© Tee',
#      'search': 'supreme-Ghost-Rider©-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Riders Tee', 'search': 'supreme-Riders-Tee-black', 'price': 61},
#     {'name': 'The Persistence of Memory Tee',
#      'search': 'supreme-The-Persistence-of-Memory-Tee-black',
#      'price': 67},
#     {'name': 'Molotov Kid Tee',
#      'search': 'supreme-Molotov-Kid-Tee-black',
#      'price': 62},
#     {'name': 'Suzie Switchblade Tee',
#      'search': 'supreme-Suzie-Switchblade-Tee-black',
#      'price': 60},
#     {'name': 'Keyboard Tee',
#      'search': 'supreme-Keyboard-Tee-black',
#      'price': 53},
#     {'name': 'Headline Tee',
#      'search': 'supreme-Headline-Tee-black',
#      'price': 56}]},
#   {'week': '2019-04-11',
#    'tees': [{'name': 'Supreme®/Jean Paul Gaultier® Tee',
#      'search': 'supreme--Jean-Paul-Gaultier-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2019-04-18', 'tees': []},
#   {'week': '2019-04-25',
#    'tees': [{'name': 'Supreme®/Swarovski® Box Logo Tee',
#      'search': 'supreme--Swarovski-Box-Logo-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2019-05-02', 'tees': []},
#   {'week': '2019-05-09', 'tees': []},
#   {'week': '2019-05-16', 'tees': []},
#   {'week': '2019-05-23', 'tees': []},
#   {'week': '2019-05-30', 'tees': []},
#   {'week': '2019-06-06', 'tees': []},
#   {'week': '2019-06-13', 'tees': []},
#   {'week': '2019-06-20', 'tees': []},
#   {'week': '2019-06-27',
#    'tees': [{'name': 'Buju Banton Tee',
#      'search': 'supreme-Buju-Banton-Tee-black',
#      'price': 135},
#     {'name': 'Dynamite Tee',
#      'search': 'supreme-Dynamite-Tee-black',
#      'price': 75},
#     {'name': 'Reaper Tee', 'search': 'supreme-Reaper-Tee-black', 'price': 75},
#     {'name': 'Buju Banton Wake The World Tee',
#      'search': 'supreme-Buju-Banton-Wake-The-World-Tee-black',
#      'price': 83},
#     {'name': 'Bela Lugosi Tee',
#      'search': 'supreme-Bela-Lugosi-Tee-black',
#      'price': 61},
#     {'name': 'Greetings Tee',
#      'search': 'supreme-Greetings-Tee-black',
#      'price': 51},
#     {'name': 'Cloud Tee', 'search': 'supreme-Cloud-Tee-black', 'price': 60},
#     {'name': 'It Gets Better Every Time Tee',
#      'search': 'supreme-It-Gets-Better-Every-Time-Tee-black',
#      'price': 49},
#     {'name': 'Shears Tee',
#      'search': 'supreme-Shears-Tee-black',
#      'price': 54}]},
#   {'week': '2019-07-05', 'tees': []},
#   {'week': '2019-07-11', 'tees': []}],
#  [{'week': '2019-08-22',
#    'tees': [{'name': 'Banner Tee',
#      'search': 'supreme-Banner-Tee-black',
#      'price': 86},
#     {'name': 'Smoke Tee', 'search': 'supreme-Smoke-Tee-black', 'price': 82},
#     {'name': 'Mary J. Blige Tee',
#      'search': 'supreme-Mary-J-Blige-Tee-black',
#      'price': 79},
#     {'name': 'Heaven and Earth Tee',
#      'search': 'supreme-Heaven-and-Earth-Tee-black',
#      'price': 59},
#     {'name': 'Save The Planet Tee',
#      'search': 'supreme-Save-The-Planet-Tee-black',
#      'price': 50},
#     {'name': 'New Shit Tee',
#      'search': 'supreme-New-Shit-Tee-black',
#      'price': 55},
#     {'name': 'Queen Tee', 'search': 'supreme-Queen-Tee-black', 'price': 57},
#     {'name': 'Levitation Tee',
#      'search': 'supreme-Levitation-Tee-black',
#      'price': 68},
#     {'name': 'Faces L/S Tee',
#      'search': 'supreme-Faces-ls-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Super Cream Tee',
#      'search': 'supreme-Super-Cream-Tee-black',
#      'price': 47}]},
#   {'week': '2019-08-26',
#    'tees': [{'name': 'Banner Tee',
#      'search': 'supreme-Banner-Tee-black',
#      'price': 86},
#     {'name': 'Smoke Tee', 'search': 'supreme-Smoke-Tee-black', 'price': 82},
#     {'name': 'Mary J. Blige Tee',
#      'search': 'supreme-Mary-J-Blige-Tee-black',
#      'price': 79},
#     {'name': 'Heaven and Earth Tee',
#      'search': 'supreme-Heaven-and-Earth-Tee-black',
#      'price': 59},
#     {'name': 'Save The Planet Tee',
#      'search': 'supreme-Save-The-Planet-Tee-black',
#      'price': 50},
#     {'name': 'New Shit Tee',
#      'search': 'supreme-New-Shit-Tee-black',
#      'price': 55},
#     {'name': 'Queen Tee', 'search': 'supreme-Queen-Tee-black', 'price': 57},
#     {'name': 'Levitation Tee',
#      'search': 'supreme-Levitation-Tee-black',
#      'price': 68},
#     {'name': 'Faces L/S Tee',
#      'search': 'supreme-Faces-ls-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Super Cream Tee',
#      'search': 'supreme-Super-Cream-Tee-black',
#      'price': 47}]},
#   {'week': '2019-09-05', 'tees': []},
#   {'week': '2019-09-12', 'tees': []},
#   {'week': '2019-09-19',
#    'tees': [{'name': 'Supreme/The Velvet Underground Tee',
#      'search': 'supreme--The-Velvet-Underground-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme/The Velvet Underground & Nico Tee',
#      'search': 'supreme--The-Velvet-Underground-Nico-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme/The Velvet Underground Drawing Tee',
#      'search': 'supreme--The-Velvet-Underground-Drawing-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2019-09-26', 'tees': []},
#   {'week': '2019-10-03', 'tees': []},
#   {'week': '2019-10-10',
#    'tees': [{'name': 'Pillows Tee',
#      'search': 'supreme-Pillows-Tee-black',
#      'price': 74},
#     {'name': 'Life Tee', 'search': 'supreme-Life-Tee-black', 'price': 57},
#     {'name': 'Bible Tee', 'search': 'supreme-Bible-Tee-black', 'price': 76},
#     {'name': 'Mercenary Tee',
#      'search': 'supreme-Mercenary-Tee-black',
#      'price': 58},
#     {'name': 'American Picture Tee',
#      'search': 'supreme-American-Picture-Tee-black',
#      'price': 55},
#     {'name': 'Cheese Tee', 'search': 'supreme-Cheese-Tee-black', 'price': 52},
#     {'name': "We're Back Tee",
#      'search': "supreme-We're-Back-Tee-black",
#      'price': 'Bad search'},
#     {'name': 'Inc. Tee', 'search': 'supreme-Inc-Tee-black', 'price': 56},
#     {'name': 'Heroines Tee',
#      'search': 'supreme-Heroines-Tee-black',
#      'price': 65}]},
#   {'week': '2019-10-17', 'tees': []},
#   {'week': '2019-10-24',
#    'tees': [{'name': 'SF Box Logo Tee',
#      'search': 'supreme-SF-Box-Logo-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2019-10-31', 'tees': []},
#   {'week': '2019-11-07', 'tees': []},
#   {'week': '2019-11-14', 'tees': []},
#   {'week': '2019-11-21', 'tees': []},
#   {'week': '2019-11-29', 'tees': []},
#   {'week': '2019-12-05',
#    'tees': [{'name': 'Supreme/dead prez Tee',
#      'search': 'supreme--dead-prez-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme/dead prez RBG Tee',
#      'search': 'supreme--dead-prez-RBG-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2019-12-12', 'tees': []},
#   {'week': '2019-12-19',
#    'tees': [{'name': 'Bandana Box Logo Tee',
#      'search': 'supreme-Bandana-Box-Logo-Tee-black',
#      'price': 312},
#     {'name': 'Aguila Tee', 'search': 'supreme-Aguila-Tee-black', 'price': 79},
#     {'name': 'Bite Tee', 'search': 'supreme-Bite-Tee-black', 'price': 62},
#     {'name': 'Eat Me Tee', 'search': 'supreme-Eat-Me-Tee-black', 'price': 53},
#     {'name': 'Bridge Tee', 'search': 'supreme-Bridge-Tee-black', 'price': 67},
#     {'name': "D'Hiver Tee",
#      'search': "supreme-D'Hiver-Tee-black",
#      'price': 'Bad search'},
#     {'name': 'Money Power Respect Tee',
#      'search': 'supreme-Money-Power-Respect-Tee-black',
#      'price': 56},
#     {'name': 'Clowns Tee',
#      'search': 'supreme-Clowns-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2019-12-26', 'tees': []},
#   {'week': '2020-01-02', 'tees': []}]]

# %%
ss18(all_tees)

# %%
ss18tees = get_all_tees()

# %%
ss18tees = add_stockx_names(ss18tees)

# %%
ss18(ss18tees)

# %%
add_stockx_prices(ss18tees)
ss18tees
# Out:
# 17:59:57 :: Retrieving raw details for supreme-FTW-Tee-black
# Good search. 124
# 18:00:00 :: Retrieving raw details for supreme-Cards-Tee-black
# Good search. 91
# 18:00:04 :: Retrieving raw details for supreme-Chicken-Dinner-Tee-black
# Good search. 117
# 18:00:07 :: Retrieving raw details for supreme-Necklace-Tee-black
# Good search. 153
# 18:00:10 :: Retrieving raw details for supreme-Jellyfish-Tee-black
# Good search. 98
# 18:00:14 :: Retrieving raw details for supreme-Prodigy-Tee-black
# Good search. 58
# 18:00:17 :: Retrieving raw details for supreme-Molotov-Tee-black
# Good search. 59
# 18:00:20 :: Retrieving raw details for supreme-Chair-Tee-black
# Good search. 55
# 18:00:23 :: Retrieving raw details for supreme-Chart-Tee-black
# Good search. 85
# 18:00:27 :: Retrieving raw details for supreme-Ripple-ls-Tee-black
# Good search. 95
# 18:00:30 :: Retrieving raw details for supreme-FTW-Tee-black
# Good search. 124
# 18:00:33 :: Retrieving raw details for supreme-Cards-Tee-black
# Good search. 91
# 18:00:37 :: Retrieving raw details for supreme-Chicken-Dinner-Tee-black
# Good search. 117
#      'price': 98},
#     {'name': 'Prodigy Tee',
#      'search': 'supreme-Prodigy-Tee-black',
#      'price': 58},
#     {'name': 'Molotov Tee',
#      'search': 'supreme-Molotov-Tee-black',
#      'price': 59},
#     {'name': 'Chair Tee', 'search': 'supreme-Chair-Tee-black', 'price': 55},
#     {'name': 'Chart Tee', 'search': 'supreme-Chart-Tee-black', 'price': 85},
#     {'name': 'Ripple L/S Tee',
#      'search': 'supreme-Ripple-ls-Tee-black',
#      'price': 95}]},
#   {'week': '2018-02-22',
#    'tees': [{'name': 'FTW Tee',
#      'search': 'supreme-FTW-Tee-black',
#      'price': 124},
#     {'name': 'Cards Tee', 'search': 'supreme-Cards-Tee-black', 'price': 91},
#     {'name': 'Chicken Dinner Tee',
#      'search': 'supreme-Chicken-Dinner-Tee-black',
#      'price': 117},
#     {'name': 'Necklace Tee',
#      'search': 'supreme-Necklace-Tee-black',
#      'price': 153},
#     {'name': 'Jellyfish Tee',
#      'search': 'supreme-Jellyfish-Tee-black',
#      'price': 98},
#     {'name': 'Prodigy Tee',
#      'search': 'supreme-Prodigy-Tee-black',
#      'price': 58},
#     {'name': 'Molotov Tee',
#      'search': 'supreme-Molotov-Tee-black',
#      'price': 59},
#     {'name': 'Chair Tee', 'search': 'supreme-Chair-Tee-black', 'price': 55},
#     {'name': 'Chart Tee', 'search': 'supreme-Chart-Tee-black', 'price': 85},
#     {'name': 'Ripple L/S Tee',
#      'search': 'supreme-Ripple-ls-Tee-black',
#      'price': 95}]},
#   {'week': '2018-03-01', 'tees': []},
#   {'week': '2018-03-08', 'tees': []},
#   {'week': '2018-03-15',
#    'tees': [{'name': 'Supreme®/UNDERCOVER/Public Enemy White House Tee',
#      'search': 'supreme--UNDERCOVER-Public-Enemy-White-House-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme®/UNDERCOVER/Public Enemy Tee',
#      'search': 'supreme--UNDERCOVER-Public-Enemy-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme®/UNDERCOVER/Public Enemy Counterattack L/S Tee',
#      'search': 'supreme--UNDERCOVER-Public-Enemy-Counterattack-ls-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme®/UNDERCOVER/Public Enemy Terrordome Tee',
#      'search': 'supreme--UNDERCOVER-Public-Enemy-Terrordome-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2018-03-22', 'tees': []},
#   {'week': '2018-03-29',
#    'tees': [{'name': 'TV Tee', 'search': 'supreme-TV-Tee-black', 'price': 172},
#     {'name': 'Diamonds Tee',
#      'search': 'supreme-Diamonds-Tee-black',
#      'price': 125},
#     {'name': 'Fiorenza Tee',
#      'search': 'supreme-Fiorenza-Tee-black',
#      'price': 68},
#     {'name': 'Ladybug Tee',
#      'search': 'supreme-Ladybug-Tee-black',
#      'price': 56},
#     {'name': 'Fuck Face Tee',
#      'search': 'supreme-Fuck-Face-Tee-black',
#      'price': 73},
#     {'name': 'Nan Goldin/Supreme Kim in Rhinestone Tee',
#      'search': 'supreme-Nan-Goldin-Kim-in-Rhinestone-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Nan Goldin/Supreme Misty and Jimmy Paulette Tee',
#      'search': 'supreme-Nan-Goldin-Misty-and-Jimmy-Paulette-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Nan Goldin/Supreme Nan as a dominatrix Tee',
#      'search': 'supreme-Nan-Goldin-Nan-as-a-dominatrix-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2018-04-05',
#    'tees': [{'name': 'Supreme®/The North Face® Metallic Logo T-Shirt',
#      'search': 'supreme--The-North-Face-Metallic-Logo-T-Shirt-black',
#      'price': 'Bad search'}]},
#   {'week': '2018-04-12', 'tees': []},
#   {'week': '2018-04-19', 'tees': []},
#   {'week': '2018-04-26',
#    'tees': [{'name': 'Supreme/Hellraiser Hell on Earth Tee',
#      'search': 'supreme--Hellraiser-Hell-on-Earth-Tee-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme/Hellraiser Pinhead Tee',
#      'search': 'supreme--Hellraiser-Pinhead-Tee-black',
#      'price': 'Bad search'}]},
#   {'week': '2018-05-03', 'tees': []},
#   {'week': '2018-05-10', 'tees': []},
#   {'week': '2018-05-17', 'tees': []},
#   {'week': '2018-05-24', 'tees': []},
#   {'week': '2018-05-31',
#    'tees': [{'name': 'Dream Tee',
#      'search': 'supreme-Dream-Tee-black',
#      'price': 123}]},
#   {'week': '2018-06-07', 'tees': []},
#   {'week': '2018-06-14', 'tees': []},
#   {'week': '2018-06-21',
#    'tees': [{'name': 'Supreme®/Spitfire® Classic Swirl T-Shirt',
#      'search': 'supreme--Spitfire-Classic-Swirl-T-Shirt-black',
#      'price': 'Bad search'},
#     {'name': 'Supreme®/Spitfire® Cat T-Shirt',
#      'search': 'supreme--Spitfire-Cat-T-Shirt-black',
#      'price': 'Bad search'}]},
#   {'week': '2018-06-28',
#    'tees': [{'name': 'Rocks Tee',
#      'search': 'supreme-Rocks-Tee-black-ss18',
#      'price': 159},
#     {'name': 'Mona Lisa Tee',
#      'search': 'supreme-Mona-Lisa-Tee-black-ss18',
#      'price': 174},
#     {'name': 'Tentacles Tee',
#      'search': 'supreme-Tentacles-Tee-black-ss18',
#      'price': 128},
#     {'name': 'Swimmers Tee',
#      'search': 'supreme-Swimmers-Tee-black-ss18',
#      'price': 82},
#     {'name': 'Ganesha Tee',
#      'search': 'supreme-Ganesha-Tee-black-ss18',
#      'price': 69},
#     {'name': 'Hardware Tee',
#      'search': 'supreme-Hardware-Tee-black-ss18',
#      'price': 80},
#     {'name': 'Gonz Logo Tee',
#      'search': 'supreme-Gonz-Logo-Tee-black-ss18',
#      'price': 59}]},
#   {'week': '2018-07-05', 'tees': []}]]

# %%
with open('supreme_tshirts_2018_{}.csv'.format(datetime.now().strftime('%H %M %S')), 'w', newline='') as csvfile:
    fieldnames = ['name', 'release date', 'stockx search', 'search quality']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for season in ss18tees:
        for date in season:
            for t in date['tees']:
                writer.writerow({'name': t['name'], 'release date': date['week'], 'stockx search': t['search'], 'search quality': t['price']})

# %%
d = Downloader()

with open('supreme_tshirts.csv', 'w', newline='') as csvfile:
    fieldnames = ['name', 'release date', 'stockx search', 'price']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for season in all_tees:
        for date in season:
            for t in date['tees']:
                search = sc_to_stockx_name(t)
                time.sleep(1)
                first = d.get_search_results(search)
                try:
                    price = first['Products'][0]['market']['averageDeadstockPrice']
                except (AttributeError, IndexError):
                    print("{} was a bad search".format(search))
                    price = "Bad search"
                
                writer.writerow({'name': t, 'release date': date['week'], 'stockx search': search, 'price': price})
# Out:
# 17:33:12 :: Retrieving search results for Sade-Tee-black
# 17:33:13 :: Retrieving search results for Elephant-Tee-black
# 17:33:14 :: Retrieving search results for Abstract-Tee-black
# 17:33:16 :: Retrieving search results for Eternal-Tee-black
# 17:33:17 :: Retrieving search results for FTP-Tee-black
# 17:33:18 :: Retrieving search results for Automatic-Tee-black
# 17:33:20 :: Retrieving search results for Joe-Roberts-Swirl-Tee-black
# 17:33:21 :: Retrieving search results for Dream-Tee-black
# 17:33:22 :: Retrieving search results for Been-Hit-ls-Tee-black
# 17:33:23 :: Retrieving search results for Larry-Clark-Girl-Tee-black
# 17:33:25 :: Retrieving search results for Mirage-Tee-black
# 17:33:26 :: Retrieving search results for Digi-Tee-black
# 17:33:27 :: Retrieving search results for Punany-Train-Tee-black
# 17:33:28 :: Retrieving search results for Super-Supreme-Tee-black
# 17:33:29 :: Retrieving search results for Undercover-Lover-Tee-black
# 17:33:31 :: Retrieving search results for Orgy-Tee-black
# 17:33:32 :: Retrieving search results for Go-Fuck-Yourself-Tee-black
# Go-Fuck-Yourself-Tee-black was a bad search
# 17:33:33 :: Retrieving search results for Buy-Off-The-Bar-Tee-black
# 17:33:35 :: Retrieving search results for Know-Your-Rights-Tee-black
# 17:33:36 :: Retrieving search results for Nas-Tee-black
# 17:33:37 :: Retrieving search results for Crash-Tee-black
# 17:33:38 :: Retrieving search results for Dollar-Tee-black
# 17:33:40 :: Retrieving search results for DNA-Tee-black
# 17:33:41 :: Retrieving search results for Heart-Tee-black
# 17:33:42 :: Retrieving search results for Gonz-Heads-Tee-black
# 17:33:44 :: Retrieving search results for Fuck-With-Your-Head-Tee-black
# 17:33:45 :: Retrieving search results for Venus-Tee-black
# 17:33:46 :: Retrieving search results for Bloom-ls-Tee-black
# 17:33:47 :: Retrieving search results for Kiss-Tee-black
# 17:33:48 :: Retrieving search results for Nas-Tee-black
# 17:33:50 :: Retrieving search results for Crash-Tee-black
# 17:33:51 :: Retrieving search results for Dollar-Tee-black
# 17:33:52 :: Retrieving search results for DNA-Tee-black
# 17:33:54 :: Retrieving search results for Heart-Tee-black
# 17:33:55 :: Retrieving search results for Gonz-Heads-Tee-black
# 17:33:56 :: Retrieving search results for Fuck-With-Your-Head-Tee-black
# 17:33:57 :: Retrieving search results for Venus-Tee-black
# 17:33:58 :: Retrieving search results for Bloom-ls-Tee-black
# 17:34:00 :: Retrieving search results for Kiss-Tee-black
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-1f3c52af550f> in <module>()
#      11                 search = sc_to_stockx_name(t)
#      12                 time.sleep(1)
# ---> 13                 first = d.get_first_result(search)
#      14                 try:
#      15                     price = first['Products'][0]['market']['averageDeadstockPrice']
#
# <ipython-input-6-3cd7ef0eee14> in get_first_result(self, query)
#      24             r.raise_for_status()
#      25         except requests.exceptions.HTTPError:
# ---> 26             log('Product detail retrieval failed [{}] : {}'.format(r.status_code, j['error']))
#      27             return 'Failed'
#      28         return j
#
# KeyError: 'error'

# %%
d.get()

# %%
PRODUCT = 'supreme-motion-logo-tee-ss20-white'

# %%
d = Downloader()

# %%
d.get_raw_details(PRODUCT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-35eef124f1b2> in <module>()
# ----> 1 d.get_raw_details(PRODUCT)
#
# NameError: name 'PRODUCT' is not defined

# %%
yeezy_query = d.get_search_results("yeezy")
# Out:
# 17:46:07 :: Retrieving search results for yeezy

# %%
yeezy_query['Products'][0]['market']['averageDeadstockPrice']
# Out:
# 304

# %%
cloud = d.get_raw_details("supreme-cloud-tee-black")
# Out:
# 18:28:15 :: Retrieving raw details for supreme-cloud-tee-black

# %%
cloud['Product']['market']['averageDeadstockPrice']
# Out:
# 60

# %%
cloud = d.get_search_results("supreme-cloud-tee")
# Out:
# 21:13:42 :: Retrieving search results for supreme-cloud-tee
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-35-4a9dcfd3fe68> in get_search_results(self, query)
#      23         try:
# ---> 24             r.raise_for_status()
#      25         except requests.exceptions.HTTPError:
#
# ~\AppData\Roaming\Python\Python37\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 403 Client Error: Forbidden for url: https://stockx.com/api/browse?&_search=supreme-cloud-tee
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-202068c1538d> in <module>()
# ----> 1 cloud = d.get_search_results("supreme-cloud-tee")
#
# <ipython-input-35-4a9dcfd3fe68> in get_search_results(self, query)
#      24             r.raise_for_status()
#      25         except requests.exceptions.HTTPError:
# ---> 26             log('Product detail retrieval failed [{}] : {}'.format(r.status_code, j['error']))
#      27             return 'Failed'
#      28         return j
#
# KeyError: 'error'

# %%
len(cloud['Products'])
# Out:
# 40

# %%
cloud['Products']
# Out:
# [{'id': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'uuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': None,
#   'colorway': 'Black',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'product',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee Black',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-Black',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTBK',
#   'title': 'Supreme Cloud Tee Black',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'Black',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-black',
#   'year': 2019,
#   'shoeSize': None,
#   'market': {'productId': 0,
#    'skuUuid': None,
#    'productUuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#    'lowestAsk': 60,
#    'lowestAskSize': 'M',
#    'parentLowestAsk': 60,
#    'numberOfAsks': 28,
#    'hasAsks': 1,
#    'salesThisPeriod': 3,
#    'salesLastPeriod': None,
#    'highestBid': 67,
#    'highestBidSize': 'L',
#    'numberOfBids': 15,
#    'hasBids': 1,
#    'annualHigh': 115,
#    'annualLow': 45,
#    'deadstockRangeLow': 65,
#    'deadstockRangeHigh': 75,
#    'volatility': 0.065843,
#    'deadstockSold': 271,
#    'pricePremium': 0.842,
#    'averageDeadstockPrice': 60,
#    'lastSale': 70,
#    'lastSaleSize': 'L',
#    'salesLast72Hours': 3,
#    'changeValue': 1,
#    'changePercentage': 0.014493,
#    'absChangePercentage': 0.014493,
#    'totalDollars': 16179,
#    'updatedAt': 1594400522,
#    'lastLowestAskTime': 1593293235,
#    'lastHighestBidTime': 1594400521,
#    'lastSaleDate': '2020-07-10T05:18:30+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 63,
#    'pricePremiumRank': 35,
#    'averageDeadstockPriceRank': 92,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3'},
#  {'id': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#   'uuid': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': None,
#   'colorway': 'White',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'product',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee White',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-White',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTWH',
#   'title': 'Supreme Cloud Tee White',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'White',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-white',
#   'year': 2019,
#   'shoeSize': None,
#   'market': {'productId': 0,
#    'skuUuid': None,
#    'productUuid': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#    'lowestAsk': 54,
#    'lowestAskSize': 'XL',
#    'parentLowestAsk': 54,
#    'numberOfAsks': 30,
#    'hasAsks': 1,
#    'salesThisPeriod': 2,
#    'salesLastPeriod': None,
#    'highestBid': 55,
#    'highestBidSize': 'M',
#    'numberOfBids': 11,
#    'hasBids': 1,
#    'annualHigh': 85,
#    'annualLow': 35,
#    'deadstockRangeLow': 47,
#    'deadstockRangeHigh': 63,
#    'volatility': 0.137737,
#    'deadstockSold': 166,
#    'pricePremium': 0.447,
#    'averageDeadstockPrice': 52,
#    'lastSale': 55,
#    'lastSaleSize': 'M',
#    'salesLast72Hours': 2,
#    'changeValue': -23,
#    'changePercentage': -0.294872,
#    'absChangePercentage': 0.294872,
#    'totalDollars': 8681,
#    'updatedAt': 1594418632,
#    'lastLowestAskTime': 1593125154,
#    'lastHighestBidTime': 1594414994,
#    'lastSaleDate': '2020-07-10T08:41:49+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 9,
#    'pricePremiumRank': 69,
#    'averageDeadstockPriceRank': 62,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': 'cacb62af-b6b5-425b-98de-8c95664760f4'},
#  {'id': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'uuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': '03912802-5b31-4a63-87af-f80def96f7b5',
#   'colorway': 'Black',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'sku',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee Black',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-Black',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTBK',
#   'title': 'Supreme Cloud Tee Black',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'Black',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-black',
#   'year': 2019,
#   'shoeSize': 'L',
#   'market': {'productId': 0,
#    'skuUuid': '03912802-5b31-4a63-87af-f80def96f7b5',
#    'productUuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#    'lowestAsk': 78,
#    'lowestAskSize': 'L',
#    'parentLowestAsk': 60,
#    'numberOfAsks': 9,
#    'hasAsks': 1,
#    'salesThisPeriod': 2,
#    'salesLastPeriod': None,
#    'highestBid': 67,
#    'highestBidSize': 'L',
#    'numberOfBids': 5,
#    'hasBids': 1,
#    'annualHigh': 71,
#    'annualLow': 45,
#    'deadstockRangeLow': 63,
#    'deadstockRangeHigh': 77,
#    'volatility': 0.099801,
#    'deadstockSold': 88,
#    'pricePremium': 0.842,
#    'averageDeadstockPrice': 60,
#    'lastSale': 70,
#    'lastSaleSize': 'L',
#    'salesLast72Hours': 2,
#    'changeValue': 1,
#    'changePercentage': 0.014493,
#    'absChangePercentage': 0.014493,
#    'totalDollars': 5258,
#    'updatedAt': 1594400522,
#    'lastLowestAskTime': 1593502922,
#    'lastHighestBidTime': 1594400522,
#    'lastSaleDate': '2020-07-10T05:18:30+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 95,
#    'pricePremiumRank': 59,
#    'averageDeadstockPriceRank': 80,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': '03912802-5b31-4a63-87af-f80def96f7b5'},
#  {'id': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'uuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': '0d7dc66e-8eba-49fd-b95e-e3137b2dab48',
#   'colorway': 'Black',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'sku',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee Black',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-Black',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTBK',
#   'title': 'Supreme Cloud Tee Black',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'Black',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-black',
#   'year': 2019,
#   'shoeSize': 'M',
#   'market': {'productId': 0,
#    'skuUuid': '0d7dc66e-8eba-49fd-b95e-e3137b2dab48',
#    'productUuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#    'lowestAsk': 60,
#    'lowestAskSize': 'M',
#    'parentLowestAsk': 60,
#    'numberOfAsks': 9,
#    'hasAsks': 1,
#    'salesThisPeriod': 1,
#    'salesLastPeriod': None,
#    'highestBid': 54,
#    'highestBidSize': 'M',
#    'numberOfBids': 4,
#    'hasBids': 1,
#    'annualHigh': 74,
#    'annualLow': 45,
#    'deadstockRangeLow': 50,
#    'deadstockRangeHigh': 58,
#    'volatility': 0.07887,
#    'deadstockSold': 119,
#    'pricePremium': 0.421,
#    'averageDeadstockPrice': 56,
#    'lastSale': 54,
#    'lastSaleSize': 'M',
#    'salesLast72Hours': 1,
#    'changeValue': -3,
#    'changePercentage': -0.052632,
#    'absChangePercentage': 0.052632,
#    'totalDollars': 6666,
#    'updatedAt': 1594350779,
#    'lastLowestAskTime': 1593293236,
#    'lastHighestBidTime': 1594170041,
#    'lastSaleDate': '2020-07-07T18:15:09+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 24,
#    'pricePremiumRank': 68,
#    'averageDeadstockPriceRank': 9,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': '0d7dc66e-8eba-49fd-b95e-e3137b2dab48'},
#  {'id': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#   'uuid': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': '077509dc-0535-4dcb-a360-b672a2ffb3dc',
#   'colorway': 'White',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'sku',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee White',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-White',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTWH',
#   'title': 'Supreme Cloud Tee White',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'White',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-white',
#   'year': 2019,
#   'shoeSize': 'M',
#   'market': {'productId': 0,
#    'skuUuid': '077509dc-0535-4dcb-a360-b672a2ffb3dc',
#    'productUuid': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#    'lowestAsk': 60,
#    'lowestAskSize': 'M',
#    'parentLowestAsk': 54,
#    'numberOfAsks': 12,
#    'hasAsks': 1,
#    'salesThisPeriod': 1,
#    'salesLastPeriod': None,
#    'highestBid': 55,
#    'highestBidSize': 'M',
#    'numberOfBids': 3,
#    'hasBids': 1,
#    'annualHigh': 68,
#    'annualLow': 35,
#    'deadstockRangeLow': 51,
#    'deadstockRangeHigh': 59,
#    'volatility': 0.078948,
#    'deadstockSold': 82,
#    'pricePremium': 0.447,
#    'averageDeadstockPrice': 50,
#    'lastSale': 55,
#    'lastSaleSize': 'M',
#    'salesLast72Hours': 1,
#    'changeValue': -4,
#    'changePercentage': -0.067797,
#    'absChangePercentage': 0.067797,
#    'totalDollars': 4083,
#    'updatedAt': 1594417475,
#    'lastLowestAskTime': 1594315904,
#    'lastHighestBidTime': 1594414994,
#    'lastSaleDate': '2020-07-10T08:41:49+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 30,
#    'pricePremiumRank': 82,
#    'averageDeadstockPriceRank': 87,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': '077509dc-0535-4dcb-a360-b672a2ffb3dc'},
#  {'id': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'uuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': '7380d73d-4fce-453f-8a05-c652d20809be',
#   'colorway': 'Black',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'sku',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Black.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee Black',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-Black',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTBK',
#   'title': 'Supreme Cloud Tee Black',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'Black',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-black',
#   'year': 2019,
#   'shoeSize': 'XL',
#   'market': {'productId': 0,
#    'skuUuid': '7380d73d-4fce-453f-8a05-c652d20809be',
#    'productUuid': '8c863970-f2cc-408d-b1fd-1e921bd5e2e3',
#    'lowestAsk': 65,
#    'lowestAskSize': 'XL',
#    'parentLowestAsk': 60,
#    'numberOfAsks': 6,
#    'hasAsks': 1,
#    'salesThisPeriod': 1,
#    'salesLastPeriod': None,
#    'highestBid': 51,
#    'highestBidSize': 'XL',
#    'numberOfBids': 4,
#    'hasBids': 1,
#    'annualHigh': 67,
#    'annualLow': 45,
#    'deadstockRangeLow': 57,
#    'deadstockRangeHigh': 69,
#    'volatility': 0.093934,
#    'deadstockSold': 52,
#    'pricePremium': 0.658,
#    'averageDeadstockPrice': 58,
#    'lastSale': 63,
#    'lastSaleSize': 'XL',
#    'salesLast72Hours': 1,
#    'changeValue': 3,
#    'changePercentage': 0.05,
#    'absChangePercentage': 0.05,
#    'totalDollars': 3027,
#    'updatedAt': 1594266088,
#    'lastLowestAskTime': 1593216837,
#    'lastHighestBidTime': 1593878278,
#    'lastSaleDate': '2020-07-08T02:42:27+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 21,
#    'pricePremiumRank': 52,
#    'averageDeadstockPriceRank': 34,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': '7380d73d-4fce-453f-8a05-c652d20809be'},
#  {'id': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#   'uuid': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': 'f8653390-1820-4029-abd3-7db2882a33b7',
#   'colorway': 'White',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'sku',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-White.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561651191',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee White',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-White',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTWH',
#   'title': 'Supreme Cloud Tee White',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'White',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-white',
#   'year': 2019,
#   'shoeSize': 'S',
#   'market': {'productId': 0,
#    'skuUuid': 'f8653390-1820-4029-abd3-7db2882a33b7',
#    'productUuid': 'cacb62af-b6b5-425b-98de-8c95664760f4',
#    'lowestAsk': 79,
#    'lowestAskSize': 'S',
#    'parentLowestAsk': 54,
#    'numberOfAsks': 2,
#    'hasAsks': 1,
#    'salesThisPeriod': 1,
#    'salesLastPeriod': None,
#    'highestBid': 22,
#    'highestBidSize': 'S',
#    'numberOfBids': 2,
#    'hasBids': 1,
#    'annualHigh': 85,
#    'annualLow': 55,
#    'deadstockRangeLow': 71,
#    'deadstockRangeHigh': 85,
#    'volatility': 0.093257,
#    'deadstockSold': 17,
#    'pricePremium': 1.053,
#    'averageDeadstockPrice': 67,
#    'lastSale': 78,
#    'lastSaleSize': 'S',
#    'salesLast72Hours': 1,
#    'changeValue': -1,
#    'changePercentage': -0.012658,
#    'absChangePercentage': 0.012658,
#    'totalDollars': 1140,
#    'updatedAt': 1594180878,
#    'lastLowestAskTime': 1593653098,
#    'lastHighestBidTime': 1591277543,
#    'lastSaleDate': '2020-07-07T22:39:18+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 19,
#    'pricePremiumRank': 56,
#    'averageDeadstockPriceRank': 30,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'release_date|2019-06-27',
#    'retail_price|38',
#    'season|ss19'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': 'f8653390-1820-4029-abd3-7db2882a33b7'},
#  {'id': '68ad64b7-ac9e-49aa-8461-c47f74d8ec53',
#   'uuid': '68ad64b7-ac9e-49aa-8461-c47f74d8ec53',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': None,
#   'colorway': 'Navy',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'product',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Navy.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561665614',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Navy.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561665614',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Navy.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561665614',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee Navy',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-Navy',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTNV',
#   'title': 'Supreme Cloud Tee Navy',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'Navy',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-navy',
#   'year': 2019,
#   'shoeSize': None,
#   'market': {'productId': 0,
#    'skuUuid': None,
#    'productUuid': '68ad64b7-ac9e-49aa-8461-c47f74d8ec53',
#    'lowestAsk': 65,
#    'lowestAskSize': 'M',
#    'parentLowestAsk': 65,
#    'numberOfAsks': 14,
#    'hasAsks': 1,
#    'salesThisPeriod': None,
#    'salesLastPeriod': None,
#    'highestBid': 53,
#    'highestBidSize': 'L',
#    'numberOfBids': 10,
#    'hasBids': 1,
#    'annualHigh': 145,
#    'annualLow': 33,
#    'deadstockRangeLow': 28,
#    'deadstockRangeHigh': 80,
#    'volatility': 0.487088,
#    'deadstockSold': 68,
#    'pricePremium': 0.421,
#    'averageDeadstockPrice': 63,
#    'lastSale': 54,
#    'lastSaleSize': 'M',
#    'salesLast72Hours': None,
#    'changeValue': -5,
#    'changePercentage': -0.084746,
#    'absChangePercentage': 0.084746,
#    'totalDollars': 4268,
#    'updatedAt': 1594414748,
#    'lastLowestAskTime': 1593882631,
#    'lastHighestBidTime': 1594400718,
#    'lastSaleDate': '2020-06-15T18:38:12+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 44,
#    'pricePremiumRank': 25,
#    'averageDeadstockPriceRank': 100,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
# ...
#    'lastSaleDate': '2020-01-03T01:29:15+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 30,
#    'pricePremiumRank': 0,
#    'averageDeadstockPriceRank': 61,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'release_date|2019-06-27',
#    'retail_price|38',
#    'season|ss19'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': '014e9438-1d74-4b2d-84d9-1141489167f8'},
#  {'id': '0dacded4-8adb-4348-838c-d571e31d4891',
#   'uuid': '0dacded4-8adb-4348-838c-d571e31d4891',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': 'effaa588-2fa1-456e-9bcc-bb7250d0e612',
#   'colorway': 'Acid Yellow',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'sku',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Acid-Yellow.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561650319',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Acid-Yellow.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561650319',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Acid-Yellow.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561650319',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee Acid Yellow',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-Acid-Yellow',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTADY',
#   'title': 'Supreme Cloud Tee Acid Yellow',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'Acid Yellow',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-acid-yellow',
#   'year': 2019,
#   'shoeSize': 'S',
#   'market': {'productId': 0,
#    'skuUuid': 'effaa588-2fa1-456e-9bcc-bb7250d0e612',
#    'productUuid': '0dacded4-8adb-4348-838c-d571e31d4891',
#    'lowestAsk': 50,
#    'lowestAskSize': None,
#    'parentLowestAsk': 50,
#    'numberOfAsks': 1,
#    'hasAsks': 1,
#    'salesThisPeriod': None,
#    'salesLastPeriod': None,
#    'highestBid': 22,
#    'highestBidSize': 'S',
#    'numberOfBids': 1,
#    'hasBids': 1,
#    'annualHigh': 73,
#    'annualLow': 50,
#    'deadstockRangeLow': 64,
#    'deadstockRangeHigh': 82,
#    'volatility': 0.124527,
#    'deadstockSold': 4,
#    'pricePremium': 0.911,
#    'averageDeadstockPrice': 57,
#    'lastSale': 73,
#    'lastSaleSize': 'S',
#    'salesLast72Hours': None,
#    'changeValue': 19,
#    'changePercentage': 0.345007,
#    'absChangePercentage': 0.345007,
#    'totalDollars': 229,
#    'updatedAt': 1593132414,
#    'lastLowestAskTime': None,
#    'lastHighestBidTime': 1588848457,
#    'lastSaleDate': '2019-11-29T19:03:17+00:00',
#    'createdAt': '2019-06-27T12:52:34+00:00',
#    'deadstockSoldRank': 29,
#    'pricePremiumRank': 12,
#    'averageDeadstockPriceRank': 83,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': 'effaa588-2fa1-456e-9bcc-bb7250d0e612'},
#  {'id': '0dacded4-8adb-4348-838c-d571e31d4891',
#   'uuid': '0dacded4-8adb-4348-838c-d571e31d4891',
#   'brand': 'Supreme',
#   'breadcrumbs': [],
#   'category': 'Supreme T-Shirts',
#   'charityCondition': 0,
#   'childId': '173a6255-dc73-46f6-8061-16eec8b55988',
#   'colorway': 'Acid Yellow',
#   'condition': 'New',
#   'countryOfManufacture': None,
#   'dataType': 'sku',
#   'description': None,
#   'hidden': False,
#   'ipoDate': None,
#   'minimumBid': 15,
#   'gender': 'men',
#   'doppelgangers': [],
#   'media': {'imageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Acid-Yellow.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561650319',
#    'smallImageUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Acid-Yellow.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561650319',
#    'thumbUrl': 'https://stockx.imgix.net/products/streetwear/Supreme-Cloud-Tee-Acid-Yellow.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1561650319',
#    'gallery': [],
#    'hidden': False},
#   'name': 'Tee Acid Yellow',
#   'productCategory': 'streetwear',
#   'releaseDate': '2019-06-27 23:59:59',
#   'releaseTime': 1561593600,
#   'belowRetail': False,
#   'retailPrice': 38,
#   'shoe': 'Supreme Cloud',
#   'shortDescription': 'Supreme-Cloud-Tee-Acid-Yellow',
#   'styleId': None,
#   'tickerSymbol': 'SUP-CLTADY',
#   'title': 'Supreme Cloud Tee Acid Yellow',
#   'traits': [{'name': 'Season',
#     'value': 'SS19',
#     'filterable': True,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Color',
#     'value': 'Acid Yellow',
#     'filterable': False,
#     'visible': True,
#     'highlight': True},
#    {'name': 'Release Date',
#     'value': '2019-06-27',
#     'filterable': True,
#     'visible': True,
#     'highlight': False},
#    {'name': 'Retail',
#     'value': 38,
#     'filterable': True,
#     'visible': True,
#     'highlight': False,
#     'format': 'currency'}],
#   'type': 0,
#   'urlKey': 'supreme-cloud-tee-acid-yellow',
#   'year': 2019,
#   'shoeSize': 'XL',
#   'market': {'productId': 0,
#    'skuUuid': '173a6255-dc73-46f6-8061-16eec8b55988',
#    'productUuid': '0dacded4-8adb-4348-838c-d571e31d4891',
#    'lowestAsk': 85,
#    'lowestAskSize': 'XL',
#    'parentLowestAsk': 50,
#    'numberOfAsks': 3,
#    'hasAsks': 1,
#    'salesThisPeriod': None,
#    'salesLastPeriod': None,
#    'highestBid': 16,
#    'highestBidSize': 'XL',
#    'numberOfBids': 2,
#    'hasBids': 1,
#    'annualHigh': 55,
#    'annualLow': 40,
#    'deadstockRangeLow': 34,
#    'deadstockRangeHigh': 46,
#    'volatility': 0.162019,
#    'deadstockSold': 3,
#    'pricePremium': 0.053,
#    'averageDeadstockPrice': 49,
#    'lastSale': 40,
#    'lastSaleSize': 'XL',
#    'salesLast72Hours': None,
#    'changeValue': -15,
#    'changePercentage': -0.272727,
#    'absChangePercentage': 0.272727,
#    'totalDollars': 147,
#    'updatedAt': 1594267600,
#    'lastLowestAskTime': 1593660458,
#    'lastHighestBidTime': 1587989698,
#    'lastSaleDate': '2019-09-18T21:11:09+00:00',
#    'createdAt': '2019-06-27T12:52:35+00:00',
#    'deadstockSoldRank': 98,
#    'pricePremiumRank': 18,
#    'averageDeadstockPriceRank': 61,
#    'featured': None},
#   '_tags': ['streetwear',
#    'supreme',
#    'supreme',
#    't-shirts',
#    'season|ss19',
#    'release_date|2019-06-27',
#    'retail_price|38'],
#   'lock_selling': False,
#   'selling_countries': ['BZ',
#    'CL',
#    'CN',
#    'CO',
#    'CR',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GP',
#    'GT',
#    'GU',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LC',
#    'LS',
#    'MA',
#    'MO',
#    'MP',
#    'MQ',
#    'MU',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PH',
#    'PR',
#    'PW',
#    'QA',
#    'RE',
#    'SA',
#    'SC',
#    'SG',
#    'SN',
#    'SV',
#    'TC',
#    'TH',
#    'TW',
#    'UY',
#    'VE',
#    'VI',
#    'VN',
#    'ZA',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'VA',
#    'CA',
#    'FR',
#    'GB',
#    'US',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AR',
#    'AS',
#    'BB',
#    'BH',
#    'BM',
#    'BR',
#    'BS',
#    'BW'],
#   'buying_countries': ['BZ',
#    'CI',
#    'CK',
#    'CL',
#    'CM',
#    'CN',
#    'CO',
#    'CR',
#    'CV',
#    'DJ',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'ER',
#    'ET',
#    'FJ',
#    'GD',
#    'GF',
#    'GL',
#    'GM',
#    'GN',
#    'GP',
#    'GT',
#    'GU',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KY',
#    'LA',
#    'LC',
#    'LK',
#    'LS',
#    'MA',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MP',
#    'MQ',
#    'MR',
#    'MS',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NC',
#    'NE',
#    'NF',
#    'NG',
#    'NI',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PF',
#    'PG',
#    'PH',
#    'PR',
#    'PW',
#    'PY',
#    'QA',
#    'RE',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SL',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TC',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TM',
#    'TN',
#    'TO',
#    'TV',
#    'TW',
#    'TZ',
#    'UG',
#    'UY',
#    'VC',
#    'VE',
#    'VG',
#    'VI',
#    'VN',
#    'VU',
#    'WF',
#    'WS',
#    'YE',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW',
#    'BN',
#    'CD',
#    'CG',
#    'EG',
#    'FM',
#    'GA',
#    'NA',
#    'TT',
#    'GG',
#    'JE',
#    'AD',
#    'AL',
#    'AM',
#    'AT',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'FI',
#    'FO',
#    'GE',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'JP',
#    'KZ',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'SE',
#    'SI',
#    'SK',
#    'UA',
#    'VA',
#    'AZ',
#    'IT',
#    'MD',
#    'PT',
#    'RU',
#    'SM',
#    'TR',
#    'CA',
#    'FR',
#    'GB',
#    'ES',
#    'US',
#    'XK',
#    'IN',
#    'AU',
#    'AE',
#    'AG',
#    'AI',
#    'AO',
#    'AR',
#    'AS',
#    'AW',
#    'BB',
#    'BF',
#    'BH',
#    'BI',
#    'BJ',
#    'BM',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW'],
#   'objectID': '173a6255-dc73-46f6-8061-16eec8b55988'}]
